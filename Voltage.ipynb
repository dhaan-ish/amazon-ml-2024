# %%
# !pip install paddlepaddle paddleocr
# !pip install gdown
# Out:
# Collecting paddlepaddle
#   Downloading paddlepaddle-2.6.2-cp310-cp310-manylinux1_x86_64.whl.metadata (8.6 kB)
# Collecting paddleocr
#   Downloading paddleocr-2.8.1-py3-none-any.whl.metadata (19 kB)
# Collecting httpx (from paddlepaddle)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (10.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (5.1.1)
# Collecting astor (from paddlepaddle)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (3.3.0)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (3.20.3)
# Collecting shapely (from paddleocr)
#   Downloading shapely-2.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from paddleocr) (0.23.2)
# Collecting imgaug (from paddleocr)
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting pyclipper (from paddleocr)
#   Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (9.0 kB)
# Collecting lmdb (from paddleocr)
#   Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.66.5)
# Collecting rapidfuzz (from paddleocr)
#   Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.10.0.84)
# Collecting opencv-contrib-python (from paddleocr)
#   Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting cython (from paddleocr)
#   Downloading Cython-3.0.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from paddleocr) (6.0.2)
# Collecting python-docx (from paddleocr)
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.53.1)
# Collecting fire>=0.3.0 (from paddleocr)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from paddleocr) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr) (2.4.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->paddleocr) (2.6)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (2024.8.30)
# Collecting httpcore==1.* (from httpx->paddlepaddle)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (3.8)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->paddlepaddle)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (1.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (3.7.1)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (2.35.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (3.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (2024.8.30)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (0.4)
# Collecting lxml>=3.1.0 (from python-docx->paddleocr)
#   Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->paddleocr) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (2.0.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->paddlepaddle) (1.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (2.9.0.post0)
# Downloading paddlepaddle-2.6.2-cp310-cp310-manylinux1_x86_64.whl (126.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 MB 4.9 MB/s eta 0:00:00
# Downloading paddleocr-2.8.1-py3-none-any.whl (407 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.5/407.5 kB 11.2 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading Cython-3.0.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 69.5 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 21.5 kB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.5 MB/s eta 0:00:00
# Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 43.4 MB/s eta 0:00:00
# Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 18.4 MB/s eta 0:00:00
# Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (68.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 MB 16.4 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (908 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 42.4 MB/s eta 0:00:00
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 16.2 MB/s eta 0:00:00
# Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 94.2 MB/s eta 0:00:00
# Downloading shapely-2.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 77.7 MB/s eta 0:00:00
# Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 71.9 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.6 MB/s eta 0:00:00
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=069887fc49ba9f2856f389c0c6b8280f0a3af55c63e99ba76d57ce7951dbdcce
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# Installing collected packages: pyclipper, lmdb, shapely, rapidfuzz, opencv-contrib-python, lxml, h11, fire, cython, astor, python-docx, httpcore, imgaug, httpx, paddlepaddle, paddleocr
# Successfully installed astor-0.8.1 cython-3.0.11 fire-0.6.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 imgaug-0.4.0 lmdb-1.5.1 lxml-5.3.0 opencv-contrib-python-4.10.0.84 paddleocr-2.8.1 paddlepaddle-2.6.2 pyclipper-1.3.0.post5 python-docx-1.1.2 rapidfuzz-3.9.7 shapely-2.0.6
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %% [markdown]
# **1.** **Libraries and Imports**
# <br/>
# This section imports various libraries that enable functionality such as downloading images, performing OCR (Optical Character Recognition), manipulating images, working with data in CSV format, and downloading files from Google Drive. These libraries are essential for processing images, extracting relevant text, and handling the results.

# %%
import pandas as pd
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
from paddleocr import PaddleOCR
import numpy as np
from docx import Document
from docx.shared import Inches
from PIL import Image
import io
import gdown
import re
import os

# %% [markdown]
# **2. PaddleOCR Initialization**
# <br/>
# PaddleOCR is initialized in this section. The model is set to use angle classification and English language recognition. The use_gpu parameter is set to True, allowing the model to leverage GPU acceleration if available, improving the speed of OCR.

# %%
ocr = PaddleOCR(use_angle_cls=True, lang='en', use_gpu=True)
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100%|██████████| 4.00M/4.00M [00:16<00:00, 245kiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to /root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer/en_PP-OCRv4_rec_infer.tar
# 100%|██████████| 10.2M/10.2M [00:19<00:00, 521kiB/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2.19M/2.19M [00:14<00:00, 148kiB/s]
# [2024/09/14 13:13:39] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')

# %%
os.makedirs("dataset")

# %% [markdown]
# **3. Google Drive File Downloading**
# <br />
# The script uses the gdown library to download a CSV file from Google Drive. The file contains data, which is later used for prediction. The file is downloaded and saved locally with a specified name.

# %%
volt = '1Oe7QYgbejBWNre4g43gn_13lQUqOjKgt'
url = f'https://drive.google.com/uc?id={volt}'
output_file = 'downloaded_file.csv'
gdown.download(url, output_file, quiet=False)

print(f"File downloaded and saved as {output_file}")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Oe7QYgbejBWNre4g43gn_13lQUqOjKgt
# To: /content/downloaded_file.csv
# 100%|██████████| 401k/401k [00:00<00:00, 116MB/s]
# File downloaded and saved as downloaded_file.csv

# %% [markdown]
# **4. Image Downloading and Text Extraction**
# <br/>
# A function is defined to download an image from a URL using the requests library. The image is processed using PaddleOCR to extract text, which is then stored in a list. This extracted text will be processed in later steps to identify weight values and units.

# %%
def download_image(url):
    response = requests.get(url)
    image = Image.open(BytesIO(response.content))
    return image

# %% [markdown]
# **5. Text Extraction Using PaddleOCR**
# <br/>
# The function get_text() performs OCR on the downloaded image. It extracts all text in the image using PaddleOCR and organizes the results into a list. This extracted text will be processed to find voltage-related values using regular expressions.

# %%
def get_text(url):
    res = []
    image = download_image(url)
    image_np = np.array(image)
    result = ocr.ocr(image_np, cls=True)
    # print(result)
    try:
        for i in result:
            for j in i:
                for k in j:
                    if isinstance(k[0], str):
                        res.append(k[0])
    except Exception as e:
        print(f"An error occurred: {e}")
    print(res)
    return res

# %% [markdown]
# **6. Mapping Voltage Units**
# <br/>
# The function map_to_standard_unit() normalizes various representations of voltage units into a standard format, such as converting "mv" to "millivolt" and "kv" to "kilovolt". This ensures consistency in the units, making it easier to process and analyze the extracted values.

# %% [markdown]
# **7. Regular Expression for Voltage Detection**
# <br/>
# The find_value() function uses a regular expression to find voltage values in the extracted text. It searches for patterns involving numbers followed by voltage units (e.g., "V", "kV", "mV", etc.) and returns them in a standardized format. This ensures that voltage values from different images are extracted accurately.

# %%
def map_to_standard_unit(unit):
    conversion_map = {
        "mv": "millivolt",
        "millivolt": "millivolt",
        "millivolts": "millivolt",
        "mv.": "millivolt",
        "kv": "kilovolt",
        "kilovolt": "kilovolt",
        "kilovolts": "kilovolt",
        "kv.": "kilovolt",
        "v": "volt",
        "volts": "volt",
        "volt": "volt",
        "v.": "volt",
        "KV": "kilovolt",
        "kV": "kilovolt",
        "MV": "megavolt",
        "mV": "millivolt",
        "VOLT": "volt",
        "VOLTS": "volt"
    }
    return conversion_map.get(unit.lower().strip(':/.-\\'), unit)
def find_value(text_list):
    text = ' '.join(text_list).lower()
    pattern = r'(\d+(\.\d+)?)\s*[\/:\\.\-]?\s*([mMkKvV]?v|[mMkK]?[vV]?olts?|millivolt|kilovolt|volt|VOLT|VOLTS)\s*[\/:\\.\-]?\b'
    matches = re.findall(pattern, text, re.IGNORECASE)
    return [match[0] + ' ' + map_to_standard_unit(match[2]).strip() for match in matches]

# %% [markdown]
# **8. Prediction Logic**
# <br/>
# In the predictor() function, images are processed one by one, and text is extracted from each image. The function looks for voltage-related values using the regular expression and returns the first detected value. If no value is found, it returns an empty string.
# <br/>
# **9. Main Program Execution**
# <br/>
# In the main block of the program:
# The CSV file is loaded, and each row is processed.
# For each row, the image URL is passed to the predictor function, which returns the extracted voltage value.
# The predicted voltage values are added to the CSV file under a new "prediction" column.
# <br/>
# **10. Saving the Results**
# <br/>
# The script saves the processed data into a new CSV file within the dataset folder. This file contains the index and the predicted voltage values, allowing easy access to the results for analysis or validation.

# %%
i = 0

def predictor(url, category_id, entity_name):
    global i
    i += 1
    print(i)
    '''
    Call your model/approach here
    '''
    #TODO
    res = get_text(url)
    f = find_value(res)
    if len(f) > 0:
      print(f[0])
      return f[0]
    else:
      print("no")
      return " "

if __name__ == "__main__":
    DATASET_FOLDER = '/content/dataset'

    test = pd.read_csv('downloaded_file.csv')

    test['prediction'] = test.apply(
        lambda row: predictor(row['image_link'], row['group_id'], row['entity_name']), axis=1)

    output_filename = os.path.join(DATASET_FOLDER, 'test_out.csv')
    test[['index', 'prediction']].to_csv(output_filename, index=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# ['3000RPM Loading Speed', '3000RPM loading speed helps dissipate high', 'heat to a great extent.']
# no
# 4656
# [2024/09/14 14:26:01] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.2574741840362549
# [2024/09/14 14:26:01] ppocr DEBUG: cls num  : 5, elapsed : 0.04064750671386719
# [2024/09/14 14:26:02] ppocr DEBUG: rec_res num  : 5, elapsed : 0.2520740032196045
# ['iKzF4028', 'Dual ball', 'MADE IN CHINA', '12V', 'bearing']
# 12 volt
# 4657
# [2024/09/14 14:26:02] ppocr DEBUG: dt_boxes num : 18, elapsed : 0.24441933631896973
# [2024/09/14 14:26:02] ppocr DEBUG: cls num  : 18, elapsed : 0.04520463943481445
# [2024/09/14 14:26:03] ppocr DEBUG: rec_res num  : 18, elapsed : 1.200380802154541
# ['120x120x38mm', 'Noise:42dBA', 'Rated Voltage:24V', 'Life: 35000 hours', 'Rated Current: 0.35A', 'Bearing type: Sleeve Bearing.', 'Speed: 3000RPM', 'Air Pressure (In H2O) :0.39', 'Air flow:125CFM', 'Connecter: XH2.54-2Pin', 'Cable Length: 25cm Or', '9.85 inches', 'Plug', 'Black', 'Red', '40mm', '2.5mm', '5.5mm']
# 24 volt
# 4658
# [2024/09/14 14:26:04] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.263399600982666
# [2024/09/14 14:26:04] ppocr DEBUG: cls num  : 8, elapsed : 0.058492183685302734
# [2024/09/14 14:26:04] ppocr DEBUG: rec_res num  : 8, elapsed : 0.523644208908081
# ['OSUNON', 'PSD1204PKB3-A', '2.B3.R.GN', 'CC2V.32W', 'EP', 'F55150', 'CLX', 'CEcis']
# 2 volt
# 4659
# [2024/09/14 14:26:04] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.2525458335876465
# [2024/09/14 14:26:05] ppocr DEBUG: cls num  : 15, elapsed : 0.0698697566986084
# [2024/09/14 14:26:06] ppocr DEBUG: rec_res num  : 15, elapsed : 1.0487773418426514
# ['Suitable for DDR2 PC2-4200 desktop computers', 'Compatible with for Intel / AMD motherboards', '1GB DDR2 533']
# no
# 4660
# [2024/09/14 14:26:06] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.26291799545288086
# [2024/09/14 14:26:06] ppocr DEBUG: cls num  : 2, elapsed : 0.015947341918945312
# [2024/09/14 14:26:06] ppocr DEBUG: rec_res num  : 2, elapsed : 0.13167262077331543
# ['DC12V', 'DE']
# 12 volt
# 4661
# [2024/09/14 14:26:06] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.3596658706665039
# [2024/09/14 14:26:07] ppocr DEBUG: cls num  : 4, elapsed : 0.04139256477355957
# [2024/09/14 14:26:07] ppocr DEBUG: rec_res num  : 4, elapsed : 0.29739832878112793
# ['MODEL:F2E-150S-230', '230V AC 50/60Hz 0.27/0.24A', '38/36W2580/2650RPM', 'M2E7402-88 moedance protected 2S']
# 230 volt
# 4662
# [2024/09/14 14:26:07] ppocr DEBUG: dt_boxes num : 21, elapsed : 0.25688695907592773
# [2024/09/14 14:26:07] ppocr DEBUG: cls num  : 21, elapsed : 0.06183815002441406
# [2024/09/14 14:26:09] ppocr DEBUG: rec_res num  : 21, elapsed : 1.4261157512664795
# ['Specifications', 'Dimensions:172x151x51 mm 6.77x5.94x2.01in', 'Rated Voltage:110V-120V', 'Frequency:60 Hz', 'Speed:2700RPM', 'Rated Current:0.46A', 'Air Flow:238CFM', 'Noise:50dBA', 'Air Pressure (In H2O):0.82', 'Wathai', '152mm', '152cm', 'rCLL', '{5.98in}', '{5.98in}', '172mm/6.77in', '51mm/2.01in', '5mm*4', '152cm', '{59in}', '162mm/6.38in']
# 110 volt
# 4663
# [2024/09/14 14:26:09] ppocr DEBUG: dt_boxes num : 20, elapsed : 0.35921597480773926
# [2024/09/14 14:26:09] ppocr DEBUG: cls num  : 20, elapsed : 0.08217787742614746
# [2024/09/14 14:26:10] ppocr DEBUG: rec_res num  : 20, elapsed : 0.8254282474517822
# ['PATRiOT', 'NIPER', '8GB', 'NIPER', 'DDR4', 'PC4-170002133MHz', 'DDR4', 'TECHNOLOGY', 'DUAL', 'CHANNEL', 'C4C', 'TECHNOLOGY', '3', 'DESIGNED FOR', 'INTELX99 AND', '100 SERIES', 'PLATFORMS', 'XMP2.0']
# no
# 4664
# [2024/09/14 14:26:10] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.29935693740844727
# [2024/09/14 14:26:10] ppocr DEBUG: cls num  : 5, elapsed : 0.04352164268493652
# [2024/09/14 14:26:11] ppocr DEBUG: rec_res num  : 5, elapsed : 0.27852296829223633
# ['EFC0251S1-C020-S9A', 'DC12V5.28W', 'R01', 'KEL', 'E']
# no
# 4665
# [2024/09/14 14:26:11] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.3953263759613037
# [2024/09/14 14:26:11] ppocr DEBUG: cls num  : 5, elapsed : 0.019739627838134766
# [2024/09/14 14:26:12] ppocr DEBUG: rec_res num  : 5, elapsed : 0.4002690315246582
# ['F120', 'Fluid Dynamic Bearing', '12V 0.25A', '2200RPM', 'MADE IN CHINA']
# 12 volt
# 4666
# [2024/09/14 14:26:12] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.3616752624511719
# [2024/09/14 14:26:12] ppocr DEBUG: cls num  : 6, elapsed : 0.021364688873291016
# [2024/09/14 14:26:12] ppocr DEBUG: rec_res num  : 6, elapsed : 0.3287336826324463
# ['CG5010M05B2-U', '4500RPM/5V/0.13A', '505010mm', 'Dual Ball Bearing', 'CEROHS', 'wwww.coolerguys.com']
# 5 volt
# 4667
# [2024/09/14 14:26:13] ppocr DEBUG: dt_boxes num : 22, elapsed : 0.26480984687805176
# [2024/09/14 14:26:13] ppocr DEBUG: cls num  : 22, elapsed : 0.08344435691833496
# [2024/09/14 14:26:14] ppocr DEBUG: rec_res num  : 22, elapsed : 1.00783371925354
# ['oyemai', '2GB2RX8PC3-12800UCL11', 'CE', 'DDR3UDIMM1.5V', '1138', '2GB', '1600MHZ', 'Made in china', 'WARRANTYVOID IFREMOVED 1807', '..']
# 1.5 volt
# 4668
# [2024/09/14 14:26:14] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.25177979469299316
# [2024/09/14 14:26:14] ppocr DEBUG: cls num  : 10, elapsed : 0.03595304489135742
# [2024/09/14 14:26:15] ppocr DEBUG: rec_res num  : 10, elapsed : 0.49641966819763184
# ['C-184/21-A11', '120V60Hz', '33129026', '5W', '000008483', 'WUDE', 'CHTUU', 'D02']
# no
# 4669
# [2024/09/14 14:26:15] ppocr DEBUG: dt_boxes num : 22, elapsed : 0.2669832706451416
# [2024/09/14 14:26:15] ppocr DEBUG: cls num  : 22, elapsed : 0.05558276176452637
# [2024/09/14 14:26:17] ppocr DEBUG: rec_res num  : 22, elapsed : 1.3928790092468262
# ['SPECIFICATIONS', '70mm/2.76"', '61.5mm/2.42"', 'Fan Size:70 x 70 x 25mm', 'Hole Pitch:61.5 x 61.5mm', 'Bearing : Hydraulic', 'Power:1.6W', 'Rated Voltage: 12V', "61.5mm/2.42'", '70mm/2.76"', 'Rated Current:0.16A', 'Speed: 3000RPM10%', 'Air Flow:38CFM', 'Static Pressure:0.15ln H2O', 'Noise Level:31dBA', 'Material: PBT plastic', 'Rotation: Nonreversible.', 'Connector:3-Pin', '4.3mm/0.17"', 'Rotation', '25mm/0.98"', "250mm/9.84'"]
# 12 volt
# 4670
# [2024/09/14 14:26:17] ppocr DEBUG: dt_boxes num : 21, elapsed : 0.29752469062805176
# [2024/09/14 14:26:17] ppocr DEBUG: cls num  : 21, elapsed : 0.07815027236938477
# [2024/09/14 14:26:19] ppocr DEBUG: rec_res num  : 21, elapsed : 1.7782275676727295
# ['Product Specs:', 'Technology:DDR4 SO-DIMM 260 Pin', 'Density:4x16GB16384MB', 'RoHS:Yes', 'Pin Count:260-pin', 'Op.Temp.:0C to+85C', 'Data Rate:DDR4-2400', 'Speed:PC4-19200', 'CL:17', 'Voltage:1.2V', 'ECC:NonECC', 'Module Ranks:DualRank', 'Low Noise 8-Layer PCB', 'Meets and/or Exceeds Apple/Intel', 'Specifications', 'RoHS Certified', 'Free Installation Videos & Manuals', 'Warranty Safe Upgrade.', 'OwC Memory Lifetime Limited Warranty', 'including the OWC Lifetime Advanced', 'Replacement Program']
# 1.2 volt
# 4671
# [2024/09/14 14:26:19] ppocr DEBUG: dt_boxes num : 33, elapsed : 0.1731123924255371
# [2024/09/14 14:26:19] ppocr DEBUG: cls num  : 33, elapsed : 0.08228874206542969
# [2024/09/14 14:26:22] ppocr DEBUG: rec_res num  : 33, elapsed : 2.7175350189208984
# ['Model:', '(E', 'Model:', '3.8VDC', 'hargeabi', '3.8VDC', '9.epwn Rachargesble', 'usinghe', 'XIE', 'Made in China', 'Battery package might vary', '*This battery has the same dimension as your stock battery.', '*You do not need a special back cover to use it.', '*Brand:Unbranded/Generic', '*Battery Type:Lithium lon', 'Battery Capacity:', 'High quality Li-lon battery', '*Integrated microchip prevents overcharging and lengthens battery life', '*The best replacement spare battery for your phone', '*Our battery is sent out with little or no power, so please charge it for about', '6-12 hours before using', '*The battery operation time depends on conditions such as:Transmitting', 'power level, Signal (distance between the phone and the base station)', 'Network parameters defined by the operator.', 'This Battery could also be charged in the phone directly thru the cell', 'phone charger.']
# no
# 4672
# [2024/09/14 14:26:22] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.41941142082214355
# [2024/09/14 14:26:22] ppocr DEBUG: cls num  : 16, elapsed : 0.07519841194152832
# [2024/09/14 14:26:24] ppocr DEBUG: rec_res num  : 16, elapsed : 1.1749165058135986
# ['3 Speed', 'Controller', 'XLowest noise', 'Perfect for most device', 'S Provide strong airflow', 'KEYNICE', 'Air volume', '48/60/65CFM', '0858', '(L/M/H)', 'Rotating speed', '1500/1800/2000RPM', '(L/M/H)', 'Choose the air volume that best meets your needs']
# no
# 4673
# [2024/09/14 14:26:24] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.25681114196777344
# [2024/09/14 14:26:24] ppocr DEBUG: cls num  : 6, elapsed : 0.02123546600341797
# [2024/09/14 14:26:25] ppocr DEBUG: rec_res num  : 6, elapsed : 0.5437467098236084
# ['Efficient Ice-making Capacity', 'L', '9pcs/7min', '26 lbs/24h', 'Icing Per Cycle', 'Daily Capacity']
# no
# 4674
# [2024/09/14 14:26:25] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.3436312675476074
# [2024/09/14 14:26:25] ppocr DEBUG: cls num  : 6, elapsed : 0.020450115203857422
# [2024/09/14 14:26:25] ppocr DEBUG: rec_res num  : 6, elapsed : 0.2833371162414551
# ['MagLev Fan', 'KDE1205PFB1', 'MS.G', 'DC12V1.4W', 'CH408', 'CE']
# no
# 4675
# [2024/09/14 14:26:26] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.3595457077026367
# [2024/09/14 14:26:26] ppocr DEBUG: cls num  : 12, elapsed : 0.03414106369018555
# [2024/09/14 14:26:26] ppocr DEBUG: rec_res num  : 12, elapsed : 0.5420894622802734
# ['Nidec', 'BETAV', '10', '7X260C1', 'TUV', 'Model M35172-35', '12VDC0.55A', 'DEL1F', 'KG885', 'c9Uus', 'MADE IN CHINA', 'A']
# no
# 4676
# [2024/09/14 14:26:27] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.18075156211853027
# [2024/09/14 14:26:27] ppocr DEBUG: cls num  : 4, elapsed : 0.04080605506896973
# [2024/09/14 14:26:27] ppocr DEBUG: rec_res num  : 4, elapsed : 0.1907670497894287
# ['makita', '18V']
# 18 volt
# 4677
# [2024/09/14 14:26:28] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.38805437088012695
# [2024/09/14 14:26:28] ppocr DEBUG: cls num  : 10, elapsed : 0.03527402877807617
# [2024/09/14 14:26:28] ppocr DEBUG: rec_res num  : 10, elapsed : 0.6519594192504883
# ['WHAT', ' CAN', 'Note:Directly use the product', 'YOU GET ?', 'for your AMD CPU, do not need the', 'Bracket you get along with our package', 'UTDP', '135W', 'ECOLER', 'S90F']
# no
# 4678
# [2024/09/14 14:26:29] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.25638914108276367
# [2024/09/14 14:26:29] ppocr DEBUG: cls num  : 10, elapsed : 0.03501415252685547
# [2024/09/14 14:26:30] ppocr DEBUG: rec_res num  : 10, elapsed : 0.6708710193634033
# ['MOD', 'Z0070HA2BT', 'AXIAL FAN', 'AC220V', '220V 50/60Hz 0.31A 65W2P', 'TAIZHOUXINNI', 'OYOUXIANGONGSI', 'Http:', 'ndq.com', 'HINA']
# 220 volt
# 4679
# [2024/09/14 14:26:30] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.24532508850097656
# [2024/09/14 14:26:30] ppocr DEBUG: cls num  : 11, elapsed : 0.060428619384765625
# [2024/09/14 14:26:31] ppocr DEBUG: rec_res num  : 11, elapsed : 0.509235143661499
# ['NSC', '98', '2']
# no
# 4680
# [2024/09/14 14:26:31] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.3732175827026367
# [2024/09/14 14:26:31] ppocr DEBUG: cls num  : 8, elapsed : 0.05431675910949707
# [2024/09/14 14:26:32] ppocr DEBUG: rec_res num  : 8, elapsed : 0.6493017673492432
# ['COWWOMWLEAHT"', 'ROTARY FAN', 'MODELFP18060EX-S1-B', 'AC220/240V 50/60Hz', '0.35A55W', 'IMPEDANCE PROTECTED', 'MADEIN CHINA', 'CE']
# 240 volt
# 4681
# [2024/09/14 14:26:32] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.3692200183868408
# [2024/09/14 14:26:32] ppocr DEBUG: cls num  : 13, elapsed : 0.0722818374633789
# [2024/09/14 14:26:33] ppocr DEBUG: rec_res num  : 13, elapsed : 0.5488042831420898
# ['invansys', 'M-85', '2188642', '120V', '50/60Hz', 'W1=20W', 'W235W', '026C12 T-2', 'MEXICO', 'FSP', 'R', 'NSF', 'CONPONENT']
# 120 volt
# 4682
# [2024/09/14 14:26:34] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.4121561050415039
# [2024/09/14 14:26:34] ppocr DEBUG: cls num  : 12, elapsed : 0.036428213119506836
# [2024/09/14 14:26:34] ppocr DEBUG: rec_res num  : 12, elapsed : 0.5516986846923828
# ['FirstDo', 'DC BRUSHLESS FD7010H12D', 'DC', '12V', '0.35AMP', 'MadeinCh', 'DCBRUSHLESS FD7010H12D', 'irstDo']
# 12 volt
# 4683
# [2024/09/14 14:26:35] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.26912355422973633
# [2024/09/14 14:26:35] ppocr DEBUG: cls num  : 14, elapsed : 0.050337791442871094
# [2024/09/14 14:26:35] ppocr DEBUG: rec_res num  : 14, elapsed : 0.7045917510986328
# ['3418N', '48VDC51mA2.4W2700r/min', '36-56VDC', 'EP', '+RD-BU', 'ns.Cl.E', 'Hungary V', '49.21', 'yn', 'C', 'CE', 'EAL']
# no
# 4684
# [2024/09/14 14:26:36] ppocr DEBUG: dt_boxes num : 31, elapsed : 0.287233829498291
# [2024/09/14 14:26:36] ppocr DEBUG: cls num  : 31, elapsed : 0.07382512092590332
# [2024/09/14 14:26:38] ppocr DEBUG: rec_res num  : 31, elapsed : 1.720047950744629
# ['1800W Turbo Hot Airflow', 'Cook 30%Faster than Traditional Convection Oven', 'Carbon Heating Tube', 'Powerful Top Fan', 'Diamond Background', 'Preheats in Seconds', '360Hot Air Circulation', 'Reflect Heat Rays to Food', 'TEMP.', 'AIR FRY', 'CHIPS', 'WINGS', 'PIZZA', 'STEAK', 'COOKIES SNACKS', 'VEGGIES', 'COOK', 'CANCEL', 'BAKE', '00h', '00', 'BAGEL', 'ROTATE', 'TIME', 'WARM', 'BROIL', 'PROOF', 'TOAST', 'DEFROST RENEAT', 'REAT', 'START']
# no
# 4685
# [2024/09/14 14:26:38] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.2635660171508789
# [2024/09/14 14:26:38] ppocr DEBUG: cls num  : 15, elapsed : 0.07174944877624512
# [2024/09/14 14:26:39] ppocr DEBUG: rec_res num  : 15, elapsed : 0.8884446620941162
# ['Water proof', 'Dual ball bearing', 'Version', '6Fans', 'Size', '360x240x55mm', 'Bearing', 'Dual ball', 'Current', '0.9A', 'Speed', '2000RPM', 'Air flow', '397.8CFM', 'Package:1pcs 6fans waterproof Fan,can wash it']
# no
# 4686
# [2024/09/14 14:26:39] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.2572965621948242
# [2024/09/14 14:26:40] ppocr DEBUG: cls num  : 4, elapsed : 0.0375826358795166
# [2024/09/14 14:26:40] ppocr DEBUG: rec_res num  : 4, elapsed : 0.37968921661376953
# ['Large Air Volume 6.7CFM', 'High Rotating Speed 7000r/min', '12V-DC', 'RoHS']
# 12 volt
# 4687
# [2024/09/14 14:26:40] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.17343926429748535
# [2024/09/14 14:26:40] ppocr DEBUG: cls num  : 5, elapsed : 0.043243408203125
# [2024/09/14 14:26:41] ppocr DEBUG: rec_res num  : 5, elapsed : 0.24947810173034668
# ['makita', 'NE', 'marita', '8V', '4.0Ar']
# 8 volt
# 4688
# [2024/09/14 14:26:41] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.08736491203308105
# [2024/09/14 14:26:41] ppocr DEBUG: cls num  : 12, elapsed : 0.03301286697387695
# [2024/09/14 14:26:42] ppocr DEBUG: rec_res num  : 12, elapsed : 1.2407143115997314
# ['EASYINSTALLATION', 'Mounts Easily to Any Standard Electrical Box', 'Round:3.5and4"', 'Octagonal:4"', '1250W', '120VOLT', 'HEATING', 'ELEMENT', 'MINIMUM', '15AMP', 'CIRCUIT', 'REQUIRED']
# 120 volt
# 4689
# [2024/09/14 14:26:42] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.2577636241912842
# [2024/09/14 14:26:43] ppocr DEBUG: cls num  : 13, elapsed : 0.07041311264038086
# [2024/09/14 14:26:43] ppocr DEBUG: rec_res num  : 13, elapsed : 0.8019320964813232
# ['4650N-465', '230V-50Hz120mA2600/min', 'ebmpapst', '19W/5.7W', '230V~60Hz 110mA2950/min', '18W/5.4W', 'ZP', 'Ins.CLBIP20', 'ebm-papst.St.Georgen', 'CN(N)', '17.17']
# 230 volt
# 4690
# [2024/09/14 14:26:44] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.40829014778137207
# [2024/09/14 14:26:44] ppocr DEBUG: cls num  : 9, elapsed : 0.060601234436035156
# [2024/09/14 14:26:45] ppocr DEBUG: rec_res num  : 9, elapsed : 1.329134225845337
# ['DIRECT TOUCH BY 4 COPPER POWDER HEAT PIPES', 'Support up to 135W TDP Processor,', 'provide excellent heat dissipation.', 'Anti-oxidation protective layer surface', 'treatment helps prevent corrosion and', 'protect heat pipes', 'TDP', '4x6mm', '135w']
# no
# 4691
# [2024/09/14 14:26:46] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.2697179317474365
# [2024/09/14 14:26:46] ppocr DEBUG: cls num  : 11, elapsed : 0.0605471134185791
# [2024/09/14 14:26:46] ppocr DEBUG: rec_res num  : 11, elapsed : 0.46311235427856445
# ['200W', '24V', 'HEAT', 'FAN', 'OFF HEAT']
# 24 volt
# 4692
# [2024/09/14 14:26:47] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.26997876167297363
# [2024/09/14 14:26:47] ppocr DEBUG: cls num  : 9, elapsed : 0.03679537773132324
# [2024/09/14 14:26:48] ppocr DEBUG: rec_res num  : 9, elapsed : 0.9397008419036865
# ['Product introduction', '1 Cooling fan', 'The cooling fan adopts 5V DC fan,', 'with1200 rpm and2000 rpm to', 'choose from, to meet your different', 'needs.It adopts USB plug,which', 'can be connected to router USB', 'interface or external UsB power', 'supply,The cable length is 60cm.']
# 5 volt
# 4693
# [2024/09/14 14:26:48] ppocr DEBUG: dt_boxes num : 37, elapsed : 0.254302978515625
# [2024/09/14 14:26:48] ppocr DEBUG: cls num  : 37, elapsed : 0.11015176773071289
# [2024/09/14 14:26:51] ppocr DEBUG: rec_res num  : 37, elapsed : 2.4664833545684814
# ['220V FREESTANDING', 'CE MAKER.MACHINE', 'PACKAGE INCLUDE:', 'ICESPOON', 'WATERINLET', '1XICESPOON', 'PIPE', '1XWATEREILTER', '1XINSTRUCTIONMANUAL', 'WATER OUTLET', 'PIPE', '1XCOMMERCIALICEMACHINE', 'CONSIDERATEACCESSORIES', '(WATER INLET/WATER OUTLET/SEALING TAPE)', 'SPECIFICATION', 'Power:', '3800W', 'Supply Voltage:', '220V/60Hz', 'Ice Making Capacity', '2000lbs per 24h Yield', 'Ice storage bin:', '1003lbs/455kg', 'Ice Tray:', '760 pcs19X20X2', 'Features:', 'Automatic Cleaning', 'Refrigerant Type:', 'R404A', 'Ice-making time:', '18-25 min', 'Ice Cube Size:', "0.9x0.9x0.9'", '2000LBS/24H 1003LBSSTORAGE BIN']
# 220 volt
# 4694
# [2024/09/14 14:26:51] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.2651968002319336
# [2024/09/14 14:26:51] ppocr DEBUG: cls num  : 2, elapsed : 0.03726840019226074
# [2024/09/14 14:26:51] ppocr DEBUG: rec_res num  : 2, elapsed : 0.16325163841247559
# ['Chassis cooling fan', '3000 rpm']
# no
# 4695
# [2024/09/14 14:26:51] ppocr DEBUG: dt_boxes num : 29, elapsed : 0.25673961639404297
# [2024/09/14 14:26:52] ppocr DEBUG: cls num  : 29, elapsed : 0.11048078536987305
# [2024/09/14 14:26:53] ppocr DEBUG: rec_res num  : 29, elapsed : 1.8290019035339355
# ['30x30x10mm', 'Specifications:', '240.3mm', '0.940.01inch', 'Dimensions:30x30x10 mm', 'Size in inch:1.18x1.18x0.39 in', 'Speed:10000RPM', 'Airflow:3.95CFM', 'Noise:25.6dBA', '1.180.02inch', '300.5mm', 'GDSTIME', 'BRUSHLESSDC FAN', 'Model:GDT3010S12B', 'Bearing:Sleeve', 'DC12V0.08A', 'MADE IN CHINA', ' RoHs', 'ay', '3.00.3mm', '0.170.01inch', '300.5mm', '1.180.02inch', '5.90.39inch', '15010mm', '0.390.02inch', '100.5mm']
# no
# 4696
# [2024/09/14 14:26:54] ppocr DEBUG: dt_boxes num : 18, elapsed : 0.2767810821533203
# [2024/09/14 14:26:54] ppocr DEBUG: cls num  : 18, elapsed : 0.04712724685668945
# [2024/09/14 14:26:55] ppocr DEBUG: rec_res num  : 18, elapsed : 1.0450961589813232
# ['Product', ' Parameters', '637mm', '58883', '428mm', '354mm', 'Rated voltage/', 'frequency:', '220-240V/50HZ', 'Product size mm:', '354*428*637', 'Rated voltage/', '110-120V/60HZ', 'Carton size (mm:', '409*466*670', 'frequency:', 'Ice production per day:', '50 kg']
# 240 volt
# 4697
# [2024/09/14 14:26:55] ppocr DEBUG: dt_boxes num : 37, elapsed : 0.2891721725463867
# [2024/09/14 14:26:55] ppocr DEBUG: cls num  : 37, elapsed : 0.12391304969787598
# [2024/09/14 14:26:57] ppocr DEBUG: rec_res num  : 37, elapsed : 1.6792171001434326
# ['Rated Power/Frequency', '120V/60Hz', 'Ice Making Current', '1.9A', 'Ice Harvest Current', '2.7A', 'Ice Trays Number', '32 Trays', 'Protection Against', '24.8', 'Electric Shock', 'I Level', '..', '0', '5', 'Tap water', 'InletPressure', '100-800KPa', 'Refrigerant/Weight', 'R134a/0.24lbs', 'Insulation Materials', 'Cyclopentane', '(C5H10', 'Applicable', 'Environmental Level', 'SN/N', '13.8 in', '14.1 in', 'Net Weight', '42.9lbs', 'ACCESSORIES', 'S INCLUDED', 'Drain Hose', 'Inlet Hose', 'Ice Scoop', 'PTFE Tape']
# 120 volt
# 4698
# [2024/09/14 14:26:57] ppocr DEBUG: dt_boxes num : 33, elapsed : 0.2563035488128662
# [2024/09/14 14:26:57] ppocr DEBUG: cls num  : 33, elapsed : 0.1007380485534668
# [2024/09/14 14:26:59] ppocr DEBUG: rec_res num  : 33, elapsed : 1.7747440338134766
# ['240P|N', 'Adopting 240PIN to achieve high anti-interference', 'and antistatic properties']
# no
# 4699
# [2024/09/14 14:27:00] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.24951910972595215
# [2024/09/14 14:27:00] ppocr DEBUG: cls num  : 10, elapsed : 0.05747342109680176
# [2024/09/14 14:27:00] ppocr DEBUG: rec_res num  : 10, elapsed : 0.47658872604370117
# ['1GBDDR266', '184', '900', '00']
# no
# 4700
# [2024/09/14 14:27:01] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.3126950263977051
# [2024/09/14 14:27:01] ppocr DEBUG: cls num  : 5, elapsed : 0.04452109336853027
# [2024/09/14 14:27:01] ppocr DEBUG: rec_res num  : 5, elapsed : 0.39826297760009766
# ['8GB2R4PC3-10600R-09-10-E1-D2', 'Made in China M393B1K70CHD-CH9', '1049']
# no
# 4701
# [2024/09/14 14:27:01] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.25310230255126953
# [2024/09/14 14:27:01] ppocr DEBUG: cls num  : 14, elapsed : 0.06766676902770996
# [2024/09/14 14:27:02] ppocr DEBUG: rec_res num  : 14, elapsed : 0.8818340301513672
# ['DESCRIPTION', 'Size:', '60x60x15mm', 'Voltage/Current : 12V 0.1A', 'Bearing type: Sleeve', 'Speed:3500RPM', 'Noise:26dBA', 'Air flow:18.2CFM', '2.362in', '1.969in', '(60mm)', '(50mm)', '2.362in(60mm)', '0.950in(15mm)']
# 12 volt
# 4702
# [2024/09/14 14:27:03] ppocr DEBUG: dt_boxes num : 31, elapsed : 0.25278615951538086
# [2024/09/14 14:27:03] ppocr DEBUG: cls num  : 31, elapsed : 0.09969353675842285
# [2024/09/14 14:27:04] ppocr DEBUG: rec_res num  : 31, elapsed : 1.339507818222046
# ['1GB DDR2 667']
# no
# 4703
# [2024/09/14 14:27:04] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.26194047927856445
# [2024/09/14 14:27:04] ppocr DEBUG: cls num  : 2, elapsed : 0.0177915096282959
# [2024/09/14 14:27:05] ppocr DEBUG: rec_res num  : 2, elapsed : 0.2607145309448242
# ['PWM intelligent temperature control', '900~2000RPM']
# no
# 4704
# [2024/09/14 14:27:05] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.26464366912841797
# [2024/09/14 14:27:05] ppocr DEBUG: cls num  : 5, elapsed : 0.02028036117553711
# [2024/09/14 14:27:05] ppocr DEBUG: rec_res num  : 5, elapsed : 0.39779019355773926
# ['F120', 'Fluid Dynamic Bearing', '12V0.25A', '2200RPM', 'MADE IN CHINA']
# no
# 4705
# [2024/09/14 14:27:06] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.1722872257232666
# [2024/09/14 14:27:06] ppocr DEBUG: cls num  : 16, elapsed : 0.06734466552734375
# [2024/09/14 14:27:07] ppocr DEBUG: rec_res num  : 16, elapsed : 1.0836129188537598
# ['Adjustable Temperature:l00F to 400F', 'Enjoy a variety of delicous foods &eating healthier', '100F', '400F', '200F', '300F', '350F', '350F', '350F', 'Dehydrate', 'Reheat', 'Air Roast', 'Bake', 'Air Fry', 'Frozen Food', 'Max Crisp']
# no
# 4706
# [2024/09/14 14:27:07] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.2720022201538086
# [2024/09/14 14:27:07] ppocr DEBUG: cls num  : 11, elapsed : 0.04076218605041504
# [2024/09/14 14:27:08] ppocr DEBUG: rec_res num  : 11, elapsed : 0.6560146808624268
# ['16', 'DDR4', 'DOMINATOR', 'CORSAIR', '8GBx2', 'GB', 'PLATINUM RGB', 'CORSAIR', 'DOMINATOR PLATINUM RGB', '16gB']
# no
# 4707
# [2024/09/14 14:27:08] ppocr DEBUG: dt_boxes num : 21, elapsed : 0.31444525718688965
# [2024/09/14 14:27:08] ppocr DEBUG: cls num  : 21, elapsed : 0.08670783042907715
# [2024/09/14 14:27:09] ppocr DEBUG: rec_res num  : 21, elapsed : 1.1445496082305908
# ['NOILNA', 'NARNING!', '34/13', 'R3G180-AD43-71', '1~200-277VAC', 'Pfmin:300Pa', '=BU', 'L', '=BK', 'GND', '=RD', 'CEERL', 'Thermally Protented', 'N=BU', '+10V', 'PE =GNYE', '0-10V/PWM=YE', 'NC=WH1', 'COM=WH2']
# 10 volt
# 4708
# [2024/09/14 14:27:10] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.242645263671875
# [2024/09/14 14:27:10] ppocr DEBUG: cls num  : 4, elapsed : 0.017327308654785156
# [2024/09/14 14:27:10] ppocr DEBUG: rec_res num  : 4, elapsed : 0.21871161460876465
# ['NOISE', 'SPEED (RPM)', '22.8 DB[A]', '1200 RPM =10%']
# no
# 4709
# [2024/09/14 14:27:10] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.2536659240722656
# [2024/09/14 14:27:10] ppocr DEBUG: cls num  : 16, elapsed : 0.04806947708129883
# [2024/09/14 14:27:12] ppocr DEBUG: rec_res num  : 16, elapsed : 1.134448766708374
# ['A-TECHTM', 'PREMIUMMEMORY', '8GB 2666MHz Module', 'For Acer Aspire', 'E5-575-72N3', 'ATTENTION', 'ELECTROSTATIC', 'SENSITIVE DEVICE', '5053462000007', 'A-TECH"', 'LIFETIME WARRANTY']
# no
# 4710
# [2024/09/14 14:27:12] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.34393739700317383
# [2024/09/14 14:27:12] ppocr DEBUG: cls num  : 9, elapsed : 0.054163217544555664
# [2024/09/14 14:27:12] ppocr DEBUG: rec_res num  : 9, elapsed : 0.39978647232055664
# ['Robertshaw', 'IMV-576S-86', 'K-78186-AM', '120V5035', 'COMPONENT', 'Mexica', '161C14']
# no
# 4711
# [2024/09/14 14:27:13] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.30383896827697754
# [2024/09/14 14:27:13] ppocr DEBUG: cls num  : 9, elapsed : 0.032160282135009766
# [2024/09/14 14:27:14] ppocr DEBUG: rec_res num  : 9, elapsed : 0.7050273418426514
# ['PE', 'N', 'L1204', 'UF200BMB38H2C2A', 'AC-380V', '50/60Hz72/82W', '0.75uF/900VAC', 'THERMALPROTECTION', 'CE']
# 380 volt
# 4712
# [2024/09/14 14:27:14] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.17087602615356445
# [2024/09/14 14:27:14] ppocr DEBUG: cls num  : 16, elapsed : 0.06875824928283691
# [2024/09/14 14:27:15] ppocr DEBUG: rec_res num  : 16, elapsed : 0.6613023281097412
# ['REDMOND', 'series multiPRO', 'REDMOND*', 'RMC-M110', 'In', '55MODES', 'AUTOMATIC', 'UNDER PRESSURE', '4.8L1900W', '100RECIPESINCLUDED']
# no
# 4713
# [2024/09/14 14:27:15] ppocr DEBUG: dt_boxes num : 48, elapsed : 0.3962287902832031
# [2024/09/14 14:27:15] ppocr DEBUG: cls num  : 48, elapsed : 0.10344290733337402
# [2024/09/14 14:27:18] ppocr DEBUG: rec_res num  : 48, elapsed : 2.59686017036438
# ['NE', 'Case Fan', 'CN', 'DE', 'Gehauselufter', 'KR', 'ES', 'Ventilador de case', 'JP', '-3', 'RU', 'BeHTnnarop Ana kopnyca', 'Two-Plane', 'Fluid Dynamic', 'Auto', 'Balance', 'Bearing', 'START/STOP', 'A', 'Dimensions', '140x140x25 mm', 'Connector', '4-pin PWM', 'Bearing', 'Fluid Dynamic Bearing', 'Speed', '500-1600RPM', 'Airflow', '96CFM', 'Noise Level', '0-36 dBA', '(with Auto START/STOP)', 'Static Pressure', '2.65mm HO', 'Voltage/Current', '12V/0.23A', 'MTTF', '>150,000 h', 'Manufacturer', '6-Year', 'Warranty', 'IceGALE 140 mm (Gray)', 'Manufactured in China', 'TM and@2020 Iceberg Thermal Inc. All rights reserved', 'Designedin UsA']
# 12 volt
# 4714
# [2024/09/14 14:27:18] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.2872021198272705
# [2024/09/14 14:27:18] ppocr DEBUG: cls num  : 13, elapsed : 0.06741595268249512
# [2024/09/14 14:27:19] ppocr DEBUG: rec_res num  : 13, elapsed : 0.577643632888794
# ['e', 'C', 'O', '.', '890', 'Kllisre']
# no
# 4715
# [2024/09/14 14:27:19] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.33793091773986816
# [2024/09/14 14:27:19] ppocr DEBUG: cls num  : 10, elapsed : 0.03901934623718262
# [2024/09/14 14:27:20] ppocr DEBUG: rec_res num  : 10, elapsed : 0.4181671142578125
# ['7111235', 'NMB-MAT7', 'N', '=', 'MODEL', 'S51', 'RED', 'X']
# no
# 4716
# [2024/09/14 14:27:20] ppocr DEBUG: dt_boxes num : 28, elapsed : 0.2787294387817383
# [2024/09/14 14:27:20] ppocr DEBUG: cls num  : 28, elapsed : 0.08695030212402344
# [2024/09/14 14:27:22] ppocr DEBUG: rec_res num  : 28, elapsed : 1.4598941802978516
# ['hynix', 'hunix', 'DAD032H', 'DArD03H2H', 'H5TQ2G83CFR', 'H5TQ2G83CFR', 's3en', '.D', '4GB 2RX8 PC3-8500S CL7', 'TECMIYO', 'DDR3SODIMM 1066MHZ1.5V', 'JEHT', 'WARRANTY VOID IF REMOVED 1807', '3042', '3CEB', 'DULDQ345H', 'DULDQ345H3', 'NNNIX', 'NNNIX', 'High', 'Improve', 'Support', 'Compatibility', 'System Performance', 'Long-time Running']
# 1.5 volt
# 4717
# [2024/09/14 14:27:22] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.26741671562194824
# [2024/09/14 14:27:22] ppocr DEBUG: cls num  : 6, elapsed : 0.020684003829956055
# [2024/09/14 14:27:23] ppocr DEBUG: rec_res num  : 6, elapsed : 0.9090542793273926
# ['4GB', ' RAM', 'Large memory up to 4GB RAM ensures the stability', 'and smoothness ot data transmission', '4GB 0DR2800']
# no
# 4718
# [2024/09/14 14:27:24] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.25072789192199707
# [2024/09/14 14:27:24] ppocr DEBUG: cls num  : 6, elapsed : 0.02116560935974121
# [2024/09/14 14:27:25] ppocr DEBUG: rec_res num  : 6, elapsed : 0.9817519187927246
# ['16GB PC3-10600/1333MHz ECC RDIMM 2Rx4 1.5V', 'P', '16GB PC3-10600/1333MHz ECC RDIMM2Rx4 1.5V', '16GB PC3-10600/1333MHz ECC RDIMM2Rx4 1.5V']
# 1.5 volt
# 4719
# [2024/09/14 14:27:25] ppocr DEBUG: dt_boxes num : 25, elapsed : 0.21898531913757324
# [2024/09/14 14:27:25] ppocr DEBUG: cls num  : 25, elapsed : 0.08818244934082031
# [2024/09/14 14:27:27] ppocr DEBUG: rec_res num  : 25, elapsed : 1.3981702327728271
# ['488', 'BLACK', '2GBDDR', 'DIAMOND', 'CAUTION', 'COMPATIBILITY CERTIFIED', 'REMOVAL WILL VOID WARRANTY', '00000', 'SANSI', '4H510438C-7C', '3OEHOTSHAX', 'JJJL-JOChUiSnuA', 'JJJL-J8corSnh', 'SNNNUUG', 'SHNSNNG', 'E19', 'SAMSUNG', 'ED']
# no
# 4720
# [2024/09/14 14:27:27] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.27751612663269043
# [2024/09/14 14:27:27] ppocr DEBUG: cls num  : 9, elapsed : 0.06309008598327637
# [2024/09/14 14:27:28] ppocr DEBUG: rec_res num  : 9, elapsed : 1.2306914329528809
# ['PRODUCTSPECIFICATIONS:', ' POWER: 115V/60Hz', 'ICE MAKING CURRENT: 1.7A', 'REFRIGERANT: R600a 0.81Oz/23g', 'ICE HARVEST CURRENT: 2A', 'VIVOHOME', "12.59'", '12.59"', '9.64"']
# 115 volt
# 4721
# [2024/09/14 14:27:29] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.2763807773590088
# [2024/09/14 14:27:29] ppocr DEBUG: cls num  : 13, elapsed : 0.04234623908996582
# [2024/09/14 14:27:30] ppocr DEBUG: rec_res num  : 13, elapsed : 0.9958491325378418
# ['OMINAT', '400', '2', '2,400 RPM', 'OMINATOR', 'DOMINATOR', 'DOMTNATO', '$JEp', 'PWM']
# no
# 4722
# [2024/09/14 14:27:31] ppocr DEBUG: dt_boxes num : 25, elapsed : 0.35607051849365234
# [2024/09/14 14:27:31] ppocr DEBUG: cls num  : 25, elapsed : 0.08083653450012207
# [2024/09/14 14:27:32] ppocr DEBUG: rec_res num  : 25, elapsed : 1.3372750282287598
# ['URAM', 'M470T5663EH0', '2GB 2Rx8 DDR2 667MHz PC2-5300S', 'SODIMM Non-ECC 200 Pin', 'oopo', 'SAMSUNG.', 'URAM', '1470T5663EH0', '2GB 2Rx8 DDR2 667MHz PC2-5300S', '1', 'SODIMM Non-ECC 200 Pin', 'Q00']
# no
# 4723
# [2024/09/14 14:27:32] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.30089378356933594
# [2024/09/14 14:27:33] ppocr DEBUG: cls num  : 10, elapsed : 0.058060407638549805
# [2024/09/14 14:27:33] ppocr DEBUG: rec_res num  : 10, elapsed : 0.9133532047271729
# ['Product Dimensions', 'Ice making capacity110LBs/24H,Operating cycle11-18min', 'Ice storage capacity33LBS', '0.87"', 'ICE SIZE', '0.87"', '0.87', '31 inch', '18 inch', '16inch']
# no
# 4724
# [2024/09/14 14:27:34] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.40403318405151367
# [2024/09/14 14:27:34] ppocr DEBUG: cls num  : 5, elapsed : 0.04091477394104004
# [2024/09/14 14:27:35] ppocr DEBUG: rec_res num  : 5, elapsed : 0.6054258346557617
# ['Specially designed for.', '4068 4082 4092 4074 4274 4268', 'RC model car and other.', 'brushless motors', 'The speed can reach 20000 rpm.']
# no
# 4725
# [2024/09/14 14:27:35] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.2537832260131836
# [2024/09/14 14:27:35] ppocr DEBUG: cls num  : 9, elapsed : 0.05486702919006348
# [2024/09/14 14:27:36] ppocr DEBUG: rec_res num  : 9, elapsed : 0.6424577236175537
# ['EMPTY THE DUSTBIN', 'AUTOMATICALLY', '1 dust bag for 6 weeks of daily use', '3L', 'ROZI', 'O', 'Free Dust Bags x5', '5-Layer HEPA']
# no
# 4726
# [2024/09/14 14:27:36] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.2511868476867676
# [2024/09/14 14:27:36] ppocr DEBUG: cls num  : 9, elapsed : 0.03440451622009277
# [2024/09/14 14:27:37] ppocr DEBUG: rec_res num  : 9, elapsed : 0.7603020668029785
# ['32GBDDR4 PC4-25600/3200MHz 2Rx8 1.2V', '32GB DDR4 PC4-25600/3200MHz 2Rx8 1.2V', '.']
# 1.2 volt
# 4727
# [2024/09/14 14:27:38] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.25580763816833496
# [2024/09/14 14:27:38] ppocr DEBUG: cls num  : 15, elapsed : 0.04685807228088379
# [2024/09/14 14:27:39] ppocr DEBUG: rec_res num  : 15, elapsed : 0.8897888660430908
# ['GPU Cooler Dimension', 'Unit: inch', '7.28', '3.62', 'Model No.CF9225GPU2PACK', 'Model No.CF9225GPU2PACK', 'DC 12V0.32A3000RPM', 'DC 12V 0.32A 3000RPM', 'MADE IN CHINA', 'MADE IN CHINA', '4.92', '1.18', 'Dimension:7.28*4.92*1.18inch']
# 12 volt
# 4728
# [2024/09/14 14:27:39] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.3806178569793701
# [2024/09/14 14:27:39] ppocr DEBUG: cls num  : 13, elapsed : 0.07265233993530273
# [2024/09/14 14:27:40] ppocr DEBUG: rec_res num  : 13, elapsed : 0.7016184329986572
# ['2.1"', 'Tesfish', 'Tesfish LED heatsink', 'DC 12VFC', '1.85"', 'Tesfish', '1.34"', 'Warning!', '2.64"', 'Remove Before', 'COPPER CORE', 'Installation', '3.15"']
# no
# 4729
# [2024/09/14 14:27:40] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.26406097412109375
# [2024/09/14 14:27:40] ppocr DEBUG: cls num  : 10, elapsed : 0.06042790412902832
# [2024/09/14 14:27:41] ppocr DEBUG: rec_res num  : 10, elapsed : 0.49312448501586914
# ['OSUNON', 'PMD2404PBB2-A', '(2).GN', 'DC24V6.0W', 'ZP', 'F93391', 'CLX', 'CE']
# no
# 4730
# [2024/09/14 14:27:41] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.30208778381347656
# [2024/09/14 14:27:41] ppocr DEBUG: cls num  : 11, elapsed : 0.06392359733581543
# [2024/09/14 14:27:42] ppocr DEBUG: rec_res num  : 11, elapsed : 0.8325042724609375
# ['050814', 'COOLING FAN', 'FLIGHT', 'COMAIR R0TRON FE24B3 031163', 'NO', 'II2.20W24V-DC3-1/4 IN', '388001', '01b', 'GMF', '0010']
# 24 volt
# 4731
# [2024/09/14 14:27:43] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.2652425765991211
# [2024/09/14 14:27:43] ppocr DEBUG: cls num  : 3, elapsed : 0.04062390327453613
# [2024/09/14 14:27:43] ppocr DEBUG: rec_res num  : 3, elapsed : 0.19381189346313477
# ['2600RPM', 'HIGH ', 'SPEED']
# no
# 4732
# [2024/09/14 14:27:43] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.28127074241638184
# [2024/09/14 14:27:44] ppocr DEBUG: cls num  : 13, elapsed : 0.0695044994354248
# [2024/09/14 14:27:44] ppocr DEBUG: rec_res num  : 13, elapsed : 0.7462396621704102
# ['DDR400M22G82X1GBUDMMKit', 'ROna', 'WINTEC 3VD4003U9-2GK', '2RX8CL3', 'value', 'WARRANTY VOID IF LABEL REMOVED', '3VD4003U9-2GK', 'DDR400M22GB2X1GBDMMKit', 'WINTEC', '2RX8CL3', 'value', 'WARRANTY VOID IF LABEL REMOVED']
# no
# 4733
# [2024/09/14 14:27:45] ppocr DEBUG: dt_boxes num : 53, elapsed : 0.31424736976623535
# [2024/09/14 14:27:45] ppocr DEBUG: cls num  : 53, elapsed : 0.11586785316467285
# [2024/09/14 14:27:48] ppocr DEBUG: rec_res num  : 53, elapsed : 2.5883994102478027
# ['8', 'GONAFR', '627V', 'GONAFR', '627V', 'GONAFA', 'GONAFR', '00000', '3351-5291', '68UH', 'HOOS', 'SBOM', 'SKhynix', '8GB2Rx8PC4-2.133P-SE0-11', 'CE', 'CHINA HMA41GS6AFR8N-TF N0 AC', '1627', 'O000', '000000', '4G8NAFR', '4G8NAFR', 'THXhhE', 'ynix', '3448H1', 'LHXhnE', 'GONAER', '944XH', 'GONAER', '627V', '627V', '627V', '627V']
# 627 volt
# 4734
# [2024/09/14 14:27:48] ppocr DEBUG: dt_boxes num : 29, elapsed : 0.3572671413421631
# [2024/09/14 14:27:48] ppocr DEBUG: cls num  : 29, elapsed : 0.0720059871673584
# [2024/09/14 14:27:50] ppocr DEBUG: rec_res num  : 29, elapsed : 1.8920402526855469
# ['KBOMPUTER', 'ce', 'Pb', '4GB DDR2 667MHz', 'PC2-5400F240PinCL5', 'ECC Fully Buffered', ')Warranty', 'Lifetime', 'Warranty Void If Removed', 'KBOMPUTER', 'CE', '4GBDDR2 667MHz', 'X', 'PC2-5400F 240 PinCL5', 'ECC Fully Buffered', 'Warranty Void If Removed', 'cee', '4GBDDR2 667MHz', 'PC2-5400F 240 PinCL5', 'ECC Fully Buffered', 'Warranty Void If Removed', 'ce', 'Pb', '4GBDDR2 667MHz', 'PC2-5400F 240 PinCL5', 'ECC Fully Buffered', 'Warranty Void If Removed']
# no
# 4735
# [2024/09/14 14:27:51] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.3796525001525879
# [2024/09/14 14:27:51] ppocr DEBUG: cls num  : 7, elapsed : 0.052327871322631836
# [2024/09/14 14:27:51] ppocr DEBUG: rec_res num  : 7, elapsed : 0.8367061614990234
# ['4GB DDR4PC4-25600/3200MHz 1.2V', '4GB DDR4PC4-25600/3200MHz 1.2V']
# 1.2 volt
# 4736
# [2024/09/14 14:27:52] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.25788426399230957
# [2024/09/14 14:27:52] ppocr DEBUG: cls num  : 13, elapsed : 0.04268050193786621
# [2024/09/14 14:27:53] ppocr DEBUG: rec_res num  : 13, elapsed : 0.8090250492095947
# ['DMS', '8GB DDR3L-1600 PC3L-12800', 'CL11 1.35V 204 PIN SODIMM', '94V-0', '2019-01', 'V-B00', '..', '.0.']
# 1.35 volt
# 4737
# [2024/09/14 14:27:53] ppocr DEBUG: dt_boxes num : 17, elapsed : 0.2749457359313965
# [2024/09/14 14:27:53] ppocr DEBUG: cls num  : 17, elapsed : 0.07971525192260742
# [2024/09/14 14:27:54] ppocr DEBUG: rec_res num  : 17, elapsed : 0.9808146953582764
# ['Pureatic', 'V2S', 'Others', '1500Pa Suction', '130OPa Suction', 'Dual Remote Control', 'App/Remote/None', 'Smart Mapping', 'No Mapping', '65OML Dustbin', '2-3OOML Dustbin', '4400mAh Battery', '300OmAh Battery', 'WiFi Connectivity', 'Bluetooth Connectivity']
# no
# 4738
# [2024/09/14 14:27:55] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.32758116722106934
# [2024/09/14 14:27:55] ppocr DEBUG: cls num  : 10, elapsed : 0.06603479385375977
# [2024/09/14 14:27:55] ppocr DEBUG: rec_res num  : 10, elapsed : 0.6415135860443115
# ['3500Pa MAX Suction', '650ML Waste Container', 'Anti-tangle Roller Brush', 'Double-sided Sweeping Brush', '35001', 'Tile Floor', 'Wooden Floor', 'Cement Floor', 'Fhin Carpets']
# no
# 4739
# [2024/09/14 14:27:56] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.2721548080444336
# [2024/09/14 14:27:56] ppocr DEBUG: cls num  : 9, elapsed : 0.06028938293457031
# [2024/09/14 14:27:57] ppocr DEBUG: rec_res num  : 9, elapsed : 1.2040669918060303
# ['PEREECTMATCIOFASTHIEATDSSPATON', 'Elaborate collocation, 6 heat pipes+Full electro.', 'plating reflow welding process+dual fans, superb.', 'cooling performance.', 'WHITE single tower aluminum fin', 'With TL-B12W', 'High performance fan/2150RPM10%', 'ARES', 'With TF7 thermal paste']
# no
# 4740
# [2024/09/14 14:27:57] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.2627720832824707
# [2024/09/14 14:27:57] ppocr DEBUG: cls num  : 14, elapsed : 0.06816744804382324
# [2024/09/14 14:27:58] ppocr DEBUG: rec_res num  : 14, elapsed : 0.604384183883667
# ['130 Ibs Ice', '24 Hours', '35 Ibs', 'Ice Storage Capacity', '11-20 Mins', 'Gilati', 'Ice Making', '05', '45 Pcs Ice', 'Per Cycle', '0.9 Inch', 'Cube Sizes']
# no
# 4741
# [2024/09/14 14:27:58] ppocr DEBUG: dt_boxes num : 25, elapsed : 0.27492213249206543
# [2024/09/14 14:27:58] ppocr DEBUG: cls num  : 25, elapsed : 0.09822487831115723
# [2024/09/14 14:28:00] ppocr DEBUG: rec_res num  : 25, elapsed : 1.583012580871582
# ['Energy Saving Design', '120w low power sonic ice maker consumes lower electricity;', 'Energy and cost efficient.', 'O', '*', '0', 'O', 'O', 'O', 'Large', 'Small', 'Clean', 'Efficient cooling function', '9pcs of ice', 'produced in 7-10 Mins', 'Indication reminder', 'PP Materia', '19mm ternary foaming layer', 'Long ice storage time', 'Thickened stainless steel panel']
# no
# 4742
# [2024/09/14 14:28:00] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.2646651268005371
# [2024/09/14 14:28:00] ppocr DEBUG: cls num  : 11, elapsed : 0.06000542640686035
# [2024/09/14 14:28:01] ppocr DEBUG: rec_res num  : 11, elapsed : 1.002767562866211
# ['16GB DDR4 PC4-21300/2666MHz 2Rx8 1.2V', 'ce o', 'Removal will void Warranty.', '.']
# 1.2 volt
# 4743
# [2024/09/14 14:28:02] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.25776100158691406
# [2024/09/14 14:28:02] ppocr DEBUG: cls num  : 15, elapsed : 0.07042646408081055
# [2024/09/14 14:28:03] ppocr DEBUG: rec_res num  : 15, elapsed : 0.5729291439056396
# ['18', 'mins', 'Ready in', 'ON/OFF', '18min', '88', '261b', 'Daily', 'Production', '3.3lb', 'Ice', 'Storage', '2.7L', 'Reservoir', 'Capacity']
# no
# 4744
# [2024/09/14 14:28:03] ppocr DEBUG: dt_boxes num : 34, elapsed : 0.2598414421081543
# [2024/09/14 14:28:03] ppocr DEBUG: cls num  : 34, elapsed : 0.1018369197845459
# [2024/09/14 14:28:04] ppocr DEBUG: rec_res num  : 34, elapsed : 1.1849565505981445
# ['-12800-2025', '1600', 'Void If Removed', 'DDR3', 'china', '.5V-PC3-', '8GB', 'Warranty', 'Assy', '00', '8', '94V-09', 'Lic.we', 'O', 'O']
# 5 volt
# 4745
# [2024/09/14 14:28:05] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.2554891109466553
# [2024/09/14 14:28:05] ppocr DEBUG: cls num  : 5, elapsed : 0.022254467010498047
# [2024/09/14 14:28:05] ppocr DEBUG: rec_res num  : 5, elapsed : 0.8520181179046631
# ['UP T0 1.500 RPM', 'per fan while in operation', 'PRECISE PWM CONTROL', 'Adjust fan speeds to accommodate the demands of your', 'system, minimizing noise or maximizing airflow.']
# no
# 4746
# [2024/09/14 14:28:06] ppocr DEBUG: dt_boxes num : 27, elapsed : 0.26770520210266113
# [2024/09/14 14:28:06] ppocr DEBUG: cls num  : 27, elapsed : 0.07205557823181152
# [2024/09/14 14:28:07] ppocr DEBUG: rec_res num  : 27, elapsed : 1.558903694152832
# ['SPECIFICATIONS', 'MODELT', 'SXD12025M1B', 'BEARINGS T Dual Ball', 'FANS SIZE |120X120X25mm', 'SPEED  3050RPM', 'VOLTAGE 1 12V DC', 'AIRFLOW L106CFM', 'CURRENT T 0.50A', 'NO|SE 43.2dBA', '4.72"', '25mm0.98"', '120mm', '120mm', 'SXDOOL', 'BRUSHLESS DC FAN', 'MODEL:SXD12025M1B', 'DC12V0.50A', 'RoHS CIP68', '4.72', '105mm', '4.13"', 'Tach Sensor FG', '105mm', 'Positive+', '4.13"', 'Ground-']
# 12 volt
# 4747
# [2024/09/14 14:28:08] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.254347562789917
# [2024/09/14 14:28:08] ppocr DEBUG: cls num  : 12, elapsed : 0.032540082931518555
# [2024/09/14 14:28:09] ppocr DEBUG: rec_res num  : 12, elapsed : 1.1532039642333984
# ['32.8cm', 'J25MM', '20MM', '35.8cm', '24.2cm', 'Weight:7.8kg', 'Power:105 w', 'Ice storage capacity:0.7kg/70ice cubes', 'Single ice release:9 ice cubes', 'Water intake mode:manual addition of water', 'Ice shape:round Amount of water added:22L', 'Working hours:6 to13 minutes']
# no
# 4748
# [2024/09/14 14:28:09] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.2572488784790039
# [2024/09/14 14:28:09] ppocr DEBUG: cls num  : 13, elapsed : 0.07014822959899902
# [2024/09/14 14:28:10] ppocr DEBUG: rec_res num  : 13, elapsed : 0.7007155418395996
# ['Nugget Ice Maker', 'Smart Ice Bin Detection', 'ICEFULL', 'DAILY', 'ICE', 'RESERVOIR', '40 lb.', '3 lb.', '3 qt.', 'INDICATOR', 'PRODUCTION', 'STORAGE', 'CAPACITY']
# no
# 4749
# [2024/09/14 14:28:10] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.25293803215026855
# [2024/09/14 14:28:11] ppocr DEBUG: cls num  : 9, elapsed : 0.05614161491394043
# [2024/09/14 14:28:11] ppocr DEBUG: rec_res num  : 9, elapsed : 0.3651754856109619
# ['Ice Maker', 'ZONOO', 'Caution', '55KG', '120V']
# 120 volt
# 4750
# [2024/09/14 14:28:11] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.25217652320861816
# [2024/09/14 14:28:11] ppocr DEBUG: cls num  : 7, elapsed : 0.03128838539123535
# [2024/09/14 14:28:12] ppocr DEBUG: rec_res num  : 7, elapsed : 0.6789979934692383
# ['Self Emptying Robot Vacuum', '- Free Your Hands.', '2.5L Large Capacity Self-Empyting Dustbin', '- 30 days of dirt and debris.', '2.51', 'neobot']
# no
# 4751
# [2024/09/14 14:28:12] ppocr DEBUG: dt_boxes num : 27, elapsed : 0.39061522483825684
# [2024/09/14 14:28:13] ppocr DEBUG: cls num  : 27, elapsed : 0.06952118873596191
# [2024/09/14 14:28:14] ppocr DEBUG: rec_res num  : 27, elapsed : 1.6245057582855225
# ['Product parameter', '328mm', '358mm', '242mm', 'Ice shape', 'Bullet cylindrical ice', 'Ice storage', '0.7KG/70pcs', 'Voltage', '220V-240V/50Hz', '24H output', '12KG', 'Power', '95W', 'Net weight', '7.8KG', 'Ice block size', '26*32mm', 'Water intake', 'Manual', 'Single ice time', '8minutes', 'Machine size', '242*358*328mm', 'Single ice out', '9 pcs', 'Note: The lower the water & ambient temperature,The greater the amount of ice produced']
# 220 volt
# 4752
# [2024/09/14 14:28:15] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.4019181728363037
# [2024/09/14 14:28:15] ppocr DEBUG: cls num  : 10, elapsed : 0.0590815544128418
# [2024/09/14 14:28:16] ppocr DEBUG: rec_res num  : 10, elapsed : 0.8812978267669678
# ['2GB DDR3 PC3-8500/1066MHz 2Rx8 1.5V', 'Ce', 'Removal will void Warranty']
# 1.5 volt
# 4753
# [2024/09/14 14:28:16] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.26180267333984375
# [2024/09/14 14:28:16] ppocr DEBUG: cls num  : 14, elapsed : 0.06831479072570801
# [2024/09/14 14:28:18] ppocr DEBUG: rec_res num  : 14, elapsed : 1.4887926578521729
# ['Product parameter', 'Note: Manual measurement may have errors', '23.62 inches', '18.89 inches', '15.55 inches', 'Model: BY-Z45FN', 'Daily ice production: 99lbs', 'Capacity: 13lbs', 'Number of ice trays: 45PCS', 'Ice shape: square', 'Rated voltage/power: 110 Ford/495 Watt', 'Product dimensions: 18.89 x 15.55 x 23.62 inches', 'Way of adding water: Barreled water or automatically,filter offered', 'Note:The test data of the labo']
# no
# 4754
# [2024/09/14 14:28:18] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.3556637763977051
# [2024/09/14 14:28:18] ppocr DEBUG: cls num  : 8, elapsed : 0.03895974159240723
# [2024/09/14 14:28:19] ppocr DEBUG: rec_res num  : 8, elapsed : 0.4920766353607178
# ['parts-quick', '1GB PC2700SDOR-333YA']
# no
# 4755
# [2024/09/14 14:28:19] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.2736654281616211
# [2024/09/14 14:28:19] ppocr DEBUG: cls num  : 3, elapsed : 0.042685747146606445
# [2024/09/14 14:28:19] ppocr DEBUG: rec_res num  : 3, elapsed : 0.43358421325683594
# ['ft for 1/10 1/8 1/12 RC ESC engine']
# no
# 4756
# [2024/09/14 14:28:20] ppocr DEBUG: dt_boxes num : 19, elapsed : 0.25566625595092773
# [2024/09/14 14:28:20] ppocr DEBUG: cls num  : 19, elapsed : 0.07645320892333984
# [2024/09/14 14:28:21] ppocr DEBUG: rec_res num  : 19, elapsed : 0.9233405590057373
# ['120mm', ' x3', '2200RPM', 'MAX', 'RAZ=R', 'RAZER', 'KUNALCHROMA', 'ARGB HYDRAULIC CASE FANS', 'QUIET.POWERFULE', 'ARG8FANS', 'CONNECTUPTO', 'CRAZERA', '8FANSAT ONCE', 'PWM FAN AND ARG8E', 'CONTROLLERSUPPORTE', 'RGB', 'ER', 'ROMA', 'RGB']
# no
# 4757
# [2024/09/14 14:28:21] ppocr DEBUG: dt_boxes num : 30, elapsed : 0.2607693672180176
# [2024/09/14 14:28:21] ppocr DEBUG: cls num  : 30, elapsed : 0.06808257102966309
# [2024/09/14 14:28:23] ppocr DEBUG: rec_res num  : 30, elapsed : 1.7642111778259277
# ['Product Parameters', 'Brand', 'Top Pure', 'Filter Life', '9 months/2000 gallons', 'Flow Rate', '0.528 gpm (1.89 Ipm)', 'Capacity', '2000 gallons (7570 Liters)', 'Filter Material', 'Coconut Shell Carbon', 'Min.33F (0.6C)', 'Temperature', 'Max.100 F (38C)', 'Working', 'Min.30 psi (207 kPa)', 'Pressure', 'Max.120 psi (822 kPa)', 'ICE2', 'F2WC911', 'W10565350', 'W10480323', 'Compatible', 'MIM1554ZRS0', 'Models', 'MIM1555ZRSO', 'IM158XYCX0', 'JIM158XYCX1', 'JIM158XYRSO', 'JIM158XYRS1']
# no
# 4758
# [2024/09/14 14:28:23] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.2683703899383545
# [2024/09/14 14:28:24] ppocr DEBUG: cls num  : 14, elapsed : 0.06855964660644531
# [2024/09/14 14:28:25] ppocr DEBUG: rec_res num  : 14, elapsed : 1.1720638275146484
# ['82GB PC3-8500/1066MHz ECC RDIMM 4Rx4 1.5V', 'CD', '32GB PC3-8500/1066MHz ECC RDIMM 4Rx4 1.5V', 'ACCH', '32GB PC3-8500/1066MHz ECC RDIMM 4Rx4 1.5V', 'CE', '32GBPC3-8500/1066MHz ECC RDIMM4Rx41.5V', 'CE']
# 1.5 volt
# 4759
# [2024/09/14 14:28:25] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.25525665283203125
# [2024/09/14 14:28:25] ppocr DEBUG: cls num  : 13, elapsed : 0.06668519973754883
# [2024/09/14 14:28:26] ppocr DEBUG: rec_res num  : 13, elapsed : 1.0014781951904297
# ['Robot Vacuum and Mopping 2 in 1', '230MI Electric Water Tank + 2 Levels Water Adjustment', 'Clean Up To 1290Sqft', '230ML', '2Levels', '1290sqft', 'Water Tank', 'Water Flow', 'Cleaning Area', 'Integrated Mopping System', 'Max Suction Power']
# no
# 4760
# [2024/09/14 14:28:27] ppocr DEBUG: dt_boxes num : 21, elapsed : 0.2927227020263672
# [2024/09/14 14:28:27] ppocr DEBUG: cls num  : 21, elapsed : 0.0776972770690918
# [2024/09/14 14:28:28] ppocr DEBUG: rec_res num  : 21, elapsed : 1.2207303047180176
# ['265 Ib. DAILYICE OUTPUT', '126pc.', '55 lb.', '750W', 'Storage', 'Ice Yield', 'Rated Power', '1.The water used must be', 'Warm Tips', 'filtered water', 'Caution', '2.The pump must be cleaned', 'termly', '1.Plcase take all the accessories out before running the', 'che manal.New machine aeed to stand 24h berore', 'WILPREP', '2.Please clcan the inside walls of the water box and ice', 'runniag.)', 'clement termly to', 'ould with detergent termly.and replace the filter', '0022']
# no
# 4761
# [2024/09/14 14:28:28] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.2565329074859619
# [2024/09/14 14:28:28] ppocr DEBUG: cls num  : 16, elapsed : 0.07181906700134277
# [2024/09/14 14:28:29] ppocr DEBUG: rec_res num  : 16, elapsed : 0.8967077732086182
# ['ADJOSTABLE ICE CUBE THICKNESS', 'Different Thickness for Different Usage', '>>>>', '>>>>', 'Size', '33 LBSIce', 'Purified', 'Water', '0.9"*0.9"*0.9"', 'Basket Capacity', 'Thin Ice', 'Medium Ice', 'Thick Ice', 'Drinking', 'Seafood', 'Beer']
# no
# 4762
# [2024/09/14 14:28:30] ppocr DEBUG: dt_boxes num : 39, elapsed : 0.28449583053588867
# [2024/09/14 14:28:30] ppocr DEBUG: cls num  : 39, elapsed : 0.10787439346313477
# [2024/09/14 14:28:32] ppocr DEBUG: rec_res num  : 39, elapsed : 1.832242727279663
# ...
# 1.5 volt
# 5469
# [2024/09/14 14:49:46] ppocr DEBUG: dt_boxes num : 113, elapsed : 0.40464353561401367
# [2024/09/14 14:49:46] ppocr DEBUG: cls num  : 113, elapsed : 0.2494363784790039
# [2024/09/14 14:49:50] ppocr DEBUG: rec_res num  : 113, elapsed : 4.215442180633545
# ['B', 'w89', 'B', 'B', 'C', 'R', 'NEMIX', 'NEMIX', 'RAM', 'RAMi', '64GB (8 x 8GB)', '64GB (8 x 8GB)', 'DDR4 3200MHz PC4-25600', 'DDR4 3200MHz PC4-25600', 'ECC UDIMM', 'ECC UDIMM', 'ATTENTION', 'ATEFENTION', 'SENSITIVE DEVICE', 'NSITIVE DEVICE', 'ME25600-818', 'ME25600-818', 'B', 'LIFETIME WARRANTY', 'LIFETIME WARRANTY', 'B']
# no
# 5470
# [2024/09/14 14:49:50] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.2411785125732422
# [2024/09/14 14:49:50] ppocr DEBUG: cls num  : 13, elapsed : 0.06597518920898438
# [2024/09/14 14:49:51] ppocr DEBUG: rec_res num  : 13, elapsed : 0.7435925006866455
# ['32GB PC4-17000 ECC REG 2RX4 CL151.2v', '32GB PC4-17000 ECC REG 2RX4 CL151.2v', '32GB PC4-17000ECC REG 2RX4 CL151.2v', '32GB PC4-17000 ECC REG 2RX4CL151.2v', '37072016']
# 151.2 volt
# 5471
# [2024/09/14 14:49:52] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.3325510025024414
# [2024/09/14 14:49:52] ppocr DEBUG: cls num  : 6, elapsed : 0.020855426788330078
# [2024/09/14 14:49:52] ppocr DEBUG: rec_res num  : 6, elapsed : 0.2847177982330322
# ['2510S', 'DC', 'BRUSHLESS DC FAN', '12V', '0.10A', 'MADEIN CHINA']
# 12 volt
# 5472
# [2024/09/14 14:49:53] ppocr DEBUG: dt_boxes num : 53, elapsed : 0.39084362983703613
# [2024/09/14 14:49:53] ppocr DEBUG: cls num  : 53, elapsed : 0.1394960880279541
# [2024/09/14 14:49:55] ppocr DEBUG: rec_res num  : 53, elapsed : 2.599055290222168
# ['0H98hCC73', 'SEC 049 HCH9', 'SEC 049 HCH9', 'K482608', 'K48260', 'WARRANTY VOID IF REMOVED1312', '01129686', 'SEC-049', 'ELJJ40', '4GB2Rx8PC3-10600S-9-CH0-CH9', 'NOK', '4GB.DDR3.1333MHz.SO-nIMM', '9hrr73', 'SEC 049', 'K482G0', 'SEIFELDEN', 'Seifelden Rans', '5HCH 6n0 33S', 'ELJJ48GHO', 'SEC 049 HCH9', 'SEC-049 HCH9', 'K482608', 'WARRANTY VOID IF REMOVED 131201129686', '6h0-33S', 'ELJJ46', '4GB2Rx8PC3-10600S-9-CH0-CH9', 'NOK', '4GB,DDR3.1333MHz.SO-DIMM CA', '73', 'SEC-049', 'K482G0', 'Seifelden Rans', 'SEIFELDEN', 'H 6n0 33S', 'ELJJ48GHU']
# no
# 5473
# [2024/09/14 14:49:56] ppocr DEBUG: dt_boxes num : 77, elapsed : 0.43805742263793945
# [2024/09/14 14:49:56] ppocr DEBUG: cls num  : 77, elapsed : 0.19127202033996582
# [2024/09/14 14:50:00] ppocr DEBUG: rec_res num  : 77, elapsed : 3.6714441776275635
# ['C', 'Cireo.', 'GBPC3-10600/1333', '0.', '.', 'ATECH A-TECHA-TECH', 'SERVERMEMORY', 'A-TECHA-TECHA-TECH', 'ATECHA-TECHA-TECH', '16GB KIT (4x4GB)', 'SERVERMEN', 'DDR3 1333MHz PC3-10600', '16GB KIT (4)', 'ECC-RDIMM 1Rx4 1.5V', 'DDR3 1333MHz P', 'ECC-RDIMM 1', 'ELETE', 'ATTENTION', 'LIFETIME', 'SEN', 'WARRANTY', 'LIFETIME', 'an0.', '.', '0.']
# 1.5 volt
# 5474
# [2024/09/14 14:50:00] ppocr DEBUG: dt_boxes num : 41, elapsed : 0.3150179386138916
# [2024/09/14 14:50:00] ppocr DEBUG: cls num  : 41, elapsed : 0.09802389144897461
# [2024/09/14 14:50:02] ppocr DEBUG: rec_res num  : 41, elapsed : 1.8537030220031738
# ['SKhynix', '32GB4Rx4PC4-2133P-LD0-10', 'CO', '32GB PC4-17000 LRDIMM4RX4CL151.2v', 'CE', 'KOREA', '1536', 'AM51LF44G72HY-QQ', '68012017', 'adamanta', 'Neee', 'Made in Taiwan', 'Warranty Void if Removed', 'SKhynix', '32GB4Rx4 PC4-2133P-LD0-10', '32GB PC4-17000LRDIMM4RX4CL15 1.2v', 'KOREA', '1536', 'CE', 'AM51LF44G72HY-QQ', '68012017', 'adamanta', 'Made in Taiwan', 'Warranty Void if Removed', 'Pb']
# 151.2 volt
# 5475
# [2024/09/14 14:50:03] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.27329087257385254
# [2024/09/14 14:50:03] ppocr DEBUG: cls num  : 9, elapsed : 0.057389259338378906
# [2024/09/14 14:50:03] ppocr DEBUG: rec_res num  : 9, elapsed : 0.6412560939788818
# ['8GB PC417000SODIMM2RX16CL15 1.2v', 'AM52SS21G64-QQ', '77082017', 'adamanta', 'Made in Taiwan', 'Warranty Void if Removed']
# 1.2 volt
# 5476
# [2024/09/14 14:50:04] ppocr DEBUG: dt_boxes num : 159, elapsed : 0.3631412982940674
# [2024/09/14 14:50:04] ppocr DEBUG: cls num  : 159, elapsed : 0.3304462432861328
# [2024/09/14 14:50:14] ppocr DEBUG: rec_res num  : 159, elapsed : 9.973989725112915
# ['* MAXX ICE', 'Project Name:', 'Location:', 'Item #:', 'Qty:', ' The Legacy Companies', '3355 Enterprise Avenue, Suite 160, Fort Lauderdale, FL 33331', 'Model:', 'Sales: (954) 202-7419  Sales@TheLegacyCompanies.com', 'Tech Service: (877) 368-2797 - Service@MaxxHelp.com', 'www.MaxximumFoodService.com', "30' MODULAR ICE MAKERS", ' MIM370N', 'Model:', 'MIM50ON', 'MIM650N', 'MIM1000N', 'MIM370NH', 'MIM500NH', 'MIM650NH', 'MIM1000NH', 'International Model:Add-50(220V/50Hz/1Ph) or-60 220V/60H7/1Ph', '30 wide Maxx Ice air cooled modular ice makers will produce 300 to 1000 pounds of ice', ' per day (under the right conditions) depending on the model. Stainless steel exterior', 'construction provides durability lo a unit that is low-maintenance and easy to clean.', 'Vertical cvaporator and proven icc making technology provide ycars of reliablc ice', 'MAXX ICE', 'production. These models can be stacked for even more ice production, if needed. Comes', 'with a hinged front panel for easy servicing. New Solid state controls display ice maker', 'status and alerts the operator when the machine requires servicing.', 'ICE PRODUCTION', 'NOLE', 'MIM', 'SOUM', 'GMONH', 'MIM', 'Temp', '70F', '50F', '373bs', '361lbs', '521 Ibs', '513 1bs', '650lbs', '6451bs', '937 Ibs', '10051bs', '21C', '(10C)', '169kg)', '164kg', '236kg', '233kg', '295kg', '245kg', '(456kg)', '90F', '70F', '288bs', '2851bs', '381b', '(32C)', '(21C)', '131kg)', '129kg)', '173kg', '175kg', '245kg', '(246kg)', '(350kg', '351kg)', 'Storage Bin is Not Included. Various Maxx Ice storage bins are available to suit individual', ' needs (certain applications may require an adapter plate). Gravity Drain is Required', 'OPERATING REQUIREMENTS', 'Ambient Temp Range', '45 to 99F (7 to 37C)', 'Water Temp Range', 'Water UJsage 100lbs (45.4kg) of Icc', '13.12 Gallons (49.7 L)', 'Water Supply Line Connection', "3/8'FPT", 'Water Pressure Range', 'Min PSI', '15', 'Max PSI', '80 above 80 requires a rcgulator', 'Min Bar', '1.0', 'Max Bar', '5.5', 'Energy Consumption kWh/100 Ib (45.4 kg) 90F(32\'C) Air / 70"F(21\'C) Water', 'MIM370N/NH', '6.1 kWh/100 lb', 'MIM500N/NII:', '4.9 kWh/100 lb', 'N Models', 'MIM650N/NH:', '5.6 kWh/100 lb', 'Shown on MIB430N Bin', 'NH Models', 'Full Slab Cube', 'MIM1000N/NH:', '5.1 kWh/100 1b', ' Bin sold separately', 'Half Slab Cube', '7/8x7/8x7/8', '7/8x7/8x3/8', 'FEATURES and CONSTRUCTION', 'Exterior Material: Corrosion resistant stainless steel and plastic', 'REFRIGERANT', 'Air Cooled Compressor', '1.27/32mm', 'Automatic Cleaning Cycle', 'CFC & HCFC free R-404A', 'Hinged panel for easy service', 'New user-friendly controls', 'STANDARD MODEL ELECTRIC SERVICE NEEDS', 'Screen displays ice maker status', 'MIM370N/NH', '115V/60Hz/1 Ph (NEMA 5-15P)', 'Power for unit also illuminates LED light in storage bin (MIB430N)', 'MIM500/NH', 'For more icc making production, ice makers are stackablc. Must purchasc optional', '115V/60Hz/1 Ph (NEMA 5-15P)', 'NEMA5-15P', 'adapter', 'MIM650/NH', '230V/60Hz/1 Ph (Hard Wired)', 'MIM370N/NH and MIM500N/NH come with a NEMA 5-15 Cord Set for plug-and-', 'MIM1000N/NH', '230V/60Hz/1 Ph (Hard Wired)', 'For MIM370N/NH,', 'play operation', 'MIM500N/NH', '(220V/50-60Hz/1ph available as an option)', '* Water Filter Recommended to provide a higher quality ice cube', 'Models', 'Maxx Ice WARRANTY (USA/CANADA)', 'Three (3) years parts', 'Three (3) years on-site labor', 'Certified to', 'Certified to', 'DOE 2018', 'Five (5 years compressor (part only', 'ANSINSF 012', 'ANSIUL563', 'Compliant', 'Administered by The Legacy Companies, 877.368.2797', 'Due to periodic changes in designs, methods, procedures, policies and regulations, the specifications contained in this sheet are subject to change without notice.While we exercise good', 'faith efforts to provide information that is accurale, we are not responsible for errors or omissions in information provided or conclusions reached as a result of using the speciications.', 'By using thc information provided, the u ...
# 220 volt
# 5477
# [2024/09/14 14:50:15] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.35106682777404785
# [2024/09/14 14:50:15] ppocr DEBUG: cls num  : 6, elapsed : 0.04951763153076172
# [2024/09/14 14:50:15] ppocr DEBUG: rec_res num  : 6, elapsed : 0.3248732089996338
# ['BRUSHLESS DC FAN', 'DC12V', 'MADE IN CHINA', '2510S', 'CE', '0.10A']
# 12 volt
# 5478
# [2024/09/14 14:50:16] ppocr DEBUG: dt_boxes num : 131, elapsed : 0.2837049961090088
# [2024/09/14 14:50:16] ppocr DEBUG: cls num  : 131, elapsed : 0.3041691780090332
# [2024/09/14 14:50:22] ppocr DEBUG: rec_res num  : 131, elapsed : 6.524561882019043
# ['F.', 'GEKSOGAI1', '4302939', 'SEC149HCH9', 'SEC 149 HCH9', 'K4B2G0846D', 'K482608460', 'K4B2608460', 'NEMIX', 'NEMIX RAM', '8GB 204-Pin SODIMM 1.35V', 'RAM', 'DDR3L-1333 PC3L-10600', '189239', 'LIFETIME WARRANTY', ' WARRANTY VOID IF REMOVED', '0918092810', '825-HCH9', 'GED250C6', 'GEEIA3ES', 'bee', '-', 'GEKSO6A3', '4302939', 'SEC149HCH9', 'SEC 149 HCH9', 'K4B2G0846D', 'K482608460', 'K4B2608460', 'NEMIX', 'NEMIX RAM', 'L', '8GB 204-Pin SODIMM 1.35V', 'RAM', 'DDR3L-1333 PC3L-10600', '.', 'LE', 'LIFETIME WARRANTY', ' WARRANTY VOID IF REMOVEDE', 'K482G08460', '225 HCH9', 'GED250C6', '33E01339', '07', 'SEC149HCH9', 'GEK506AT', 'SEC 149 HCH9', 'K4B2G0846D', 'K482608460', 'K482608460', 'K4B2608460', 'NEMIX', 'NEMIX RAM', 'F', '8GB 204-Pin SODIMM 1.35V', 'RAM', 'DDR3L-1333 PC3L-10600', 'LIFETIME WARRANTY', 'WARRANTY VOID IF REMOVED', 'K482G08460', 'ES', 'SEC825 HCH9', 'GED250C6C', '33801339', '7017', 'SEC149HCH9', 'SEC 149 HCH9', '1302939', 'K482G08460', 'K482G08460', 'EL', 'K482608460', '6H3H 6133S', 'NEMIX', 'NEMIX RAM', '8GB 204-Pin SODIMM 1.35V', 'RAM', 'DDR3L-1333 PC3L-10600', 'LIFETIME WARRANTY', ' WARRANTY VOID IF REMOVED', 'K482608460', 'ES', 'SEC22S HCH9', 'GED250C6', '3361339']
# 1.35 volt
# 5479
# [2024/09/14 14:50:23] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.34995102882385254
# [2024/09/14 14:50:23] ppocr DEBUG: cls num  : 8, elapsed : 0.06299328804016113
# [2024/09/14 14:50:23] ppocr DEBUG: rec_res num  : 8, elapsed : 0.3973982334136963
# ['DSUNON', 'PMB1138..GA', 'DC12V9.8W', 'H7125J', 'ZP', 'CLX', 'CEis']
# no
# 5480
# [2024/09/14 14:50:24] ppocr DEBUG: dt_boxes num : 38, elapsed : 0.4281923770904541
# [2024/09/14 14:50:24] ppocr DEBUG: cls num  : 38, elapsed : 0.10805702209472656
# [2024/09/14 14:50:26] ppocr DEBUG: rec_res num  : 38, elapsed : 2.015634775161743
# ['5YE77', 'PBB', '8GB PC3-12800 SODIMM 2RX8 CL11 1.5v', 'a', 'adamanta', 'VPBB', '8GBPC3-12800SODIMM 2RX8CL11 1.5v', 'a', 'AM42SE21G64-MS', '30060414', 'adamanta', 'Made in Taiwan', 'Warranty Void if Removed', '88d', '8GB PC3-12800SODIMM 2RX8 CL11 1.5v', 'adamanta', '/PBB', '8GB PC3-12800SODIMM 2RX8 CL11 1.5v', 'a', 'AM42SE21G64-MS', '30060414', 'adamanta', 'Made in Taiwan', 'Warranty Void If Removed', 'P']
# 1.5 volt
# 5481
# [2024/09/14 14:50:27] ppocr DEBUG: dt_boxes num : 48, elapsed : 0.4162275791168213
# [2024/09/14 14:50:27] ppocr DEBUG: cls num  : 48, elapsed : 0.10538148880004883
# [2024/09/14 14:50:29] ppocr DEBUG: rec_res num  : 48, elapsed : 2.533424139022827
# ['8888', 'ATECH ATECHA-TECH', 'ATECH', 'ATEC', 'DESKTOPMEMORY', 'A-TECH A-TECHA-TECH', '16GB KIT (4x4GB)', 'DESKTOPME', 'DDR42400MHz PC4-19200', '16GB KIT (4)', '1Rx8 1.2V DIMM Non-ECC', 'DDR4 2400MHz P', '1Rx8 1.2V DIMM', 'ATTENTION', 'EELEE', 'LIFETIME', 'WARRANTY', 'LIFETIME', 'C']
# 1.2 volt
# 5482
# [2024/09/14 14:50:30] ppocr DEBUG: dt_boxes num : 28, elapsed : 0.3003382682800293
# [2024/09/14 14:50:30] ppocr DEBUG: cls num  : 28, elapsed : 0.1025233268737793
# [2024/09/14 14:50:32] ppocr DEBUG: rec_res num  : 28, elapsed : 1.6059057712554932
# ['TECH', '32GB PC3L-12800/1600MHz ECC LRDIMM 4I', '-TCCH', 'A-TECH A-TECH A-TECH', 'ATECH', 'X', 'SERVER MEMORY', 'ATEC', 'A-TECH A-TECH A-TECH', 'A-TECH A-TECH A-TECH', 'l28GB KIT (4x32GB)', 'SERVER MEN', 'DDR3L 1600MHz PC3L-12800L', '128GB KIT (4)', 'ECC-LRDIMM 4Rx4 1.35V', 'DDR3L 1600MHz Pg', 'ECC-LRDIMM 4F', 'ATTENTION', 'ATTE', 'ELECT', 'IME', 'WARRANTY', 'LIFETIME']
# 1.35 volt
# 5483
# [2024/09/14 14:50:32] ppocr DEBUG: dt_boxes num : 35, elapsed : 0.37078404426574707
# [2024/09/14 14:50:32] ppocr DEBUG: cls num  : 35, elapsed : 0.10646748542785645
# [2024/09/14 14:50:35] ppocr DEBUG: rec_res num  : 35, elapsed : 2.529634475708008
# ['BYD-J-210608-00530', 'Robot', '2008-2021 iRobot Corporation8 Crosby Dr.Bedford,MA 01730 USA', 'iRobot Corporation.Clean Base is a trademark of iRobot Corporation.', '100-240V~50/60Hz0.56A31W', 'Home Base', 'Model:ADI-N1', 'Manufacturer Huizhou BYD Electronic Co.Ltd.', 'Designed in the USA,Assembled in China', 'CAUTION/ATTENTION', 'Risk of electric shock/Risque de Choc Electriques', 'Dry Location Only/Endroit Sec Seulement', 'Only charge one of the following iRobot batteries:max 14.8V, max', 'DO NOT OPEN/Ne chargez que les batteries iRobot: max 14,8 V,', "Li-on max 3300mAh.D'autres types de piles peuvent eclater et provoquer", 'des blessures.NE PAS OUVRIR', 'EU Importer/Importateur:', 'UK Importer/Importateur:', '3', 'iRobot Corporation', 'iRobot Corporation', '11 Avenue Albert Einstein,', '111 Buckingham Palace Road', '69100 Villeurbanne,France', 'London,SW1w OSR', 'United Kingdom', 'AD', 'Class2', 'Power Unit', '2) this', 'ptany', 'TUV', 'U.S.Patent Nos.www.irobot.com/patents', 'SUD', 'Other Patents Pending']
# 240 volt
# 5484
# [2024/09/14 14:50:35] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.3139004707336426
# [2024/09/14 14:50:35] ppocr DEBUG: cls num  : 16, elapsed : 0.07266950607299805
# [2024/09/14 14:50:36] ppocr DEBUG: rec_res num  : 16, elapsed : 0.9791622161865234
# ['16GB PC3-10600 ECC REG 2RX4 CL11 1.35v', 'AM41RF22G72-LR', '30032016', 'damanta', 'Made in Taiwan', 'Warranty Void If Removed', 'Pb', '16GB PC3-10600ECC REG2RX4CL11 1.35v', 'AM41RF22G72-LR', 'adamanta', '30032016', 'Made in Taiwan', 'Warranty Void If Removed', 'P']
# 1.35 volt
# 5485
# [2024/09/14 14:50:37] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.18099164962768555
# [2024/09/14 14:50:37] ppocr DEBUG: cls num  : 14, elapsed : 0.07310032844543457
# [2024/09/14 14:50:37] ppocr DEBUG: rec_res num  : 14, elapsed : 0.7758622169494629
# ['32GBPC3-12800LRDIMM4RX4CL111.35v', 'AM41LF44G72-MR', '30121913', 'adamanta', 'Warranty Void If Removed', 'LR DIMM', '32GBPC3-12800LRDIMM4RX4 CL111.35y', 'AM41LF44G72-MR', '30121913', 'adamanta', 'Removed', 'LR DIMM']
# 111.35 volt
# 5486
# [2024/09/14 14:50:38] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.3693349361419678
# [2024/09/14 14:50:38] ppocr DEBUG: cls num  : 16, elapsed : 0.04739046096801758
# [2024/09/14 14:50:39] ppocr DEBUG: rec_res num  : 16, elapsed : 0.9431378841400146
# ['DRDATARAN', '0843890', 'WARRANTY VOID IF REMOVED', 'JFFERE', 'DRDATARAM', '0843889', 'WARRANTY VOID IF REMOVED', '4GB,DDR32Rx8.PC3-10600,1333MHzECC UNBUFFERED', '0843888', 'DRDATARAM', 'WARRANTY VOID IF REMCVED', '4GBDDR3.2Rx8,PC3-106001333MHzECC UNBUFFERED', '0843887', 'DRDATARAM', 'VOID IF REMOVED', '4GB.DDR3.2Rx8.PC3-10600.1333MHz.ECC JNBUFFERED']
# no
# 5487
# [2024/09/14 14:50:39] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.3598341941833496
# [2024/09/14 14:50:40] ppocr DEBUG: cls num  : 6, elapsed : 0.022561311721801758
# [2024/09/14 14:50:40] ppocr DEBUG: rec_res num  : 6, elapsed : 0.5971319675445557
# ['noctua', 'SSO2 SYSTEM WITH METAL BEARING SHELL', 'NF-A205V', '800RPMDC5V0.85W0.17A', 'CE RoHS']
# 205 volt
# 5488
# [2024/09/14 14:50:41] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.2514209747314453
# [2024/09/14 14:50:41] ppocr DEBUG: cls num  : 23, elapsed : 0.09633922576904297
# [2024/09/14 14:50:42] ppocr DEBUG: rec_res num  : 23, elapsed : 1.5756032466888428
# ['32GBPC4-19200 ECC REG 2RX4CL171.2v', 'MTA36ASF4G72PZ-2G3A1IK', 'EECE', 'AM51RF24G72-RQ', '76062016', 'adamanta', '32GB2RX4 PC4-2400T-RBB-10', 'Made in Taiwan', ' If Removed', 'Product of CHINA', 'DPAFPP3002', 'P', '32GBPC4-19200 ECC REG2RX4 CL17 1.2v', '9', 'AM51RF24G72-RQ', '76082016', 'TA36ASF4G72PZ-2G3A11K', 'adamanta', '32GB2RX4 PC4-2400T-RBB-10', 'Made in Taiwan', 'Warranty Void if Removed', 'Product of CHINA', 'DPAFPP3002']
# 171.2 volt
