# %%
# !pip install paddlepaddle paddleocr
# !pip install gdown
# Out:
# Collecting paddlepaddle
#   Downloading paddlepaddle-2.6.2-cp310-cp310-manylinux1_x86_64.whl.metadata (8.6 kB)
# Collecting paddleocr
#   Downloading paddleocr-2.8.1-py3-none-any.whl.metadata (19 kB)
# Collecting httpx (from paddlepaddle)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (10.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (5.1.1)
# Collecting astor (from paddlepaddle)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (3.3.0)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (3.20.3)
# Collecting shapely (from paddleocr)
#   Downloading shapely-2.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from paddleocr) (0.23.2)
# Collecting imgaug (from paddleocr)
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting pyclipper (from paddleocr)
#   Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (9.0 kB)
# Collecting lmdb (from paddleocr)
#   Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.66.5)
# Collecting rapidfuzz (from paddleocr)
#   Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.10.0.84)
# Collecting opencv-contrib-python (from paddleocr)
#   Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting cython (from paddleocr)
#   Downloading Cython-3.0.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from paddleocr) (6.0.2)
# Collecting python-docx (from paddleocr)
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.53.1)
# Collecting fire>=0.3.0 (from paddleocr)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from paddleocr) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr) (2.4.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->paddleocr) (2.6)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (2024.8.30)
# Collecting httpcore==1.* (from httpx->paddlepaddle)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (3.8)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->paddlepaddle)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (1.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (3.7.1)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (2.35.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (3.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (2024.8.30)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (0.4)
# Collecting lxml>=3.1.0 (from python-docx->paddleocr)
#   Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->paddleocr) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (2.0.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->paddlepaddle) (1.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (2.9.0.post0)
# Downloading paddlepaddle-2.6.2-cp310-cp310-manylinux1_x86_64.whl (126.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 MB 8.5 MB/s eta 0:00:00
# Downloading paddleocr-2.8.1-py3-none-any.whl (407 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.5/407.5 kB 15.9 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading Cython-3.0.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 80.8 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.6 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.8 MB/s eta 0:00:00
# Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 36.0 MB/s eta 0:00:00
# Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 15.0 MB/s eta 0:00:00
# Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (68.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 MB 15.5 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (908 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 27.9 MB/s eta 0:00:00
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 11.4 MB/s eta 0:00:00
# Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 67.4 MB/s eta 0:00:00
# Downloading shapely-2.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 64.1 MB/s eta 0:00:00
# Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 4.0 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 42.0 kB/s eta 0:00:00
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=34764b9d8b7322d1b8d111afc3a179ea9709bb69fcda34ebe2e710db1387b042
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# Installing collected packages: pyclipper, lmdb, shapely, rapidfuzz, opencv-contrib-python, lxml, h11, fire, cython, astor, python-docx, httpcore, imgaug, httpx, paddlepaddle, paddleocr
# Successfully installed astor-0.8.1 cython-3.0.11 fire-0.6.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 imgaug-0.4.0 lmdb-1.5.1 lxml-5.3.0 opencv-contrib-python-4.10.0.84 paddleocr-2.8.1 paddlepaddle-2.6.2 pyclipper-1.3.0.post5 python-docx-1.1.2 rapidfuzz-3.9.7 shapely-2.0.6
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %% [markdown]
# **1.** **Libraries and Imports**
# <br/>
# This section imports various libraries that enable functionality such as downloading images, performing OCR (Optical Character Recognition), manipulating images, working with data in CSV format, and downloading files from Google Drive. These libraries are essential for processing images, extracting relevant text, and handling the results.

# %%
import pandas as pd
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
from paddleocr import PaddleOCR
import numpy as np
from docx import Document
from docx.shared import Inches
from PIL import Image
import io
import gdown
import re
import os

# %% [markdown]
# **2. PaddleOCR Initialization**
# <br/>
# PaddleOCR is initialized in this section. The model is set to use angle classification and English language recognition. The use_gpu parameter is set to True, allowing the model to leverage GPU acceleration if available, improving the speed of OCR.

# %%
ocr = PaddleOCR(use_angle_cls=True, lang='en', use_gpu=True)
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100%|██████████| 4.00M/4.00M [00:15<00:00, 256kiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to /root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer/en_PP-OCRv4_rec_infer.tar
# 100%|██████████| 10.2M/10.2M [00:16<00:00, 613kiB/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2.19M/2.19M [00:15<00:00, 141kiB/s]
# [2024/09/14 14:44:23] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')

# %%
os.makedirs("dataset")

# %% [markdown]
# **3. Google Drive File Downloading**
# <br />
# The script uses the gdown library to download a CSV file from Google Drive. The file contains data, which is later used for prediction. The file is downloaded and saved locally with a specified name.

# %%
maxweight = '1z3iLz2R7-gGvRWwJ2rMWtDBq1A4hozfK'
weight = '1F7emO5QqHPNwFlZhz7nvq3kH3L9h2r1G'
url = f'https://drive.google.com/uc?id={weight}'
output_file = 'downloaded_file.csv'
gdown.download(url, output_file, quiet=False)

print(f"File downloaded and saved as {output_file}")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1F7emO5QqHPNwFlZhz7nvq3kH3L9h2r1G
# To: /content/downloaded_file.csv
# 100%|██████████| 1.71M/1.71M [00:00<00:00, 195MB/s]
# File downloaded and saved as downloaded_file.csv

# %% [markdown]
# **4. Image Downloading and Text Extraction**
# <br/>
# A function is defined to download an image from a URL using the requests library. The image is processed using PaddleOCR to extract text, which is then stored in a list. This extracted text will be processed in later steps to identify weight values and units.

# %%
def download_image(url):
    response = requests.get(url)
    image = Image.open(BytesIO(response.content))
    return image

# %% [markdown]
# **5. Text Parsing for Weight Units**
# <br />
# Using regular expressions, the script identifies weight-related measurements from the extracted text. It looks for patterns of numerical values followed by units such as grams, kilograms, pounds, ounces, etc. These values are then parsed and prepared for further processing.

# %%
def get_text(url):
    res = []
    image = download_image(url)
    image_np = np.array(image)
    result = ocr.ocr(image_np, cls=True)
    # print(result)
    try:
        for i in result:
            for j in i:
                for k in j:
                    if isinstance(k[0], str):
                        res.append(k[0])
    except Exception as e:
        print(f"An error occurred: {e}")
    print(res)
    return res

# %%
def find_value(text_list):
    text = ' '.join(text_list).lower()
    pattern = r'(\d+(\.\d+)?)\s*(weight|g|kg|grams?|gram|kilogram|kilograms?|pound|pounds?|gm|gms|oz|milligram|mg|milligrams?|mgs|grains?|gr|grs|ounce|ounces?|lbs?)\b'
    matches = re.findall(pattern, text, re.IGNORECASE)
    return [match[0] + ' ' + map_to_standard_unit(match[2]).strip() for match in matches]

# %% [markdown]
# **6. Mapping to Standard Units**
# <br/>
# This section maps various weight units (like grams, kilograms, pounds, etc.) to standardized units using a dictionary. This mapping ensures that all weight units are consistent and comparable, regardless of how they are presented in the text.

# %%
from collections import Counter

def map_to_standard_unit(weight_unit):
    unit_mappings = {
        "mg": "milligram",
        "milligram": "milligram",
        "mgs": "milligram",
        "g": "gram",
        "gram": "gram",
        "grams": "gram",
        "gm": "gram",
        "gms": "gram",
        "kg": "kilogram",
        "kilogram": "kilogram",
        "kilograms": "kilogram",
        "pound": "pound",
        "pounds": "pound",
        "lb": "pound",
        "lbs": "pound",
        "ibs": "pound",
        "oz": "ounce",
        "ounce": "ounce",
        "ounces": "ounce",
        "gr": "gram",
        "grs": "gram",
        "grain": "gram",
        "grains": "gram",
        "ton": "ton",
        "tons": "ton"
    }
    return unit_mappings.get(weight_unit.lower(), None)

def predictor1(url, entity):
  try:
    if entity != "item_weight":
        return ""
    result = get_text(url)
    values = find_value(result)
    print(values)
    d = {val.split()[0] : val.split()[1] for val in values}
    if not values:
        return ""
    weights = [weight.split()[0] for weight in values]
    if not weights:
        print("no")
        return ""
    weight_counts = Counter(weights)
    most_common_weight, count = weight_counts.most_common(1)[0]
    most_common_weights = [weight for weight, freq in weight_counts.items() if freq == count]
    if len(most_common_weights) > 1:
        result_weight = max(most_common_weights)
    else:
        result_weight = most_common_weight

    print(result_weight + " " + d[result_weight])
    return result_weight + " " + d[result_weight]
  except Exception as e:
    print(f"An error occurred: {e}")
    return ""

# %% [markdown]
# **7. Prediction Logic**
# <br/>
# The core function of this script predicts the weight of an item from an image based on the extracted text. It processes the extracted text, maps the weight units, and finds the most frequent or largest weight value from the identified results. This predicted value is then returned.
#
# **8. Main Program Execution**
# <br/>
# In the main execution block:
#
# A dataset is loaded from the previously downloaded CSV file.
# The script processes the dataset, downloading images from URLs provided in the CSV file, extracting text, and predicting weight values.
# The results are then saved in a new CSV file, where the predicted weights are added as a column.
# <br/>
# **9. File Processing and Output**
# <br/>
# Finally, the processed data, including the predicted weights, is saved to a CSV file in the dataset folder. The output file contains both the index and the predicted values, allowing easy access to the results for further analysis or validation.

# %%
import os
import random
import pandas as pd

i = 0

def predictor(url, category_id, entity_name):
    '''
    Call your model/approach here
    '''
    global i
    i += 1
    print(i)
    #TODO
    return predictor1(url, entity_name)

if __name__ == "__main__":
    DATASET_FOLDER = '/content/dataset'
    header = pd.read_csv('downloaded_file.csv', nrows=1).columns

    test = pd.read_csv('downloaded_file.csv', skiprows=14999, header=None, names=header)

    test['prediction'] = test.apply(
        lambda row: predictor(row['image_link'], row['group_id'], row['entity_name']), axis=1)

    output_filename = os.path.join(DATASET_FOLDER, 'test_out.csv')
    test[['index', 'prediction']].to_csv(output_filename, index=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# [2024/09/14 17:44:09] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.07991433143615723
# [2024/09/14 17:44:09] ppocr DEBUG: cls num  : 9, elapsed : 0.05376863479614258
# [2024/09/14 17:44:10] ppocr DEBUG: rec_res num  : 9, elapsed : 0.5022926330566406
# ['Durable zipper', 'Internal pouch', 'for Makeup brush', 'Lipstick', 'Eyebrow pencil', 'Mascara', '12oz Cotton Canvas', 'Jacquard pattern']
# ['12 ounce']
# 12 ounce
# 6475
# [2024/09/14 17:44:10] ppocr DEBUG: dt_boxes num : 21, elapsed : 0.08192157745361328
# [2024/09/14 17:44:10] ppocr DEBUG: cls num  : 21, elapsed : 0.05424976348876953
# [2024/09/14 17:44:11] ppocr DEBUG: rec_res num  : 21, elapsed : 1.2962355613708496
# ['Directions', ' FOR USE', ' Administer 1g per 5kg body weight Orally', 'Give twice daily ( AM & PM )', 'INGREDIENTS', 'PRODUCTFACTS', 'Calcium Carbonate', '250 mg', 'Chitosan', '200 mg', 'Inactive Ingredients:Lactose, Hydrolyzed Soy Protein.', 'Aluminum', 'Hydroxide', 'FREE', "Deggy Natura's", 'TRUKITIN', 'NUTRITIOAALSUDDEMENT', '200m', 'Dggy Naturas']
# ['1 gram', '5 kilogram', '250 milligram', '200 milligram']
# 5 kilogram
# 6476
# [2024/09/14 17:44:12] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.343275785446167
# [2024/09/14 17:44:12] ppocr DEBUG: cls num  : 1, elapsed : 0.03463172912597656
# [2024/09/14 17:44:12] ppocr DEBUG: rec_res num  : 1, elapsed : 0.2904934883117676
# ['Lightweight and portable, foldable design, only 238g, convenient for traveling']
# ['238 gram']
# 238 gram
# 6477
# [2024/09/14 17:44:12] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.08413410186767578
# [2024/09/14 17:44:12] ppocr DEBUG: cls num  : 13, elapsed : 0.0452730655670166
# [2024/09/14 17:44:13] ppocr DEBUG: rec_res num  : 13, elapsed : 0.5795502662658691
# ['12PACK', 'UV', 'RED LIGHT', 'HIGH PRESSURE', 'STANDARD', 'PROTECTION', 'TREATMENT', 'UV TANNING', 'UV TANNING', 'PROTECTION', 'PROTECTION', 'PROTECTION']
# []
# 6478
# [2024/09/14 17:44:13] ppocr DEBUG: dt_boxes num : 35, elapsed : 0.08768296241760254
# [2024/09/14 17:44:13] ppocr DEBUG: cls num  : 35, elapsed : 0.10092043876647949
# [2024/09/14 17:44:15] ppocr DEBUG: rec_res num  : 35, elapsed : 1.4553806781768799
# ['What Size and Weight', 'imoh+yhyyn', 'WeightChart', 'SINGLESIZE BED', 'TWIN SIZE BED', 'Quility Weighted Blankets are designed', 'to weigh10-14%ofyour body weight.', 'BLANKETWEIGHT', 'BODY WEIGHT', '05lbs', '40-70lbs', 'UPTO', '41X60', '48X72', 'KIDS', '07lbs', '70-90lbs', '10lbs', '90-120lbs', '12lbs', 'FULL/QUEEN SIZE BED', '110-140lbs', 'KING SIZE BED', '15lbs', '110-140bs', '20lbs', '140-190lbs', '251bs', '190-240bs', 'L', '30lbs', '240-280lbs', '60X80', '86X92']
# ['05 pound', '70 pound', '07 pound', '90 pound', '10 pound', '120 pound', '12 pound', '140 pound', '15 pound', '20 pound', '190 pound', '30 pound', '280 pound']
# 90 pound
# 6479
# [2024/09/14 17:44:15] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.08051252365112305
# [2024/09/14 17:44:15] ppocr DEBUG: cls num  : 7, elapsed : 0.029569387435913086
# [2024/09/14 17:44:15] ppocr DEBUG: rec_res num  : 7, elapsed : 0.36554455757141113
# ['OMEN 15-dh1070wm', '10.35H', '14.17W', '10.35D', '5.12', '0.79H']
# []
# 6480
# [2024/09/14 17:44:15] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.08433675765991211
# [2024/09/14 17:44:15] ppocr DEBUG: cls num  : 9, elapsed : 0.0560908317565918
# [2024/09/14 17:44:16] ppocr DEBUG: rec_res num  : 9, elapsed : 0.5594899654388428
# ['FAST EVEN HEATING', 'DOUBLE SIDE BAKING', 'Make Your Breakfast Tastier', '750', 'W']
# []
# 6481
# [2024/09/14 17:44:16] ppocr DEBUG: dt_boxes num : 21, elapsed : 0.13360285758972168
# [2024/09/14 17:44:16] ppocr DEBUG: cls num  : 21, elapsed : 0.053879737854003906
# [2024/09/14 17:44:17] ppocr DEBUG: rec_res num  : 21, elapsed : 1.0410001277923584
# ['Ingredients:100%Pineapple', 'Nutrition Fact', '1Pack (20g)', 'NUTRITION FACTS (As per200gn)', 'Caleries keal', '46', '369.52', 'cal Fa gn', 'Gary Fiber tgn', 'BLQ', 'rbelodratesrgeo', '89.13', '41.52', '3.25', 'INGREDEENT', 'Pincapple-20om', 'ydre wth Aps 200 sWaM', 'acist ib ope', 'ATOHINO:', 'FG.BATE:', 'NETWEIGHT']
# ['20 gram']
# 20 gram
# 6482
# [2024/09/14 17:44:18] ppocr DEBUG: dt_boxes num : 19, elapsed : 0.0931539535522461
# [2024/09/14 17:44:18] ppocr DEBUG: cls num  : 19, elapsed : 0.05927228927612305
# [2024/09/14 17:44:19] ppocr DEBUG: rec_res num  : 19, elapsed : 1.6046879291534424
# ['Accsoon CineEye', '1080PWifi HDMI Transmitter', 'The accsoon cineEye WIFI HDMI Transmitter is designed to', 'Utilize your smartphone and tablet as a portable wireless', 'Moniter for your camera .connect to 4 devices simuitaneously', 'Up to 4 hpurs on a sigle charge.Mobile monitoring is more', 'Convenient than ever before.', 'um', 'Up to100m1080P', 'Upto4-hour', 'run time', 'IOS/Android', 'Video transmission', 'Cross platfom', 'ery Jow latency', 'Lut loading', 'only 175g']
# ['175 gram']
# 175 gram
# 6483
# [2024/09/14 17:44:20] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.35077905654907227
# [2024/09/14 17:44:20] ppocr DEBUG: cls num  : 8, elapsed : 0.05440926551818848
# [2024/09/14 17:44:20] ppocr DEBUG: rec_res num  : 8, elapsed : 0.36266064643859863
# ['PYLE', '250W', 'PEAKPOWER', '6%2WAY', 'SPEAKER SYSTEM', 'IN-CEILING', 'PDIC60', '4-8OHM']
# []
# 6484
# [2024/09/14 17:44:20] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.08249187469482422
# [2024/09/14 17:44:20] ppocr DEBUG: cls num  : 14, elapsed : 0.04165768623352051
# [2024/09/14 17:44:21] ppocr DEBUG: rec_res num  : 14, elapsed : 0.7643678188323975
# ['LIMITEDEDITION', 'SALTED CARAMEL', 'BROWNIE', 'ARTIFICIALLY', 'FLAVORED', 'OREO', 'SALT', 'PER2COOOES', 'SUT APPEARS WNEN OPENED', 'CHOCOLATESANOWICH COOKIES', 'NETWT12.20Z (345g)']
# ['345 gram']
# 345 gram
# 6485
# [2024/09/14 17:44:21] ppocr DEBUG: dt_boxes num : 18, elapsed : 0.07997751235961914
# [2024/09/14 17:44:21] ppocr DEBUG: cls num  : 18, elapsed : 0.04034018516540527
# [2024/09/14 17:44:22] ppocr DEBUG: rec_res num  : 18, elapsed : 0.7339098453521729
# ['LIMITEDD', 'EDITION', 'ARTIFICIALLY', 'MAPLECREME', 'FLAVORED', 'OREO', 'OREO:', 'GOLDEN COOKIE', 'R2COCKE', 'NETWT12.207 (345', 'SANDWICH COOKIES', 'SUT APPEARS WMEN OPENED']
# []
# 6486
# [2024/09/14 17:44:22] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.14841294288635254
# [2024/09/14 17:44:22] ppocr DEBUG: cls num  : 12, elapsed : 0.03153514862060547
# [2024/09/14 17:44:23] ppocr DEBUG: rec_res num  : 12, elapsed : 0.5934431552886963
# ['DONA JIMENA', 'ASSECHAUSARISPDESCANS', 'DE ESPANA', 'PANISI', 'ite d b Confilei', 'CONT.NET350g', 'NETWE12.30Z', 'DONAJIMENA', 'DE', 'ESPANA']
# ['350 gram']
# 350 gram
# 6487
# [2024/09/14 17:44:23] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.16035676002502441
# [2024/09/14 17:44:23] ppocr DEBUG: cls num  : 7, elapsed : 0.05146956443786621
# [2024/09/14 17:44:23] ppocr DEBUG: rec_res num  : 7, elapsed : 0.48598146438598633
# ['ORGANIC', 'Skillet', 'M', 'Grill It', 'SEASONING & RUB', 'Nebraska Prime Steak', 'NET WT3.50Z(99g)']
# ['99 gram']
# 99 gram
# 6488
# [2024/09/14 17:44:24] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.3207530975341797
# [2024/09/14 17:44:24] ppocr DEBUG: cls num  : 2, elapsed : 0.037268638610839844
# [2024/09/14 17:44:24] ppocr DEBUG: rec_res num  : 2, elapsed : 0.24465727806091309
# ['15W Fast Charging Wireless', '50% Charged']
# []
# 6489
# [2024/09/14 17:44:24] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.24377226829528809
# [2024/09/14 17:44:24] ppocr DEBUG: cls num  : 6, elapsed : 0.019692659378051758
# [2024/09/14 17:44:26] ppocr DEBUG: rec_res num  : 6, elapsed : 1.0396466255187988
# ['Manual focus and fully.', 'multi-coated optics', 'You can easily adjust to the best focal length.', 'accordingto the actual observation distance.', 'Dimension ofObjectives: 35mm', 'Exit pupil distance:20mm']
# []
# 6490
# [2024/09/14 17:44:26] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.1317431926727295
# [2024/09/14 17:44:26] ppocr DEBUG: cls num  : 11, elapsed : 0.05715775489807129
# [2024/09/14 17:44:26] ppocr DEBUG: rec_res num  : 11, elapsed : 0.705303430557251
# ['BanLang', 'Vien gia vi', 'PHOGA', 'PREPARATION POUR "PHO"', '"PHO"SOUPSEASONING', 'SERVING SUGGESTION', 'KL TINH/POID NET/NET WT.', '2.640Z', '(75g)', 'TVIEN']
# ['75 gram']
# 75 gram
# 6491
# [2024/09/14 17:44:27] ppocr DEBUG: dt_boxes num : 24, elapsed : 0.16998600959777832
# [2024/09/14 17:44:27] ppocr DEBUG: cls num  : 24, elapsed : 0.05729532241821289
# [2024/09/14 17:44:28] ppocr DEBUG: rec_res num  : 24, elapsed : 1.326784372329712
# ['aioTechUSA', 'BioTechUSA', 'BioTechUSA', 'BioTechUSA', 'doedts', 'BioTechUSA', 'BioTechUSA', 'aioTechUSA', 'BioTechUSA', "Boedt's", 'CA', 'TICA', 'itl', 'BioTechUSA', 'COLLAGEN', 'FOOD SUPPLEMENT DRINK POWDER', 'B', 'BLACKRASPBERRYFLAVOURED', 'UER', 'FREE', 'LACTOSE', '13GCOLLAGEN', 'PER SERVING', '300 groms [20 servings]']
# []
# 6492
# [2024/09/14 17:44:28] ppocr DEBUG: dt_boxes num : 24, elapsed : 0.08478951454162598
# [2024/09/14 17:44:28] ppocr DEBUG: cls num  : 24, elapsed : 0.05094623565673828
# [2024/09/14 17:44:30] ppocr DEBUG: rec_res num  : 24, elapsed : 1.6349515914916992
# ['HORSES&', 'PONIES', 'This pack', 'Pellets', 'will tast', '1 horse', 'aproximately', 'ORIGINAL', '72 days', 'A daily supplement', 'Tasty supplement', 'tomaintain', '100% natural herbs', 'intestinalhealth', 'Intestinal control', 'Made from natural active ingredients', 'Veterinarian formulated', 'BiomeXity Original can be given all year round', 'for hassle free intestinal health support', 'Net Contents:4lb/1.814kg ', 'Use daily.Suitable for horses and ponies.', 'Natural herbal pellets to maintain gut vitality']
# ['4 pound', '1.814 kilogram']
# 4 pound
# 6493
# [2024/09/14 17:44:30] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.2693474292755127
# [2024/09/14 17:44:30] ppocr DEBUG: cls num  : 9, elapsed : 0.0625913143157959
# [2024/09/14 17:44:31] ppocr DEBUG: rec_res num  : 9, elapsed : 0.4773447513580322
# ['12.5kg/27.5lb', '10kg/22lb', '7.5kg/16.5lb', '5kg/11lb', '2.5kg/5.5lb', '17cm/6.7', 'AWARNING', '40cm/15.7"', '9']
# ['12.5 kilogram', '27.5 pound', '10 kilogram', '22 pound', '7.5 kilogram', '16.5 pound', '5 kilogram', '11 pound', '2.5 kilogram', '5.5 pound']
# 7.5 kilogram
# 6494
# [2024/09/14 17:44:31] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.16755390167236328
# [2024/09/14 17:44:31] ppocr DEBUG: cls num  : 16, elapsed : 0.07131338119506836
# [2024/09/14 17:44:32] ppocr DEBUG: rec_res num  : 16, elapsed : 1.0856568813323975
# ['A135', 'SnviroCare', 'TECHNOLOGIES', 'anti-allergen', 'VACUUM BAGS', 'Animal Dander Beware!', 'perlect for oiiergy sufferers', 'Will Mot Te', 'Designed to F', 'Eureka *Style OX', 'Fits6500.69900.CV140Ser', 'Electrolux*Style S', 'Fits EL6950,EL7000EL7020Seri']
# []
# 6495
# [2024/09/14 17:44:33] ppocr DEBUG: dt_boxes num : 34, elapsed : 0.17862558364868164
# [2024/09/14 17:44:33] ppocr DEBUG: cls num  : 34, elapsed : 0.08239269256591797
# [2024/09/14 17:44:34] ppocr DEBUG: rec_res num  : 34, elapsed : 1.5600109100341797
# ['digestive health', 'supports acute diarrhea AND constipation.', '(no more scooting or straining!)', 'immune', 'health', 'gut health', 'pumpkin is naturally', 'fiber is a natural', 'rich in Vitamins', 'prebiotic which', 'A,C,and E.', 'supports healthy', 'gut bacteria.', 'wild-', 'Pacre', 'premium', 'pumpkin', 'tastes great', 'fiber rich', 'FIBER SUPPLEMENT', 'your pup will love', 'fiber adds volume to', '&', 'DGETI', 'this special treat!', "your pet's food so they", 'stay fuller, longer.', 'T CONTENT.1OZ23', 'Supports healthy stools', 'wild', 'and digestion.', 'aere', 'PET']
# []
# 6496
# [2024/09/14 17:44:34] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.07915282249450684
# [2024/09/14 17:44:35] ppocr DEBUG: cls num  : 3, elapsed : 0.03719043731689453
# [2024/09/14 17:44:35] ppocr DEBUG: rec_res num  : 3, elapsed : 0.40910792350769043
# ['STRING LIGHT 9.84 FEET LONG 20 LED', '6CM/2.36INCH', '2.8CM/1.1INCH']
# []
# 6497
# [2024/09/14 17:44:35] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.0906071662902832
# [2024/09/14 17:44:35] ppocr DEBUG: cls num  : 8, elapsed : 0.055522918701171875
# [2024/09/14 17:44:36] ppocr DEBUG: rec_res num  : 8, elapsed : 0.3765683174133301
# ['APLENTY', 'Butter Chicken', 'SAUCE KIT', 'SERVES2-3IN 20MINS', 'butter ond frogront spices', 'MADEININDIA', 'MILD SPICE', 'NET WT.10OZ 283g']
# ['10 ounce', '283 gram']
# 283 gram
# 6498
# [2024/09/14 17:44:36] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.08608055114746094
# [2024/09/14 17:44:36] ppocr DEBUG: cls num  : 4, elapsed : 0.0186917781829834
# [2024/09/14 17:44:36] ppocr DEBUG: rec_res num  : 4, elapsed : 0.45159006118774414
# ['C60 Evo for Dogs', 'with Natural Bacon Essence', 'C60Evo', '3 oz']
# ['3 ounce']
# 3 ounce
# 6499
# [2024/09/14 17:44:37] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.3062269687652588
# [2024/09/14 17:44:37] ppocr DEBUG: cls num  : 8, elapsed : 0.03741788864135742
# [2024/09/14 17:44:37] ppocr DEBUG: rec_res num  : 8, elapsed : 0.46709489822387695
# ['AVOLUSION', 'AVOLUSION', 'Buillt-in', '5', '3TB', 'XBOXSeries', 'X,S', 'pre-tormatted']
# []
# 6500
# [2024/09/14 17:44:37] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.13006091117858887
# [2024/09/14 17:44:38] ppocr DEBUG: cls num  : 13, elapsed : 0.06252813339233398
# [2024/09/14 17:44:38] ppocr DEBUG: rec_res num  : 13, elapsed : 0.6931629180908203
# ['Always', 'ORGANIC', 'CateredBowl', 'PREMIUM CAT FOOD', '1ngrdint isCage-Free', 'Oroanic Chicken', 'GMO-Free Recipe', 'Grain-Free Recipe', 'A Balanced Formula for', 'All Life Stages', 'ORGANIC', 'CHICKEN RECIPE', '3Lb(.36kg)']
# ['3 pound', '36 kilogram']
# 36 kilogram
# 6501
# [2024/09/14 17:44:38] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.16894268989562988
# [2024/09/14 17:44:39] ppocr DEBUG: cls num  : 3, elapsed : 0.03583216667175293
# [2024/09/14 17:44:39] ppocr DEBUG: rec_res num  : 3, elapsed : 0.4537489414215088
# ['Anti Blue Ligh.', 'double anti blue light design to prevent eye fatigue', '10.1 inch IPS HD display with 1960x1080 high definition']
# []
# 6502
# [2024/09/14 17:44:39] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.08405160903930664
# [2024/09/14 17:44:39] ppocr DEBUG: cls num  : 15, elapsed : 0.045346736907958984
# [2024/09/14 17:44:41] ppocr DEBUG: rec_res num  : 15, elapsed : 1.3885035514831543
# ['The package including:', '60Ft/Roll 60LEDs/M Waterproof RGB LED Strip Light', 'w/Double-Sided Adhesive Tape on the back', '24Keys IR Remote', '&WiFi Controller w/Bulit-In Microphone', 'Waterproof Power Supply w/US 3-Prong Plug', 'Mounting Clips &Screws 2 Sets/Meter', '4x 90 degreeL Shaped) connectors', '4x Any angle bending connectorsrs', '110X']
# []
# 6503
# [2024/09/14 17:44:41] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.09168410301208496
# [2024/09/14 17:44:41] ppocr DEBUG: cls num  : 2, elapsed : 0.03748822212219238
# [2024/09/14 17:44:41] ppocr DEBUG: rec_res num  : 2, elapsed : 0.2119460105895996
# ['Ulllra-Lightweight Car Seat', 'Just under 8 Ib']
# []
# 6504
# [2024/09/14 17:44:42] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.3511350154876709
# [2024/09/14 17:44:42] ppocr DEBUG: cls num  : 9, elapsed : 0.03594541549682617
# [2024/09/14 17:44:42] ppocr DEBUG: rec_res num  : 9, elapsed : 0.4709916114807129
# ['Material', 'Silicone', 'Color', 'Multicolor', 'Item Weight', '3.52 Ounces', 'Age Range', '(Description)', 'Baby']
# ['3.52 ounce']
# 3.52 ounce
# 6505
# [2024/09/14 17:44:42] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.08939313888549805
# [2024/09/14 17:44:42] ppocr DEBUG: cls num  : 10, elapsed : 0.06363892555236816
# [2024/09/14 17:44:43] ppocr DEBUG: rec_res num  : 10, elapsed : 1.0250740051269531
# ['LIGHTWEIGHT&PORTABLE', '6.2 lbs 2.8kg', 'Easy to Use', 'Battery powered pressure washer,', 'no wires concern', '15.5x9.4 x5.3inches', '39.5*24*13.5cm', 'Compact Design', 'Convenient to carry around', 'or store.']
# ['6.2 pound', '2.8 kilogram']
# 6.2 pound
# 6506
# [2024/09/14 17:44:44] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.0771174430847168
# [2024/09/14 17:44:44] ppocr DEBUG: cls num  : 3, elapsed : 0.015796899795532227
# [2024/09/14 17:44:44] ppocr DEBUG: rec_res num  : 3, elapsed : 0.4805421829223633
# ['22o0w Double Tube Heating', 'The hot pot and the barbecue can be controlled', 'separately']
# []
# 6507
# [2024/09/14 17:44:44] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.07913041114807129
# [2024/09/14 17:44:44] ppocr DEBUG: cls num  : 7, elapsed : 0.052393198013305664
# [2024/09/14 17:44:45] ppocr DEBUG: rec_res num  : 7, elapsed : 0.3423466682434082
# ['NFL', 'TAE PROVTE', 'PROTEIN BAR', '20G', 'ETW33802218180060', '228078084']
# ['20 gram']
# 20 gram
# 6508
# [2024/09/14 17:44:45] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.3254413604736328
# [2024/09/14 17:44:45] ppocr DEBUG: cls num  : 4, elapsed : 0.01773238182067871
# [2024/09/14 17:44:46] ppocr DEBUG: rec_res num  : 4, elapsed : 0.9024796485900879
# ['Quick Charge', 'Output 8.4V71x 800mA or 2x 550mA,takes only4 hours', 'to fully recharge 2 batteries simultaneously', 'BESTON']
# []
# 6509
# [2024/09/14 17:44:46] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.14906859397888184
# [2024/09/14 17:44:46] ppocr DEBUG: cls num  : 10, elapsed : 0.034630775451660156
# [2024/09/14 17:44:47] ppocr DEBUG: rec_res num  : 10, elapsed : 0.6454110145568848
# ['BASILUR', 'BOUOUET', 'Collection', 'ASSORTED GREEN TEAS 32 TEA BAGS', 'UET', 'aien', 'MASY', 'NETWEIGHT48g/169 ']
# ['48 gram']
# 48 gram
# 6510
# [2024/09/14 17:44:47] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.08026456832885742
# [2024/09/14 17:44:47] ppocr DEBUG: cls num  : 14, elapsed : 0.0630488395690918
# [2024/09/14 17:44:48] ppocr DEBUG: rec_res num  : 14, elapsed : 1.118429183959961
# ['0', 'MADE FROM U.S.D.A. CHOICE BEEF CHUCK', 'BUBBA', 'burger', 'HE', 'SIX (6)-GLUTEN FREE BURGERSKEEP FROZENNET WT.32OZ(2LES', '0', 'MADE FROM U.S.DA. CHOICE BEEF CHUCK', 'BUBBA', 'urger', 'GF', 'SLX(6)-GLUTENFREE BURGERSKEEP FROZENNET WT.3OZ 2LES']
# ['32 ounce', '3 ounce']
# 32 ounce
# 6511
# [2024/09/14 17:44:49] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.07953238487243652
# [2024/09/14 17:44:49] ppocr DEBUG: cls num  : 10, elapsed : 0.03287315368652344
# [2024/09/14 17:44:49] ppocr DEBUG: rec_res num  : 10, elapsed : 0.645491361618042
# ['Ultralight &Comfortable', 'Inflate/Deflate In Seconds', 'Durable &Strong', 'Perfect for Backpacking/Camping/Travel', '2lnch', '74lnch', '74Inch', '500g/1.11bs', '23.6Inch']
# ['500 gram']
# 500 gram
# 6512
# [2024/09/14 17:44:50] ppocr DEBUG: dt_boxes num : 24, elapsed : 0.13430523872375488
# [2024/09/14 17:44:50] ppocr DEBUG: cls num  : 24, elapsed : 0.05236554145812988
# [2024/09/14 17:44:51] ppocr DEBUG: rec_res num  : 24, elapsed : 1.416274070739746
# ['SCIENTIFICALLY FORMULATED', 'Nutribonk', 'MITO-TONIC', 'YCO010', 'ADVANCEDO', 'MITOCHONDRIAL', 'COCKTAIL', 'MITONUTRIENTSO', 'Creatine.CoQ', 'Contains', 'D-Ribose,&L-Carnitine', 'ORANGE', 'ENKANCEO MITOCHONDRIAL', 'HELPS TO SUPPORT', 'DEDARYSPRBE', 'FLAVOR', 'INCREASED CELLULAR ENERGY!', "FUNCTION'", 'SUPPL', '15Day', 'IMPROVEO.CARDIAC FUNCTION', '(225g)']
# ['225 gram']
# 225 gram
# 6513
# [2024/09/14 17:44:51] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.22720098495483398
# [2024/09/14 17:44:51] ppocr DEBUG: cls num  : 7, elapsed : 0.05385255813598633
# [2024/09/14 17:44:52] ppocr DEBUG: rec_res num  : 7, elapsed : 0.35712337493896484
# ['THOMAS', 'GOLF', 'L60 AT7s', 'HYBRID', 'I/W', 'PATENTED', '5.716.288']
# []
# 6514
# [2024/09/14 17:44:52] ppocr DEBUG: dt_boxes num : 21, elapsed : 0.16628026962280273
# [2024/09/14 17:44:52] ppocr DEBUG: cls num  : 21, elapsed : 0.07576990127563477
# [2024/09/14 17:44:53] ppocr DEBUG: rec_res num  : 21, elapsed : 0.9555644989013672
# ['BRACHS', 'Miniature', 'Unicorn', 'JellgBeans', 'e.Cherry', 'nge.Lime', 'laspberry', 'od Blue', 'NE', "BRACH'S", 'Mintiature', 'Unicorn', 'JellgBeans', 'pe.Cherry', '110', 'd Blue', 'mge.Lime', 'aspbetry', 'NETW', '107099']
# []
# 6515
# [2024/09/14 17:44:54] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.16886472702026367
# [2024/09/14 17:44:54] ppocr DEBUG: cls num  : 9, elapsed : 0.037952423095703125
# [2024/09/14 17:44:54] ppocr DEBUG: rec_res num  : 9, elapsed : 0.47580909729003906
# ['YANKee', 'CANDLe', 'Scenterpiece', 'EASYMELTCUP', 'NETWT', '2202', '61g', 'HONEY', 'CLEMENTINE']
# ['61 gram']
# 61 gram
# 6516
# [2024/09/14 17:44:54] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.08744549751281738
# [2024/09/14 17:44:54] ppocr DEBUG: cls num  : 7, elapsed : 0.03334546089172363
# [2024/09/14 17:44:55] ppocr DEBUG: rec_res num  : 7, elapsed : 0.5036096572875977
# ['Natural Valley', 'Goat Cheese', 'MOZZARELLA', '.A visit to the past.', 'KEEP REFRIGERATED', 'NETW.8OZ.227g)', 'Pasture Pride CheeseLLC.110 Eagle Dr.CashtonWisconsin 54619']
# ['8 ounce', '227 gram']
# 8 ounce
# 6517
# [2024/09/14 17:44:55] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.3493983745574951
# [2024/09/14 17:44:55] ppocr DEBUG: cls num  : 3, elapsed : 0.016892433166503906
# [2024/09/14 17:44:56] ppocr DEBUG: rec_res num  : 3, elapsed : 0.2506430149078369
# ['Portable SsD', 'MOBILE STORAGE', '4TB']
# []
# 6518
# [2024/09/14 17:44:56] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.23826384544372559
# [2024/09/14 17:44:56] ppocr DEBUG: cls num  : 6, elapsed : 0.018973112106323242
# [2024/09/14 17:44:56] ppocr DEBUG: rec_res num  : 6, elapsed : 0.3416574001312256
# ['Color', 'Blacke', 'Exterior Finish', 'Painted', 'Item Weight.', '57.42 Pounds']
# ['57.42 pound']
# 57.42 pound
# 6519
# [2024/09/14 17:44:57] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.08215689659118652
# [2024/09/14 17:44:57] ppocr DEBUG: cls num  : 5, elapsed : 0.03991293907165527
# [2024/09/14 17:44:57] ppocr DEBUG: rec_res num  : 5, elapsed : 0.4186875820159912
# ['GREATFOR', 'BACKPACKING', 'CAMPING & TRAVEL', 'Lightweight &Compact', '490g']
# ['490 gram']
# 490 gram
# 6520
# [2024/09/14 17:44:57] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.07824921607971191
# [2024/09/14 17:44:57] ppocr DEBUG: cls num  : 6, elapsed : 0.01982712745666504
# [2024/09/14 17:44:58] ppocr DEBUG: rec_res num  : 6, elapsed : 0.285982608795166
# ['Dout', 'Din', 'GND', 'GND', 'CND']
# []
# 6521
# [2024/09/14 17:44:58] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.25164175033569336
# [2024/09/14 17:44:58] ppocr DEBUG: cls num  : 8, elapsed : 0.05386781692504883
# [2024/09/14 17:44:59] ppocr DEBUG: rec_res num  : 8, elapsed : 0.6699068546295166
# ['About Fishing Reel', 'Material:Aluminum alloy', 'Weight:6.3oz', 'Axis material: Copper', 'Ball bearing:2+1BB', 'Gear ratio:4.3:1', 'Size3.5 *3.5 *3.1in', 'Line capacity:1#-120M/2#-60M']
# ['6.3 ounce']
# 6.3 ounce
# 6522
# [2024/09/14 17:44:59] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.23245787620544434
# [2024/09/14 17:44:59] ppocr DEBUG: cls num  : 10, elapsed : 0.05225062370300293
# [2024/09/14 17:45:00] ppocr DEBUG: rec_res num  : 10, elapsed : 0.5770938396453857
# ['BODIPURE', 'Professional Spa Products', 'SOCKS', 'Nail Strengthening', 'Skin Nourishing', 'All-In-One', 'Foot Treatment', 'NO PARABEN I NO TRICLOSAN', 'NET WT.O.81 OZ.']
# ['81 ounce']
# 81 ounce
# 6523
# [2024/09/14 17:45:00] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.08353400230407715
# [2024/09/14 17:45:00] ppocr DEBUG: cls num  : 3, elapsed : 0.03577446937561035
# [2024/09/14 17:45:00] ppocr DEBUG: rec_res num  : 3, elapsed : 0.34182286262512207
# ['2000W Fast Heat-up', '5-Level Temperature Control', 'Choose proper temperature to cook']
# []
# 6524
# [2024/09/14 17:45:01] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.08319735527038574
# [2024/09/14 17:45:01] ppocr DEBUG: cls num  : 12, elapsed : 0.031021595001220703
# [2024/09/14 17:45:01] ppocr DEBUG: rec_res num  : 12, elapsed : 0.8485496044158936
# ['1200W High Power Heaing Panel', 'Fast & Evenly heating conduction', 'Lid', 'VENTRAY', 'Steam/Grill', 'Pan', 'Base', '6.5in', 'Function', 'Off.Low.Medium,High', '15.1in', '10.2in']
# []
# 6525
# [2024/09/14 17:45:02] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.07853460311889648
# [2024/09/14 17:45:02] ppocr DEBUG: cls num  : 8, elapsed : 0.051450490951538086
# [2024/09/14 17:45:02] ppocr DEBUG: rec_res num  : 8, elapsed : 0.7247564792633057
# ['WIDERTHICKER ULTRALIGHT', 'ABOUT9.4IN/24CM', 'OESMOK', 'ABOUT4.7IN/12CM', '190CM74.8IN', '30.50Z/865G', '1KG', '70CM(27.6IN)']
# ['865 gram', '1 kilogram']
# 865 gram
# 6526
# [2024/09/14 17:45:03] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.14043760299682617
# [2024/09/14 17:45:03] ppocr DEBUG: cls num  : 12, elapsed : 0.03225231170654297
# [2024/09/14 17:45:03] ppocr DEBUG: rec_res num  : 12, elapsed : 0.6939482688903809
# ['GOURMET', 'MEXICAN', 'GCRUSHED', 'FIRE-ROASTED', 'TOMATOES', 'with roasted garlic+ onion', 'GREATFOR', 'SALSAS,BRAISES', 'AND SAUCES', 'MILD', 'NET WT 14.5 OZ 410g']
# ['14.5 ounce', '410 gram']
# 410 gram
# 6527
# [2024/09/14 17:45:04] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.07984209060668945
# [2024/09/14 17:45:04] ppocr DEBUG: cls num  : 7, elapsed : 0.05133533477783203
# [2024/09/14 17:45:04] ppocr DEBUG: rec_res num  : 7, elapsed : 0.47196340560913086
# ['CANARY', 'KAYTEE', 'Healthy Support Diet', 'with DHA.Omega-3&Problotics Plus Real Egg', 'FortiDiet', 'NET WT2LB (907 g)', 'PROHEALTH']
# ['2 pound', '907 gram']
# 907 gram
# 6528
# [2024/09/14 17:45:04] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.06965351104736328
# [2024/09/14 17:45:04] ppocr DEBUG: cls num  : 2, elapsed : 0.03263449668884277
# [2024/09/14 17:45:05] ppocr DEBUG: rec_res num  : 2, elapsed : 0.13112688064575195
# An error occurred: 'NoneType' object is not iterable
# []
# []
# 6529
# [2024/09/14 17:45:05] ppocr DEBUG: dt_boxes num : 38, elapsed : 0.14761972427368164
# [2024/09/14 17:45:05] ppocr DEBUG: cls num  : 38, elapsed : 0.10124731063842773
# [2024/09/14 17:45:09] ppocr DEBUG: rec_res num  : 38, elapsed : 3.5968217849731445
# ['Enlight', 'ENlight Corporation', 'P/N#843H2001A', 'CE', 'AC INPUT:', '115V', '9A', '+5V+3.3V+12V1+12V2-12V+5VSB', 'DC', 'OUTPUT', '230V', '5A', 'FC o', 'FREQUENCY50-60 Hz', '20A20A18A18A0.8A', 'MAX LOAD430W PEAK', '2A', '130W', '300W', '9.6W10W', 'WARNING', 'WARNUNG', 'THIS POWER SUPPLY IS NOT USER SERVICEABLE.', 'HAZARDOUS VOLTAGES CONTAINED WITHIN,', 'NICHT VOM BENUTZER ZU REPARIEREN.ZUR', 'NETZTEIL UNTER GEFAHRLICHER SPANNUNG,', 'RETURN TO SERVICE CENTER FOR REPAIR.', 'ATTENTION', 'REPARATUR AN KUNDENDIENST ZURUCKSENDEN,', 'TENSIONS DANGEREUSES NE PEUT ETRE', 'PELIGRO', 'ESTA FUENTE DE PODER UTILIZA ALTA TENSION.', 'REPARATION RENVOYER AU SERVICE APRES', 'VENTE.', 'CENTRO DE SERVICIO PARA SU REPARACION', 'Made In Chini', 'MODEL:HPC-430L128 40.40012.029A']
# []
# 6530
# [2024/09/14 17:45:09] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.16657137870788574
# [2024/09/14 17:45:09] ppocr DEBUG: cls num  : 12, elapsed : 0.031488656997680664
# [2024/09/14 17:45:09] ppocr DEBUG: rec_res num  : 12, elapsed : 0.4852774143218994
# ['2 gallons', 'back carryon', 'MAJESTIC', 'Anti-roll', 'DUAL', 'Rear Whee', 'Engine', 'SHOCK', 'Absorption', 'Design', '55 Ibs', 'with battery']
# []
# 6531
# [2024/09/14 17:45:10] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.0863640308380127
# [2024/09/14 17:45:10] ppocr DEBUG: cls num  : 10, elapsed : 0.06039905548095703
# [2024/09/14 17:45:10] ppocr DEBUG: rec_res num  : 10, elapsed : 0.6935007572174072
# ['AVERAGEWEIGHT IS7.93OZ', 'PERFECTLY BALANCES DRIVE AND CONTROL', 'Professional', 'Strong&', 'Light&', 'Perfect', 'Design', 'Sturdy', 'Comfortable', 'protection']
# ['7.93 ounce']
# 7.93 ounce
# 6532
# [2024/09/14 17:45:10] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.08288192749023438
# [2024/09/14 17:45:11] ppocr DEBUG: cls num  : 9, elapsed : 0.054276466369628906
# [2024/09/14 17:45:11] ppocr DEBUG: rec_res num  : 9, elapsed : 0.4925663471221924
# ['Adjustable', 'Headrest', 'Memory Foam', 'Leather', 'Cushion & Backrest', 'Lightweight', '55 lbs', 'with battery', 'MAJESTIC']
# ['55 pound']
# 55 pound
# 6533
# [2024/09/14 17:45:11] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.0785837173461914
# [2024/09/14 17:45:11] ppocr DEBUG: cls num  : 5, elapsed : 0.03897714614868164
# [2024/09/14 17:45:12] ppocr DEBUG: rec_res num  : 5, elapsed : 0.29932403564453125
# ['590', 'Light weight', 'Release your stress', '1.3 pounds, 590g', 'coming from shoulder']
# ['1.3 pound', '590 gram']
# 590 gram
# 6534
# [2024/09/14 17:45:12] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.23538780212402344
# [2024/09/14 17:45:12] ppocr DEBUG: cls num  : 5, elapsed : 0.018358469009399414
# [2024/09/14 17:45:13] ppocr DEBUG: rec_res num  : 5, elapsed : 1.347485065460205
# ['1', 'COATINGPROCESSPANEL', '2', 'TABLE TENNIS FOR KIDS']
# []
# 6535
# [2024/09/14 17:45:14] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.32320666313171387
# [2024/09/14 17:45:14] ppocr DEBUG: cls num  : 3, elapsed : 0.015662193298339844
# [2024/09/14 17:45:14] ppocr DEBUG: rec_res num  : 3, elapsed : 0.1741023063659668
# ['KINGF9', '10.5STD']
# []
# 6536
# [2024/09/14 17:45:14] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.15082192420959473
# [2024/09/14 17:45:14] ppocr DEBUG: cls num  : 12, elapsed : 0.05252957344055176
# [2024/09/14 17:45:15] ppocr DEBUG: rec_res num  : 12, elapsed : 0.6291842460632324
# ['ORIGINAL', 'Cranberry', 'Juice Cocktail', '100', '130', 'Ooz', 'FROM CONCENTRATE', '100%', 'BOTTLES', 'VITAMINC']
# []
# 6537
# [2024/09/14 17:45:15] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.14007806777954102
# [2024/09/14 17:45:15] ppocr DEBUG: cls num  : 2, elapsed : 0.035883188247680664
# [2024/09/14 17:45:15] ppocr DEBUG: rec_res num  : 2, elapsed : 0.12041020393371582
# ['10x', 'BBRESSER']
# []
# 6538
# [2024/09/14 17:45:16] ppocr DEBUG: dt_boxes num : 24, elapsed : 0.23649835586547852
# [2024/09/14 17:45:16] ppocr DEBUG: cls num  : 24, elapsed : 0.058011531829833984
# [2024/09/14 17:45:17] ppocr DEBUG: rec_res num  : 24, elapsed : 1.6173686981201172
# ['220539', '83916-2013-02', 'Distributed by/Distribue par', 'Distribuido por', '02946:98027', 'Michaels Stores.Inc.', '8000 Bent Branch Drive', 'Irving.TX75063', '0010099668', 'MADEINUSA/FABRIQUE AUX ETATS-UNIS', '3', 'Recollections', 'Sianature"Esnccia', 'Shimmer Cardstock', 'White gold  Acid and lignin free', 'Papier Cartonne Satine', 'Orblanc  Sans acide nilignine', 'Cartulina Brillante', 'Oro.blanco Libre de acidos y lignina', 'sheets', '100', '65 lb/176g/m2', '8.5 inx.11 in/21.5 cmx27.9 cm']
# ['65 pound', '176 gram']
# 65 pound
# 6539
# [2024/09/14 17:45:18] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.17193102836608887
# [2024/09/14 17:45:18] ppocr DEBUG: cls num  : 10, elapsed : 0.05991387367248535
# [2024/09/14 17:45:18] ppocr DEBUG: rec_res num  : 10, elapsed : 0.6788463592529297
# ['2100070134.00', 'KEEPREFRIGERATED', 'raftfo', '1-864-538-2335', 'KRAFT', 'CHEDASHARP', 'PASTEURIZED PROCESS CHEDDAR CHEESE SHRED', '10021000701363', 'NET WT 20 LBS (9.07Kg)', '4/5LB BAGS']
# ['20 pound', '9.07 kilogram', '5 pound']
# 9.07 kilogram
# 6540
# [2024/09/14 17:45:19] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.09148478507995605
# [2024/09/14 17:45:19] ppocr DEBUG: cls num  : 16, elapsed : 0.04996037483215332
# [2024/09/14 17:45:20] ppocr DEBUG: rec_res num  : 16, elapsed : 0.9079921245574951
# ['YHDAXARTMATCERRRMAT', 'Resealable', 'TEAR HERE', 'PRESSZIPPERTOCLOS', 'Karibbean', 'Flavours', 'DRIED SEAMOSS', 'Vedar', 'Irish Moss', 'EREE', "Mousse-d'Irlande", 'Organic', 'Net Weight/poids net:', '85g']
# ['85 gram']
# 85 gram
# 6541
# [2024/09/14 17:45:20] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.14392542839050293
# [2024/09/14 17:45:20] ppocr DEBUG: cls num  : 7, elapsed : 0.05588269233703613
# [2024/09/14 17:45:20] ppocr DEBUG: rec_res num  : 7, elapsed : 0.34572291374206543
# ['BristolFarms', 'Mediterranean', 'Chicken with', 'Grains', 'NET902 (255 )']
# []
# 6542
# [2024/09/14 17:45:20] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.11847329139709473
# [2024/09/14 17:45:20] ppocr DEBUG: cls num  : 6, elapsed : 0.0195310115814209
# [2024/09/14 17:45:21] ppocr DEBUG: rec_res num  : 6, elapsed : 0.32144856452941895
# ['SpecjalTea', 'You toste the difference', 'Candy CaramelApple', 'oose Leaf Black Tea', 'www.specialteacompany.com']
# []
# 6543
# [2024/09/14 17:45:21] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.17336177825927734
# [2024/09/14 17:45:21] ppocr DEBUG: cls num  : 10, elapsed : 0.05311775207519531
# [2024/09/14 17:45:22] ppocr DEBUG: rec_res num  : 10, elapsed : 0.6633591651916504
# ['BEAUTIFUL', 'Compact, Elegant, Stylish Design', 'IEKOV', 'LED STRIP LIGHT', 'LED', 'LED STRIP LIGHT', 'CECOX']
# []
# 6544
# [2024/09/14 17:45:22] ppocr DEBUG: dt_boxes num : 27, elapsed : 0.26558518409729004
# [2024/09/14 17:45:22] ppocr DEBUG: cls num  : 27, elapsed : 0.08946824073791504
# [2024/09/14 17:45:24] ppocr DEBUG: rec_res num  : 27, elapsed : 1.3180701732635498
# ['Specifications', 'EWA A106 Bluetooth Spe...d Carabiner RoseGold)', 'Product name', 'Wireless speaker', 'Production lot number:EWA43131', 'Model', 'A106Pro', 'Wireless.range', '20m', 'Weight', '182g', 'B08FY1VPLC', 'Output:', '3W', 'Version2.0', 'Dimensions', 'H40*48mm', 'Battery', '700mAn', 'Prolinx Global LTD', 'UKREP', '27 0ld Gloucester Street', 'LondonWC1N 3AX UK', 'ROHS', 'FECID:2ANVR-A106', 'Made in China']
# ['182 gram']
# 182 gram
# 6545
# [2024/09/14 17:45:24] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.14091014862060547
# [2024/09/14 17:45:24] ppocr DEBUG: cls num  : 16, elapsed : 0.0676736831665039
# [2024/09/14 17:45:25] ppocr DEBUG: rec_res num  : 16, elapsed : 0.7504632472991943
# ['PRODUCTOF', '2LB', 'PERU', '(907g)', 'Amazing', 'CHILES & SPICES', 'A', '...', 'MAIZMOTEPELADO', 'GIANT WHITE CORN/WHITE', 'H', 'HAND PACKEO IN CALIFORNIA', 'INGREDIENTS:', 'RECIPES AND INFORMATION', 'WHITE CORN', 'WWW.AMAZINGCHILES.COM']
# ['2 pound', '907 gram']
# 907 gram
# 6546
# [2024/09/14 17:45:25] ppocr DEBUG: dt_boxes num : 19, elapsed : 0.3455982208251953
# [2024/09/14 17:45:25] ppocr DEBUG: cls num  : 19, elapsed : 0.07643914222717285
# [2024/09/14 17:45:26] ppocr DEBUG: rec_res num  : 19, elapsed : 1.0609824657440186
# ['Frame Material:', 'Pure Titanium(Ip Plating)', 'Style:', 'Square I Model:', 'F85642', 'Lens Material:', 'PC', 'Gender:', 'Unisex', 'I Weight:', '15.2G', 'Parameter:', '35mm/1.38in', '216mm/0.63in', '3146mm/5.75in', '456mm/2.20in', '5148mm/5.83in', 'Due to different measurement methods,there exist 1-3mm(0.04-0.12in) error.']
# ['15.2 gram']
# 15.2 gram
# 6547
# [2024/09/14 17:45:26] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.16108036041259766
# [2024/09/14 17:45:26] ppocr DEBUG: cls num  : 1, elapsed : 0.013544559478759766
# [2024/09/14 17:45:27] ppocr DEBUG: rec_res num  : 1, elapsed : 0.09463191032409668
# ['2 Pack']
# []
# 6548
# [2024/09/14 17:45:27] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.08301711082458496
# [2024/09/14 17:45:27] ppocr DEBUG: cls num  : 9, elapsed : 0.0530245304107666
# [2024/09/14 17:45:28] ppocr DEBUG: rec_res num  : 9, elapsed : 1.3939549922943115
# ['12 ORGANIC WHOLE FOOD PLANT-BASED INGREDIENTS', 'PACKED withORGANIC NOURISHMENT', 'KETO', 'KETOGENICFORMULA', 'NetW1.8 0z. (227g)', 'Plant Based|Clean Sourced|Gluten Free|Dairy Free', 'Soy Free|Corn Free|GMO Free|BPA Free']
# ['227 gram']
# 227 gram
# 6549
# [2024/09/14 17:45:28] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.08941149711608887
# [2024/09/14 17:45:28] ppocr DEBUG: cls num  : 5, elapsed : 0.044516801834106445
# [2024/09/14 17:45:29] ppocr DEBUG: rec_res num  : 5, elapsed : 0.270702600479126
# ['2FEETLONG!', 'WAAR', 'REBELS', 'CAUNO', 'AGES5.']
# []
# 6550
# [2024/09/14 17:45:29] ppocr DEBUG: dt_boxes num : 20, elapsed : 0.09268784523010254
# [2024/09/14 17:45:29] ppocr DEBUG: cls num  : 20, elapsed : 0.08118867874145508
# [2024/09/14 17:45:31] ppocr DEBUG: rec_res num  : 20, elapsed : 1.6484489440917969
# ['ELECTRONIC MOTOR', 'MULTI-FUNCTION SELECTOR', 'AND CELL PROTECTION', 'Helps protect motor and', 'ERGONOMIC GRIP ZONE', 'Offers three modes of operation', 'battery from overheating', 'Offers a soft grip and optimized', 'rotary hammer,hammer only', 'design for better handling and', 'and rotation only', 'greater comfort', 'BRUSHLESS MOTOR', 'Maximizes battery runtime', 'in extended applications', 'HIGH IMPACT-TO-WEIGHT RATIO', 'Delivers 1.5 Ft.-Lbs.of impact energy', 'EPTA) and weighs only 5.3 Lbs.', 'tool onlynot including battery)']
# ['5.3 pound']
# 5.3 pound
# 6551
# [2024/09/14 17:45:31] ppocr DEBUG: dt_boxes num : 40, elapsed : 0.09367108345031738
# [2024/09/14 17:45:31] ppocr DEBUG: cls num  : 40, elapsed : 0.11625194549560547
# [2024/09/14 17:45:33] ppocr DEBUG: rec_res num  : 40, elapsed : 1.9024627208709717
# ['Technical parameters', 'AC input voltage range:180-260ac40-70Hz', 'charging mode:6-stage intelligent charging', 'overall efficiency94.0%protection level ip66', 'noise45d8', 'Size weight and', 'temperature Weight:', '3Kg', ')Operating temperature:-40#-+60', '#0verallsize:244 127', '86(mm)', 'Specification', 'Battery rated voltage', 'Maximum output voltage', 'Maximum output current', 'model', '2430A', '24V', '33.0V', '30A', '4825A', '48V', '66.0V', '25A', '4830A', '48V', '66.0V', '30A', '6025A', '60V', '82.5V', '25A', '6030A', '60V', '82.5V', '30A', '7225A', '72V', '99.0V', '25A']
# ['3 kilogram']
# 3 kilogram
# 6552
# [2024/09/14 17:45:33] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.33447718620300293
# [2024/09/14 17:45:33] ppocr DEBUG: cls num  : 4, elapsed : 0.01680922508239746
# [2024/09/14 17:45:34] ppocr DEBUG: rec_res num  : 4, elapsed : 0.7179105281829834
# ['PACKING', 'LIST', 'MOBILE PHONE HOLDER*1,TUYEREBASE*1,PASTE BASE *1,', 'ELASTIC FIXING RING *1,BACKING ADHESIVE *2']
# []
# 6553
# [2024/09/14 17:45:34] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.2413771152496338
# [2024/09/14 17:45:34] ppocr DEBUG: cls num  : 13, elapsed : 0.061489105224609375
# [2024/09/14 17:45:35] ppocr DEBUG: rec_res num  : 13, elapsed : 0.7221989631652832
# ['Compatible with MacBookProA1708', 'Mode:FM17A', 'FC', 'Capacity:512GB', 'CE', 'PCI-ENVMESSD', 'PROHS', 'Madein China']
# []
# 6554
# [2024/09/14 17:45:35] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.14346671104431152
# [2024/09/14 17:45:35] ppocr DEBUG: cls num  : 4, elapsed : 0.01866745948791504
# [2024/09/14 17:45:36] ppocr DEBUG: rec_res num  : 4, elapsed : 0.43456339836120605
# ['Vatural', 'PlusGreer', 'Whole Dried Chilies (Medium Hot)', 'NET WT.4oz114g)']
# ['114 gram']
# 114 gram
# 6555
# [2024/09/14 17:45:36] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.15861058235168457
# [2024/09/14 17:45:36] ppocr DEBUG: cls num  : 9, elapsed : 0.05679178237915039
# [2024/09/14 17:45:37] ppocr DEBUG: rec_res num  : 9, elapsed : 0.8022074699401855
# ['Ultralight & Compact', '-Save a Pillow and Pump', '11.8"', '1.76L8', 'Enough Support to Turn Rough into Flat', '78.7*', '27.6', '4.7', '2.4']
# []
# 6556
# [2024/09/14 17:45:37] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.15328240394592285
# [2024/09/14 17:45:37] ppocr DEBUG: cls num  : 6, elapsed : 0.019270896911621094
# [2024/09/14 17:45:37] ppocr DEBUG: rec_res num  : 6, elapsed : 0.2561354637145996
# ['GRATED', 'PARMESAN', 'STYLE', 'CHEESE']
# []
# 6557
# [2024/09/14 17:45:38] ppocr DEBUG: dt_boxes num : 120, elapsed : 0.10975885391235352
# [2024/09/14 17:45:38] ppocr DEBUG: cls num  : 120, elapsed : 0.20717763900756836
# [2024/09/14 17:45:45] ppocr DEBUG: rec_res num  : 120, elapsed : 6.802967548370361
# ['Nutrition Facts', 'Servings Per Container', 'Serving Size', '1 Packet (37g)', '1/2Packet 18.5g', '2through 3', 'Children', 'Amount per serving', 'Years of Age', 'GMO', 'Calories', '140', '70', '%Daily Value', 'Total Fat', '7g', '9%', '3.5g', '9%', 'Saturated Fat', '1g', '5%', '0.5g', '5%', 'Non', 'Soy', 'Trans Fat', '0g', '0g', 'GMO', 'Free', 'Cholesterol', '5mg', '2%', '<5mg', '1%', 'Sodium', '150mg', '7%', '80mg', '5%', 'Total Carbohydrate', '18g', '7%', '9g', '6%', 'Dietary Fiber', '8g', '29%', '4g', '29%', 'Soluble Fiber', '79', '39', 'Insoluble Fiber', '1g', '<1g', 'Total Sugars', '<1g', '0%0g', '<1g', 'Incl.Added Sugars', '0g', '8', '0%', 'Protein', '16%', '4g', '30%', 'Lactose', 'Gluten', 'Vitamin D', '6mog', '30%', '3mog', '20%', 'Free', 'Free', 'Caicum', '180mg', '15%', '90mg', '15%', 'Iron', '0.4mg', '2%', '0.2mg', '2%', 'Potassium', '100mg', '2%', '50mg', '2%', 'VitaminA', '180mcg', '20%', '90mcg', '30%', 'Vitamin C', '30mg', '35%', '15mg', '100%', 'USDA', 'The % Daily Value (Dv tels you how much a nutrient in a serving of food', 'The%Day Ve Dv ts you how mucha ntrint in a sening of food', 'onibutos to a day diet.1,ococalories a daysused for general nutrson advio', 'ORGANIC', 'INGREDIENTS:ORGANICPRE-BIOTIC TAPIOCA FIBER,ORGANIC', 'MILKPROTEIN CONCENTRATE.ORGANIC CREAMER ORGANIC', 'HIGH OLEIC SUNFLOWER OIL.ORGANIC RICE SYRUP SOLIDS.', 'LECITHIN.TRICALCIUM PHOSPHATE)ORGANIC AVOCADO OIL,', 'ORGANIC PEA PROTEIN,SODIUM CITRATE,ORGANIC SUNFLOWER', 'ORGANIC OAT FIBERORGANIC LOCUST BEAN GUM SEA SALT', 'ORGANIC COCOA POWDER,ORGANIC NATURAL FLAVORS', 'XANTHAN GUM.ORGANIC STEVIA LEAF EXTRACTASCORBIC ACID', 'VITAMIN C.ORGANIC MONK FRUIT EXTRACT.VITAMINA', 'PALMITATEVITAMIN D3.CONTAINS MILK (LACTOSEFREE.']
# ['37 gram', '18.5 gram', '7 gram', '3.5 gram', '1 gram', '0.5 gram', '0 gram', '0 gram', '5 milligram', '5 milligram', '150 milligram', '80 milligram', '18 gram', '9 gram', '8 gram', '4 gram', '1 gram', '1 gram', '1 gram', '0 gram', '1 gram', '0 gram', '4 gram', '180 milligram', '90 milligram', '0.4 milligram', '0.2 milligram', '100 milligram', '50 milligram', '30 milligram', '15 milligram']
# 1 gram
# 6558
# [2024/09/14 17:45:45] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.14841055870056152
# [2024/09/14 17:45:45] ppocr DEBUG: cls num  : 10, elapsed : 0.05525088310241699
# [2024/09/14 17:45:46] ppocr DEBUG: rec_res num  : 10, elapsed : 0.752894401550293
# ['REEI', 'Walnuts,Almonds,', "Job's Tears Tea", '15', 'STICKS', '270g1.275kca/18gX1504%.3%.1%']
# []
# 6559
# [2024/09/14 17:45:46] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.07630491256713867
# [2024/09/14 17:45:46] ppocr DEBUG: cls num  : 2, elapsed : 0.04019808769226074
# [2024/09/14 17:45:46] ppocr DEBUG: rec_res num  : 2, elapsed : 0.26433444023132324
# ['SURERPOWERWATERGUN', 'More Shooting Range (27-36 Ft']
# []
# 6560
# [2024/09/14 17:45:46] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.12714862823486328
# [2024/09/14 17:45:46] ppocr DEBUG: cls num  : 6, elapsed : 0.021164655685424805
# [2024/09/14 17:45:47] ppocr DEBUG: rec_res num  : 6, elapsed : 0.3030214309692383
# ['Campbells', 'CONDENSED SOUI', 'RE', 'NETWT.104:0288']
# []
# 6561
# [2024/09/14 17:45:47] ppocr DEBUG: dt_boxes num : 32, elapsed : 0.13086962699890137
# [2024/09/14 17:45:47] ppocr DEBUG: cls num  : 32, elapsed : 0.07351994514465332
# [2024/09/14 17:45:48] ppocr DEBUG: rec_res num  : 32, elapsed : 1.4714577198028564
# ['ANIMED"', 'GUARANE', 'Eachonng', 'dH-Meond', "It's all about /the animals.", 'INGREDEN', 'Aetadng biocks', 'd-Ve', 'sr and oher', 'PURE', 'FORANVE', 'Radsin', 'KEEPORS', 'radondtions', 'd-Methionine', 'GROTHO', '.rd hooe', 'ton ar', 'Powder', 'o', 'Concentrated Feed Supplement', 'Lare', 'Ne1 Contents:16 ounces (454Gm']
# ['16 ounce', '454 gram']
# 454 gram
# 6562
# [2024/09/14 17:45:49] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.08714818954467773
# [2024/09/14 17:45:49] ppocr DEBUG: cls num  : 15, elapsed : 0.06516599655151367
# [2024/09/14 17:45:49] ppocr DEBUG: rec_res num  : 15, elapsed : 0.834876537322998
# ['Lightweight &', 'WEIGHT', '20 lbs', 'Easy to Instal', 'VOLTAGE', '120volts', 'steel enamel', 'burner cap', 'obbe', 'enameled stainless-steel cooktop', 'NON-STICK&', 'aluminum', 'base', 'EASYTO CLEAN', 'burners']
# ['20 pound']
# 20 pound
# 6563
# [2024/09/14 17:45:50] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.07581877708435059
# [2024/09/14 17:45:50] ppocr DEBUG: cls num  : 10, elapsed : 0.0542905330657959
# [2024/09/14 17:45:50] ppocr DEBUG: rec_res num  : 10, elapsed : 0.6211309432983398
# ['8Pack', 'ofCans', 'Roland', 'Straw', 'Mushrooms', 'WHOLE PEELED', 'MEDIUM', 'NETWT.150Z 25gDRWT.80Z 3', 'Bringing Restaurant-Quality', 'Ingredients Into The Home Kitchen']
# []
# 6564
# [2024/09/14 17:45:50] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.07671499252319336
# [2024/09/14 17:45:50] ppocr DEBUG: cls num  : 4, elapsed : 0.017177820205688477
# [2024/09/14 17:45:51] ppocr DEBUG: rec_res num  : 4, elapsed : 0.208449125289917
# ['mokeless', 'imni5-20ne:', '2x2.50z/71g']
# ['71 gram']
# 71 gram
# 6565
# [2024/09/14 17:45:51] ppocr DEBUG: dt_boxes num : 17, elapsed : 0.0875234603881836
# [2024/09/14 17:45:51] ppocr DEBUG: cls num  : 17, elapsed : 0.0695946216583252
# [2024/09/14 17:45:52] ppocr DEBUG: rec_res num  : 17, elapsed : 1.2898924350738525
# ['crazy about chocolate,', 'serious about people', 'chocolate 51% pecan coconu', 'FONYS', 'CHOCOLONELY', 'ONMSCHOGOLONEL', 'unequally', 'Fairtrade', 'divided', 'and B Corp', 'Certified', '... and very,', 'FAIRTRADE', 'veryyummy']
# []
# 6566
# [2024/09/14 17:45:53] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.35094642639160156
# [2024/09/14 17:45:53] ppocr DEBUG: cls num  : 3, elapsed : 0.04050087928771973
# [2024/09/14 17:45:53] ppocr DEBUG: rec_res num  : 3, elapsed : 0.2040703296661377
# ['Folding design', '131cm/51.57in', '26.5cm/10.43in']
# []
# 6567
# [2024/09/14 17:45:53] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.1507396697998047
# [2024/09/14 17:45:53] ppocr DEBUG: cls num  : 3, elapsed : 0.016285181045532227
# [2024/09/14 17:45:53] ppocr DEBUG: rec_res num  : 3, elapsed : 0.19143104553222656
# ['Pasteurized Process Cheese', 'mon GMO', 't 1a 25']
# []
# 6568
# [2024/09/14 17:45:54] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.2514657974243164
# [2024/09/14 17:45:54] ppocr DEBUG: cls num  : 5, elapsed : 0.018267393112182617
# [2024/09/14 17:45:54] ppocr DEBUG: rec_res num  : 5, elapsed : 0.5297269821166992
# ['Bottom bracket adjustment button', 'CACW-', 'Wir']
# []
# 6569
# [2024/09/14 17:45:54] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.0751490592956543
# [2024/09/14 17:45:54] ppocr DEBUG: cls num  : 3, elapsed : 0.015201568603515625
# [2024/09/14 17:45:55] ppocr DEBUG: rec_res num  : 3, elapsed : 0.25943565368652344
# ['Length: 21.5CM(8.46")', 'Width: 1.5CM(0.59")', 'Weight: 29.7g']
# ['29.7 gram']
# 29.7 gram
# 6570
# [2024/09/14 17:45:55] ppocr DEBUG: dt_boxes num : 26, elapsed : 0.08442926406860352
# [2024/09/14 17:45:55] ppocr DEBUG: cls num  : 26, elapsed : 0.10581517219543457
# [2024/09/14 17:45:56] ppocr DEBUG: rec_res num  : 26, elapsed : 1.3508150577545166
# ['8SSP50A', 'us', 'E131875', 'R3567', 'PC9059', 'CUSTOMERELOG', '6FRU54Y8888', 'LCPN36200496', 'LPNSP50A33585', 'AC NPUT', '200-240V50/60Hz3.0A', '45080-513-0', 'TOTAL', 'DC OUTPUT ', '+5.08V', 'FIOW', '+12.0V', '2.0A', 'XM', '+5.08Vsb=', 'TOTAL 180WMAX.1/1W', 'MADE N CHNA']
# []
# 6571
# [2024/09/14 17:45:56] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.1351933479309082
# [2024/09/14 17:45:56] ppocr DEBUG: cls num  : 3, elapsed : 0.015591859817504883
# [2024/09/14 17:45:57] ppocr DEBUG: rec_res num  : 3, elapsed : 0.1726994514465332
# ['Crushed Red Pepper', 'DOUBLE', 'CUT']
# []
# 6572
# [2024/09/14 17:45:57] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.13838958740234375
# [2024/09/14 17:45:57] ppocr DEBUG: cls num  : 13, elapsed : 0.060364484786987305
# [2024/09/14 17:45:58] ppocr DEBUG: rec_res num  : 13, elapsed : 0.6690559387207031
# ['MAXWELL', 'HOUSE', 'INTERNATIONAL', 'VANILLA CARAMEL', 'MAKESABOUT', '.16', 'latte', 'SERVINGS', '60', 'NET WT 8.7 0Z (247g)', 'CAFE-STYLE BEVERAGE MIX']
# ['247 gram']
# 247 gram
# 6573
# [2024/09/14 17:45:58] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.12204766273498535
# [2024/09/14 17:45:58] ppocr DEBUG: cls num  : 6, elapsed : 0.019429445266723633
# [2024/09/14 17:45:58] ppocr DEBUG: rec_res num  : 6, elapsed : 0.23361802101135254
# ['JS', 'SPAM', '4-120ZCANS', '25%LESS SODIUM', 'NETWT4802', '3LBS/1.36kg']
# ['3 pound', '1.36 kilogram']
# 3 pound
# 6574
# [2024/09/14 17:45:58] ppocr DEBUG: dt_boxes num : 18, elapsed : 0.1590595245361328
# [2024/09/14 17:45:58] ppocr DEBUG: cls num  : 18, elapsed : 0.03922295570373535
# [2024/09/14 17:46:00] ppocr DEBUG: rec_res num  : 18, elapsed : 1.4132132530212402
# ['ENERGYGUIDE', 'Estimated', 'Airflow', 'Yearly Energy Cost', '2,478', '$5', 'Cubic Feet Per Minute', 'The higher the airflow, the', '$34', 'more air the fan will move', 'Airflow Efficiency:128 Cubic', 'Cost Range of Similar Models 19-84', 'Feet Per Minute Per Watt', 'Based on 12 cents per kWh and 6.4 hours use per day', 'Your cost depends on rates and use', 'Energy Use:19 Watts', 'All estimates based on typical use, excluding lights', 'ftc.gov/energy']
# []
# 6575
# [2024/09/14 17:46:00] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.10080671310424805
# [2024/09/14 17:46:00] ppocr DEBUG: cls num  : 5, elapsed : 0.03620028495788574
# [2024/09/14 17:46:00] ppocr DEBUG: rec_res num  : 5, elapsed : 0.30141663551330566
# ["CURLY'S", 'PULLEDPORK', 'NET WT 16OZ.1LB.', 'LUTEN FREE', 'MIEITE']
# ['16 ounce', '1 pound']
# 16 ounce
# 6576
# [2024/09/14 17:46:00] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.14889192581176758
# [2024/09/14 17:46:00] ppocr DEBUG: cls num  : 6, elapsed : 0.019858360290527344
# [2024/09/14 17:46:01] ppocr DEBUG: rec_res num  : 6, elapsed : 0.2454991340637207
# ['0Lumary', '56', '15', 'Dreamcolor', 'Lumary Smart', 'String Light']
# []
# 6577
# [2024/09/14 17:46:01] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.08722400665283203
# [2024/09/14 17:46:01] ppocr DEBUG: cls num  : 9, elapsed : 0.05751466751098633
# [2024/09/14 17:46:02] ppocr DEBUG: rec_res num  : 9, elapsed : 0.8563134670257568
# ...
# [2024/09/14 17:58:18] ppocr DEBUG: cls num  : 19, elapsed : 0.05283164978027344
# [2024/09/14 17:58:18] ppocr DEBUG: rec_res num  : 19, elapsed : 0.679926872253418
# ['Jes nd', '200W', 'GENERATOR', 'NOICATOR', 'Jesnd', 'ENGSW', 'AC RESET', '120PE T', '2-STROKE GENERATOR', 'L', 'O', 'DCRESET', 'AC 120', 'OCRV']
# []
# 7207
# [2024/09/14 17:58:19] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.06987810134887695
# [2024/09/14 17:58:19] ppocr DEBUG: cls num  : 8, elapsed : 0.05292224884033203
# [2024/09/14 17:58:19] ppocr DEBUG: rec_res num  : 8, elapsed : 0.5407507419586182
# ['3ft./90cm.', '2ft.', '60cm.', 'Soft Polypropylene Yarn', 'Hand Carved Pattern Accents', 'Dimensions:2\'x30.4"Pile Height', '0.4Height']
# []
# 7208
# [2024/09/14 17:58:19] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.16412997245788574
# [2024/09/14 17:58:19] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2024/09/14 17:58:19] ppocr DEBUG: rec_res num  : 0, elapsed : 1.9073486328125e-06
# An error occurred: 'NoneType' object is not iterable
# []
# []
# 7209
# [2024/09/14 17:58:20] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.15215206146240234
# [2024/09/14 17:58:20] ppocr DEBUG: cls num  : 5, elapsed : 0.04084920883178711
# [2024/09/14 17:58:20] ppocr DEBUG: rec_res num  : 5, elapsed : 0.37562084197998047
# ['X-LARGE', '120L7325cn', '31.513.515.75/80.3440cm', '2bs7oz/1.11g', 'eaglecreek']
# ['7 ounce', '1.11 gram']
# 7 ounce
# 7210
# [2024/09/14 17:58:20] ppocr DEBUG: dt_boxes num : 73, elapsed : 0.15180683135986328
# [2024/09/14 17:58:20] ppocr DEBUG: cls num  : 73, elapsed : 0.1802055835723877
# [2024/09/14 17:58:24] ppocr DEBUG: rec_res num  : 73, elapsed : 3.9257917404174805
# ['12%TEXTUREDALL STOCK FEED', 'NOADDEDCOPPER', 'A complete textured feed formulated for weaned catfile on pasture,', 'equines, and all classes of sheep and goats', 'PRODUCTCOOE:T920.S-50.bag', 'GUARANTEED ANALYSIS:', 'Aabiea.gas T920', 'CraleFa(Min', 'Crude Protein (Min.)', '1200%', 'Crale Fibe (M)', '.400%', 'FEEDING DIRECTIONS:', 'ADF()', 'Fend Sw Coty 12 AllStok a a ne o  2 af', 'NDF (MaK.)', 'Calcium (Ca) (Min.)', '3200%', 'ma ogh per dyThe ot f SeeCy', 'Calciun (Ca) (dac.)', '2 Sk eng fed cn y dnng on ', '05%', '12%', 'remal body: er', 'Salt (NCl (Mex)', 'Poteniam (K)-Min)', 'L00%', 'dod ferdr', 'Phesphorus (P(Mn', '1.0%', 'ds Mals s feadirg chee', 'day ovr s perd', 'Zeo (Zn) (in)', '04%', 'I te 2 woeix Aruimals should be Sed Swort Country 12%', 'All Stock set Seart beice diely at negade, evem intervab.', 'ViumnA(Mn.', 'cknium (Se) (Min).', 'Street Cousiry 32% All Sxock tbedd be purt of s balanced', 'Vsamin D (dn.)', 'L000RU', 'oleaire', 'INGREDIENTS:', ' all nes w t', 'Craked Can, Whole R', 'ed Oens, Proxessed Grain', 'Free-chirpecis spprprir e minedst', 'need to be rhr gd', 'A minnun af 1 gh in hy  p', 'Phoerhunte', 'Sugpknene', 'Morccelciurn', 'Vnann E', 'Sugo', 'Phopbate', 'Vitamin', 'Suppknens,', 'yeoun', 'SufaZn', 'Sutfate', 'Vamin K AcvityPropic Ad. Thiamine', 'Meadicre', 'Sodiam Bisdfine Conpkex', 'Sorce', 'Monontrae Pyndone Hydrochride d Sod', 'Seanine', 'PRODUCT REFERENCE']
# []
# 7211
# [2024/09/14 17:58:25] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.16440939903259277
# [2024/09/14 17:58:25] ppocr DEBUG: cls num  : 10, elapsed : 0.05674910545349121
# [2024/09/14 17:58:25] ppocr DEBUG: rec_res num  : 10, elapsed : 0.4839904308319092
# ['50Z', 'VALLEY', 'FRESH', 'Organic', 'RIBMEAT', 'Chicken Breast IN wATER', 'NETWT502142']
# []
# 7212
# [2024/09/14 17:58:25] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.07767558097839355
# [2024/09/14 17:58:25] ppocr DEBUG: cls num  : 6, elapsed : 0.023262500762939453
# [2024/09/14 17:58:26] ppocr DEBUG: rec_res num  : 6, elapsed : 0.34218549728393555
# ['FostedCocounit', 'Darktudge', 'Newtons', 'fruitTHINS', 'CRISPYC00KIESNETWT8.750Z248g']
# ['248 gram']
# 248 gram
# 7213
# [2024/09/14 17:58:26] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.08104419708251953
# [2024/09/14 17:58:26] ppocr DEBUG: cls num  : 15, elapsed : 0.06824541091918945
# [2024/09/14 17:58:26] ppocr DEBUG: rec_res num  : 15, elapsed : 0.6172659397125244
# ['Misamar', 'Midamar', 'Campfire Grillers', 'Campfire Grillers', 'loxedBee/Frank', 'Midamar', 'Midamar', 'Campfire Grillers', 'Campfire Grillers', 'Midamar', 'Midamar', 'Campfire Grillers', 'Campfire Grillers', 'ETWT120340', 'NETWT1202 (340g']
# ['340 gram']
# 340 gram
# 7214
# [2024/09/14 17:58:27] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.14905333518981934
# [2024/09/14 17:58:27] ppocr DEBUG: cls num  : 4, elapsed : 0.01947808265686035
# [2024/09/14 17:58:27] ppocr DEBUG: rec_res num  : 4, elapsed : 0.20067119598388672
# ['Power Adapter', 'USB Cable', 'OTG Cable', 'User Manual']
# []
# 7215
# [2024/09/14 17:58:27] ppocr DEBUG: dt_boxes num : 20, elapsed : 0.13431596755981445
# [2024/09/14 17:58:27] ppocr DEBUG: cls num  : 20, elapsed : 0.08955669403076172
# [2024/09/14 17:58:29] ppocr DEBUG: rec_res num  : 20, elapsed : 1.4288418292999268
# ['ENERGYINFORMATION', 'DOWNROD MOUNT', 'ENERGYGUIDE', 'Estimated', 'Airflow', 'Yearly Energy Cost', '3,810', '$5', 'Cubic Feet Per Minute', 'The higher the airflow, the', '1 $34', 'more air the fan will move', 'Airflow Efficiency:200Cubic', 'Cost Range of Similar Models19-84', 'Feet Per Minute Per Watt', 'Based on 12 cents per kWh and 6.4 hours use per day', 'Your cost depends on rates and use', 'EnergyUse:19watts', 'All estimates based on typical use,excluding lights', 'ftc.gov/energy']
# []
# 7216
# [2024/09/14 17:58:29] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.303450345993042
# [2024/09/14 17:58:29] ppocr DEBUG: cls num  : 3, elapsed : 0.037674903869628906
# [2024/09/14 17:58:29] ppocr DEBUG: rec_res num  : 3, elapsed : 0.28691959381103516
# ['15lbs Kids Children Bow.', 'Fits both left and right hands', '17']
# ['15 pound']
# 15 pound
# 7217
# [2024/09/14 17:58:29] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.1628706455230713
# [2024/09/14 17:58:30] ppocr DEBUG: cls num  : 5, elapsed : 0.04314851760864258
# [2024/09/14 17:58:30] ppocr DEBUG: rec_res num  : 5, elapsed : 0.23312163352966309
# ['Dimensions:', 'Weight:6 lbs.', '20.25"', '11.75"', '5.9']
# ['6 pound']
# 6 pound
# 7218
# [2024/09/14 17:58:30] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.08318781852722168
# [2024/09/14 17:58:30] ppocr DEBUG: cls num  : 5, elapsed : 0.020000457763671875
# [2024/09/14 17:58:31] ppocr DEBUG: rec_res num  : 5, elapsed : 0.7437572479248047
# ['ZTE Star 1', 'RAM:2GB+ROM:16GB', 'MSM8928 Quad Core 1.6GHzGPU:Adreno305', '5.0 inch 4GAndroid 4.4 Smart Phone', '-']
# []
# 7219
# [2024/09/14 17:58:31] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.08122420310974121
# [2024/09/14 17:58:31] ppocr DEBUG: cls num  : 1, elapsed : 0.039193153381347656
# [2024/09/14 17:58:31] ppocr DEBUG: rec_res num  : 1, elapsed : 0.09903264045715332
# ['1500W']
# []
# 7220
# [2024/09/14 17:58:31] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.07855916023254395
# [2024/09/14 17:58:31] ppocr DEBUG: cls num  : 6, elapsed : 0.04619097709655762
# [2024/09/14 17:58:32] ppocr DEBUG: rec_res num  : 6, elapsed : 0.5612192153930664
# ['2 D-Shape Heavy Duty Carabiners', '29-ft Ropes,18+1Loops', 'Dimension:8.5x4.6 ft.', 'Weight Capacity:400 lbs', 'Dimension:4 x8 inches', 'The Whole Package Weight 1.5 lbs']
# ['400 pound', '1.5 pound']
# 400 pound
# 7221
# [2024/09/14 17:58:32] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.134901762008667
# [2024/09/14 17:58:32] ppocr DEBUG: cls num  : 12, elapsed : 0.03441596031188965
# [2024/09/14 17:58:32] ppocr DEBUG: rec_res num  : 12, elapsed : 0.5076925754547119
# ['HEST', '100%', 'USA', 'N THE', 'CCARLYLE', 'MAITAKE', 'MUSHROOM', '1600MG', 'pufer.tee', '007', '000', 'GMP']
# ['1600 milligram']
# 1600 milligram
# 7222
# [2024/09/14 17:58:33] ppocr DEBUG: dt_boxes num : 27, elapsed : 0.0857095718383789
# [2024/09/14 17:58:33] ppocr DEBUG: cls num  : 27, elapsed : 0.08980941772460938
# [2024/09/14 17:58:34] ppocr DEBUG: rec_res num  : 27, elapsed : 1.1287274360656738
# ['imapop of color and touchof', 'New!', ' sprinkle Del Monte', 'ene Beets on a variety of', 'your favorite foods:', 'SALADS', 'ON', 'spinachslawcarrot', 'quinoabroccoli', 'OF', 'uscouscottage cheese', 'SANDWICHES', 'MAI', '.urgrs,pitas,tacos', 'DIPS', 'tummus,French onion', ' .23n', 'JuLl', 'VSIT US AT: www.delmonte.com', '24000-24592', 'NETWVA150', 'PLEASE RECYCLE']
# []
# 7223
# [2024/09/14 17:58:34] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.1364123821258545
# [2024/09/14 17:58:34] ppocr DEBUG: cls num  : 9, elapsed : 0.034339189529418945
# [2024/09/14 17:58:34] ppocr DEBUG: rec_res num  : 9, elapsed : 0.3969545364379883
# ['DRY CURED', 'BURGERS', 'NOXADER', '-SMOKEHOUSE:', 'SLICED TEMPTATION', 'APPLE WOOD', 'BACON', 'SMOKET', 'NETWL.160Z.1L0.']
# []
# 7224
# [2024/09/14 17:58:35] ppocr DEBUG: dt_boxes num : 17, elapsed : 0.08235549926757812
# [2024/09/14 17:58:35] ppocr DEBUG: cls num  : 17, elapsed : 0.06936478614807129
# [2024/09/14 17:58:36] ppocr DEBUG: rec_res num  : 17, elapsed : 0.8363776206970215
# ['BETTER THAN', 'BOUILLON', 'BETTER THAN', 'BOUILLON', 'BETTER THAN', 'BOUILLON', '38', 'SERMPIGS', 'THAN', 'BETTER', 'Serving', 'Net Wt', 'uogsa6ons', '8oz2', 'MADE WITH ROASTED TURKEY']
# []
# 7225
# [2024/09/14 17:58:36] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.07850003242492676
# [2024/09/14 17:58:36] ppocr DEBUG: cls num  : 5, elapsed : 0.018886804580688477
# [2024/09/14 17:58:36] ppocr DEBUG: rec_res num  : 5, elapsed : 0.21994829177856445
# ['18W Total', 'Energy Saving', '25000Hrs', 'Lifespan']
# []
# 7226
# [2024/09/14 17:58:36] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.08107233047485352
# [2024/09/14 17:58:36] ppocr DEBUG: cls num  : 15, elapsed : 0.0441129207611084
# [2024/09/14 17:58:37] ppocr DEBUG: rec_res num  : 15, elapsed : 0.6658868789672852
# ['Spark plug', 'Recoil starter', 'maintenance cover', 'Oil drain plug', 'Fuel tank cap', 'Ventilation knob', 'Muffler', 'blind window', 'Telescoping Handle', 'M', 'Air filter', 'maintenance cover', 'Muffler', 'Control Panel', 'Combination switch']
# []
# 7227
# [2024/09/14 17:58:37] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.08441495895385742
# [2024/09/14 17:58:37] ppocr DEBUG: cls num  : 7, elapsed : 0.05593466758728027
# [2024/09/14 17:58:37] ppocr DEBUG: rec_res num  : 7, elapsed : 0.3064546585083008
# ['SIZE', 'CHART', '20Luggage:6 lbs.', '1-4Days Trip', '20', '13"', '9.2']
# ['6 pound']
# 6 pound
# 7228
# [2024/09/14 17:58:38] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.16008424758911133
# [2024/09/14 17:58:38] ppocr DEBUG: cls num  : 2, elapsed : 0.03571486473083496
# [2024/09/14 17:58:38] ppocr DEBUG: rec_res num  : 2, elapsed : 0.12477684020996094
# ['TNTE']
# []
# 7229
# [2024/09/14 17:58:38] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.16555476188659668
# [2024/09/14 17:58:38] ppocr DEBUG: cls num  : 23, elapsed : 0.09138107299804688
# [2024/09/14 17:58:39] ppocr DEBUG: rec_res num  : 23, elapsed : 1.039466142654419
# ['C@rmation', 'reakfast', 'ByThe', 'CUP', 'ESSENTIALS', '14Sery', 'NutritionalDrink Mix', 'CALCIUM', 'VITAMIND', 'ZX', '13g', 'PROTEIN', 'Rich Milk Chocolate', 'NO', 'PONDER DRNKMEX', 'ATURAFLAVORWT OTHER NATURALFLAVORS', 'ARTIFICA', 'FLAVORS', 'ETW17.70118/52o', '/SWEEEe']
# ['13 gram']
# 13 gram
# 7230
# [2024/09/14 17:58:39] ppocr DEBUG: dt_boxes num : 19, elapsed : 0.08843135833740234
# [2024/09/14 17:58:39] ppocr DEBUG: cls num  : 19, elapsed : 0.05781221389770508
# [2024/09/14 17:58:40] ppocr DEBUG: rec_res num  : 19, elapsed : 0.6992433071136475
# ['EHM', 'SE', "LEHMAN'S", 'FORASIMP', 'CHIC', 'ALL NAT', 'HEAT&', 'FOR A SIMPLER LIFE', 'HEAT', 'SERVE', 'EN', 'ALL NATURAL', 'SERVE', 'CHICKEN', 'FULLY CO', 'FULLY COOKED', 'SO2', 'JEHM']
# []
# 7231
# [2024/09/14 17:58:40] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.09381985664367676
# [2024/09/14 17:58:40] ppocr DEBUG: cls num  : 10, elapsed : 0.06526970863342285
# [2024/09/14 17:58:41] ppocr DEBUG: rec_res num  : 10, elapsed : 0.515235185623169
# ['oUrs', 'ans', 'RRECOOL', '300W', 'G301', 'Ox']
# []
# 7232
# [2024/09/14 17:58:41] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.08923196792602539
# [2024/09/14 17:58:41] ppocr DEBUG: cls num  : 23, elapsed : 0.062035322189331055
# [2024/09/14 17:58:42] ppocr DEBUG: rec_res num  : 23, elapsed : 0.9977061748504639
# ['Carnation', 'reakfast', '5', '14Ser', 'ESSENTIALS', '2x', 'Complete Nutritional Drink', 'VITAMIND', '2x', 'CALCIUM', 'OFYOGORT', '21', '13g', 'VITAMINS&', 'MINERALS', 'F9', 'PROTEIN', 'Rich Milk Chocolate', 'Naturally&Artificially Flavored PowderDrinkMix', 'NETWT17.70Z (1.1LB)']
# ['13 gram', '1.1 pound']
# 13 gram
# 7233
# [2024/09/14 17:58:42] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.33073854446411133
# [2024/09/14 17:58:42] ppocr DEBUG: cls num  : 9, elapsed : 0.05734872817993164
# [2024/09/14 17:58:43] ppocr DEBUG: rec_res num  : 9, elapsed : 0.42357444763183594
# ['Thickness :', 'weight:', '17mm', '0.48kg', '300mm', '210mm', 'SWOMON']
# ['0.48 kilogram']
# 0.48 kilogram
# 7234
# [2024/09/14 17:58:43] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.08220767974853516
# [2024/09/14 17:58:43] ppocr DEBUG: cls num  : 11, elapsed : 0.035642147064208984
# [2024/09/14 17:58:43] ppocr DEBUG: rec_res num  : 11, elapsed : 0.4267997741699219
# ['Nutter', 'Butter', 'peanut butter', 'sandwich coohies', 'PER2COOKES', 'REAL', '1200', 'peanut butter', 'oNETWT11.8OZ(334g)']
# ['11.8 ounce', '334 gram']
# 334 gram
# 7235
# [2024/09/14 17:58:44] ppocr DEBUG: dt_boxes num : 18, elapsed : 0.1351926326751709
# [2024/09/14 17:58:44] ppocr DEBUG: cls num  : 18, elapsed : 0.045472145080566406
# [2024/09/14 17:58:44] ppocr DEBUG: rec_res num  : 18, elapsed : 0.7220063209533691
# ['Schogetten', 'Schogetten', 'Schogetten', 'Schogette', 'Alpine Milk Chocolate', 'Alpine Milk Chocolote with', 'Dark Chocolate filled with', 'Hozelnuts', 'Cocoo CreomCocoo Ns ond Hozts', 'Dark Chocolate', '18pieces', "18'pieces", '18pieces', '18pieces', 'NETWT3.50Z(100g)', 'NETWT3.50Z (100g)', 'NET WT3.5OZ(100g', 'NETWT3.5OZ(100g']
# ['100 gram', '100 gram', '3.5 ounce', '100 gram', '3.5 ounce', '100 gram']
# 100 gram
# 7236
# [2024/09/14 17:58:45] ppocr DEBUG: dt_boxes num : 21, elapsed : 0.0871284008026123
# [2024/09/14 17:58:45] ppocr DEBUG: cls num  : 21, elapsed : 0.05903434753417969
# [2024/09/14 17:58:47] ppocr DEBUG: rec_res num  : 21, elapsed : 2.1148500442504883
# ['AYURVEDA', 'NXTGEN', 'Ashwagandha or Indian ginseng is the spine of Ayurveda, too good in', 'chronic diseases like arthritis, Insomnia, asthma, tuberculosis,backache', 'Ashwagandha gives power and energy to the person from inside', 'Improves your muscle strength.', '(Ingredients:100% Natural powdered Ashwagandha roots', 'fssai', 'Packed by', 'Oilcure Health & Beauty', 'LicenseNo:11218334001554', '34/4,10th A Main,Devarachikkanahalli', 'Main Road,Bangalore-560068', 'www.oilcure.com', 'Batch No:', 'customercare@oilcure.com', 'Pkd.Date', 'MRP', 'Net.Weight:250gm (when packed', '(Best before 18 months from packing date)', '8907981000543']
# ['250 gram']
# 250 gram
# 7237
# [2024/09/14 17:58:47] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.08244514465332031
# [2024/09/14 17:58:47] ppocr DEBUG: cls num  : 11, elapsed : 0.05492901802062988
# [2024/09/14 17:58:48] ppocr DEBUG: rec_res num  : 11, elapsed : 0.736870288848877
# ['MINI', 'WiFi', 'Smart CarDVR', 'TOLL', 'Niqht vision FHD 1080P Cyclye recrding G-Sensor lock', 'WIFI Hotsopt', 'APP Share', 'Wide-Angle']
# []
# 7238
# [2024/09/14 17:58:48] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.08529162406921387
# [2024/09/14 17:58:48] ppocr DEBUG: cls num  : 10, elapsed : 0.05583071708679199
# [2024/09/14 17:58:48] ppocr DEBUG: rec_res num  : 10, elapsed : 0.41710376739501953
# ["ERIN BAKER'S", 'TheOriginal', 'BREAKFAST', 'COOKIE', 'BananaWalnut', 'FEED', 'KIDS', 'NET WT.3oz (85g)']
# ['3 ounce', '85 gram']
# 85 gram
# 7239
# [2024/09/14 17:58:49] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.33614563941955566
# [2024/09/14 17:58:49] ppocr DEBUG: cls num  : 3, elapsed : 0.038549184799194336
# [2024/09/14 17:58:49] ppocr DEBUG: rec_res num  : 3, elapsed : 0.5301978588104248
# ['AngeloYang', 'Compatible with Kirby Bags 205811, 204814, 204811, 204808.', 'Dust Bag Size L22.24 X W12in. weight 2oz']
# ['2 ounce']
# 2 ounce
# 7240
# [2024/09/14 17:58:49] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.08468508720397949
# [2024/09/14 17:58:50] ppocr DEBUG: cls num  : 5, elapsed : 0.019080400466918945
# [2024/09/14 17:58:50] ppocr DEBUG: rec_res num  : 5, elapsed : 0.2245008945465088
