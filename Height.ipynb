# %%
# !pip install paddlepaddle paddleocr
# Out:
# Collecting paddlepaddle
#   Downloading paddlepaddle-2.6.2-cp310-cp310-manylinux1_x86_64.whl.metadata (8.6 kB)
# Collecting paddleocr
#   Downloading paddleocr-2.8.1-py3-none-any.whl.metadata (19 kB)
# Collecting httpx (from paddlepaddle)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (9.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (4.4.2)
# Collecting astor (from paddlepaddle)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (3.3.0)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (3.20.3)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from paddleocr) (2.0.6)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from paddleocr) (0.23.2)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from paddleocr) (0.4.0)
# Collecting pyclipper (from paddleocr)
#   Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (9.0 kB)
# Collecting lmdb (from paddleocr)
#   Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.66.5)
# Collecting rapidfuzz (from paddleocr)
#   Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from paddleocr) (3.0.11)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from paddleocr) (6.0.2)
# Collecting python-docx (from paddleocr)
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.53.1)
# Collecting fire>=0.3.0 (from paddleocr)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from paddleocr) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr) (2.4.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->paddleocr) (2.6)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (2024.8.30)
# Collecting httpcore==1.* (from httpx->paddlepaddle)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (3.8)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->paddlepaddle)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (1.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (3.7.1)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (2.34.2)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (3.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (2024.8.30)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (0.4)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->paddleocr) (4.9.4)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->paddleocr) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (2.0.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->paddlepaddle) (1.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (2.8.2)
# Downloading paddlepaddle-2.6.2-cp310-cp310-manylinux1_x86_64.whl (126.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 MB 6.0 MB/s eta 0:00:00
# Downloading paddleocr-2.8.1-py3-none-any.whl (407 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.5/407.5 kB 15.6 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.5 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.7 MB/s eta 0:00:00
# Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 12.6 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (908 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 23.1 MB/s eta 0:00:00
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 12.5 MB/s eta 0:00:00
# Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 39.7 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.3 MB/s eta 0:00:00
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=b654108cafd71b46503aab8d59c0d4e4efcbc8e2268afab4c02994c075b77b8c
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# Installing collected packages: pyclipper, lmdb, rapidfuzz, python-docx, h11, fire, astor, httpcore, httpx, paddlepaddle, paddleocr
# Successfully installed astor-0.8.1 fire-0.6.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 lmdb-1.5.1 paddleocr-2.8.1 paddlepaddle-2.6.2 pyclipper-1.3.0.post5 python-docx-1.1.2 rapidfuzz-3.9.7

# %% [markdown]
# **1. Library Imports**
# <br/>
# Imports essential libraries for image manipulation (cv2, numpy, PIL), text extraction (paddleocr), and data handling (pandas). It also includes modules for mathematical operations (math), HTTP requests (requests), and regular expressions (re).

# %%
import cv2
import numpy as np
from paddleocr import PaddleOCR
import math
import requests
from io import BytesIO
from PIL import Image
import os
import pandas as pd
import gdown


import re

# %% [markdown]
# **2. Unit Mapping Function**
# <br/>
# The map_to_length_unit() function standardizes various representations of length units to a consistent format, such as converting "cm" to "centimeter" and "mm" to "millimeter".

# %%
def map_to_length_unit(unit):
    length_units = {
        "centimetre": "centimeter",
        "cm": "centimeter",
        "millimetre": "millimeter",
        "mm": "millimeter",
        "metre": "meter",
        "m": "meter",
        "inch": "inch",
        "i": "inch",
        "in": "inch",
        "foot": "foot",
        "ft": "foot",
        "yard": "yard",
        "yd": "yard",
        "feet": "foot",
        "yds": "yard"
    }

    clean_unit = re.sub(r'[.,:/\\]', '', unit).strip().lower()
    return length_units.get(clean_unit, unit)

# %% [markdown]
# **3. PaddleOCR Initialization**
# <br/>
# PaddleOCR is initialized to perform OCR tasks. It is configured with angle classification and English language support, suitable for extracting text from images.

# %%
ocr = PaddleOCR(use_angle_cls=True, lang='en')

# %% [markdown]
# **4. Image Conversion Function**
# <br/>
# The url_to_image() function downloads an image from a provided URL, converts it to RGB format using PIL, and then converts it to an OpenCV-compatible BGR format for further processing.

# %%
def url_to_image(url):
    response = requests.get(url)
    image = Image.open(BytesIO(response.content)).convert('RGB')
    open_cv_image = np.array(image)
    return cv2.cvtColor(open_cv_image, cv2.COLOR_RGB2BGR)

# %% [markdown]
# **5. Vertical Line Detection**
# <br/>
# The detect_vertical_lines() function identifies vertical lines in the image using edge detection and Hough Line Transform techniques. It returns a list of vertical lines with their midpoints and lengths.

# %%
def detect_vertical_lines(image):
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray_image, 50, 150, apertureSize=3)
    lines = cv2.HoughLinesP(edges, 1, np.pi / 180, 100, minLineLength=100, maxLineGap=10)

    vertical_lines = []

    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            if abs(x1 - x2) < 10:
                line_length = abs(y2 - y1)
                x_mid = (x1 + x2) / 2
                y_mid = (y1 + y2) / 2
                vertical_lines.append((x_mid, y_mid, line_length, x1, y1, x2, y2))

    return vertical_lines

# %% [markdown]
# **6. Text Extraction with Coordinates**
# <br/>
# The extract_text_with_coordinates() function extracts text from an image using PaddleOCR and calculates the center coordinates of each text bounding box.

# %%
def extract_text_with_coordinates(image):
    result = ocr.ocr(image)

    text_coordinates = []
    for line in result:
        for word_info in line:
            text = word_info[1][0]
            coordinates = word_info[0]
            x_center = (coordinates[0][0] + coordinates[2][0]) / 2
            y_center = (coordinates[0][1] + coordinates[2][1]) / 2
            text_coordinates.append((text, x_center, y_center))

    return text_coordinates

# %% [markdown]
# **7. Distance Calculation**
# <br/>
# The calculate_distance() function computes the Euclidean distance between two points in the image. This is used to measure the proximity between text and detected vertical lines.

# %%
def calculate_distance(point1, point2):
    x1, y1 = point1
    x2, y2 = point2
    return math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

# %% [markdown]
# **8. Minimum Distance Text Finder**
# <br/>
# The find_minimum_distance_text() function finds the text closest to any detected vertical line. It considers both the distance and the length of the vertical lines to determine the closest text.

# %%
def find_minimum_distance_text(image):
    vertical_lines_midpoints = detect_vertical_lines(image)
    if not vertical_lines_midpoints:
        return None, None

    text_coordinates = extract_text_with_coordinates(image)
    min_distance = float('inf')
    closest_text = None
    closest_line_length = -1
    for text, x_text, y_text in text_coordinates:
        distances_to_lines = []
        for x_line_mid, y_line_mid, line_length, _, _, _, _ in vertical_lines_midpoints:
            distance = calculate_distance((x_text, y_text), (x_line_mid, y_line_mid))
            distances_to_lines.append((distance, line_length))
        distances_to_lines.sort(key=lambda d: (-d[1], d[0]))
        best_distance, best_line_length = distances_to_lines[0]
        if best_distance < min_distance or (best_distance == min_distance and best_line_length > closest_line_length):
            min_distance = best_distance
            closest_text = text
            closest_line_length = best_line_length

    return closest_text, min_distance

# %% [markdown]
# **9. Number and Text Extraction**
# <br/>
# The extract_number_and_text() function extracts a number and a text unit from an input string using regular expressions. It captures numeric values and associated units like "cm" or "inch".

# %%
def extract_number_and_text(input_string):
    pattern = r'(\d+(\.\d+)?)\s*([a-zA-Z]+)'
    match = re.search(pattern, input_string)

    if match:
        number = match.group(1)
        text = match.group(3)
        return number, text
    else:
        return None, None

# %% [markdown]
# **10. Main Processing Function**
# <br/>
# The get_vertical() function processes the image URL to find the closest text to vertical lines and extracts the number with its associated length unit. It then returns the formatted length measurement.

# %%
def get_vertical(image_url):
    image = url_to_image(image_url)

    closest_text, min_distance = find_minimum_distance_text(image)

    if closest_text:
        try:
            m, u = extract_number_and_text(closest_text)
            if u:
              fina = map_to_length_unit(u.strip())
              f = f"{m} {fina}"
              print(f)
              return f
        except ValueError:
            print("Text format is incorrect")
            return ""

# %% [markdown]
# **11. Prediction Function**
# <br/>
# The predictor() function calls get_horizontal() to process an image URL and obtain predictions. It is used for batch processing of images.
#
# **12. Save Predictions Function**
# <br/>
# The save_predictions() function saves or appends batch predictions to a CSV file. It ensures that predictions are properly written to the output file, handling both new and existing files.

# %%
i = 0
batch_size = 5

def predictor(url, category_id, entity_name):
    global i
    i += 1
    print(f"Processing {i}th image...")
    return get_horizontal(url)

def save_predictions(df):
    output_filename = os.path.join(DATASET_FOLDER, 'test_out.csv')

    # Check if the file exists; if not, create and write headers
    if not os.path.exists(output_filename):
        df[['index', 'prediction']].to_csv(output_filename, index=False, mode='w', header=True)
    else:
        df[['index', 'prediction']].to_csv(output_filename, index=False, mode='a', header=False)

    print(f"Batch predictions appended to {output_filename}")

if __name__ == "__main__":
    DATASET_FOLDER = 'dataset'

    # Create dataset folder if it doesn't exist
    if not os.path.exists(DATASET_FOLDER):
        os.makedirs(DATASET_FOLDER)

    # Download a sample CSV file
    height = '1wDYH_D-S3WhkSZ_pudlEe9OR86d79JZT'
    width = '1RPn7I70mlus2OV1-cAh7pRsrtcana7C8'
    url = f'https://drive.google.com/uc?id={height}'
    output_file = 'downloaded_file.csv'
    gdown.download(url, output_file, quiet=False)

    print(f"File downloaded and saved as {output_file}")

    # Load and process the CSV file
    test = pd.read_csv('downloaded_file.csv', nrows=13000)

    # Prepare to save predictions in batches
    test['prediction'] = None
    num_rows = len(test)

    for start in range(0, num_rows, batch_size):
        end = min(start + batch_size, num_rows)
        batch = test.iloc[start:end]

        # Apply the predictor function to each row of the batch
        batch['prediction'] = batch.apply(lambda row: predictor(row['image_link'], row['group_id'], row['entity_name']), axis=1)

        # Save the batch predictions to the same file
        save_predictions(batch)

    # In case there are rows left with missing predictions
    remaining = test[test['prediction'].isna()]
    if not remaining.empty:
        save_predictions(remaining)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1wDYH_D-S3WhkSZ_pudlEe9OR86d79JZT
# To: /content/downloaded_file.csv
# 100%|██████████| 2.32M/2.32M [00:00<00:00, 151MB/s]
# File downloaded and saved as downloaded_file.csv
# Processing 1th image...
# Processing 2th image...
# Processing 3th image...
# Processing 4th image...
# Processing 5th image...
# [2024/09/15 08:59:57] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.4040226936340332
# [2024/09/15 08:59:57] ppocr DEBUG: cls num  : 3, elapsed : 0.017586946487426758
# [2024/09/15 08:59:57] ppocr DEBUG: rec_res num  : 3, elapsed : 0.1402435302734375
# 15 centimeter
# Batch predictions appended to dataset/test_out.csv
# Processing 6th image...
# Processing 7th image...
# [2024/09/15 08:59:57] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.1260673999786377
# [2024/09/15 08:59:57] ppocr DEBUG: cls num  : 2, elapsed : 0.02766704559326172
# [2024/09/15 08:59:57] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11901569366455078
# 14 centimeter
# Processing 8th image...
# Processing 9th image...
# Processing 10th image...
# [2024/09/15 08:59:58] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.22827696800231934
# [2024/09/15 08:59:58] ppocr DEBUG: cls num  : 4, elapsed : 0.043576955795288086
# [2024/09/15 08:59:58] ppocr DEBUG: rec_res num  : 4, elapsed : 0.5711460113525391
# 122 centimeter
# Batch predictions appended to dataset/test_out.csv
# Processing 11th image...
# [2024/09/15 08:59:59] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.1459038257598877
# [2024/09/15 08:59:59] ppocr DEBUG: cls num  : 6, elapsed : 0.050115346908569336
# [2024/09/15 09:00:00] ppocr DEBUG: rec_res num  : 6, elapsed : 0.8734252452850342
# 60 centimeter
# Processing 12th image...
# Processing 13th image...
# [2024/09/15 09:00:00] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.1653292179107666
# [2024/09/15 09:00:00] ppocr DEBUG: cls num  : 4, elapsed : 0.023038148880004883
# [2024/09/15 09:00:00] ppocr DEBUG: rec_res num  : 4, elapsed : 0.2780280113220215
# 90 centimeter
# Processing 14th image...
# [2024/09/15 09:00:00] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.14558148384094238
# [2024/09/15 09:00:00] ppocr DEBUG: cls num  : 5, elapsed : 0.059162139892578125
# [2024/09/15 09:00:01] ppocr DEBUG: rec_res num  : 5, elapsed : 0.3931732177734375
# 19 centimeter
# Processing 15th image...
# [2024/09/15 09:00:01] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.5732438564300537
# [2024/09/15 09:00:01] ppocr DEBUG: cls num  : 3, elapsed : 0.021656036376953125
# [2024/09/15 09:00:02] ppocr DEBUG: rec_res num  : 3, elapsed : 0.15932750701904297
# 280 millimeter
# Batch predictions appended to dataset/test_out.csv
# Processing 16th image...
# Processing 17th image...
# [2024/09/15 09:00:02] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.09819507598876953
# [2024/09/15 09:00:02] ppocr DEBUG: cls num  : 2, elapsed : 0.01615595817565918
# [2024/09/15 09:00:02] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10537934303283691
# 10 centimeter
# Processing 18th image...
# Processing 19th image...
# Processing 20th image...
# Batch predictions appended to dataset/test_out.csv
# Processing 21th image...
# Processing 22th image...
# [2024/09/15 09:00:02] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.16696429252624512
# [2024/09/15 09:00:02] ppocr DEBUG: cls num  : 3, elapsed : 0.01271200180053711
# [2024/09/15 09:00:03] ppocr DEBUG: rec_res num  : 3, elapsed : 0.14205265045166016
# Processing 23th image...
# [2024/09/15 09:00:03] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.4064595699310303
# [2024/09/15 09:00:03] ppocr DEBUG: cls num  : 2, elapsed : 0.010537862777709961
# [2024/09/15 09:00:03] ppocr DEBUG: rec_res num  : 2, elapsed : 0.15993285179138184
# 12.5 centimeter
# Processing 24th image...
# Processing 25th image...
# [2024/09/15 09:00:03] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.10114717483520508
# [2024/09/15 09:00:04] ppocr DEBUG: cls num  : 8, elapsed : 0.05465102195739746
# [2024/09/15 09:00:04] ppocr DEBUG: rec_res num  : 8, elapsed : 0.4578101634979248
# 37 inch
# Batch predictions appended to dataset/test_out.csv
# Processing 26th image...
# [2024/09/15 09:00:04] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.2920701503753662
# [2024/09/15 09:00:04] ppocr DEBUG: cls num  : 5, elapsed : 0.03936314582824707
# [2024/09/15 09:00:05] ppocr DEBUG: rec_res num  : 5, elapsed : 0.26912784576416016
# Processing 27th image...
# Processing 28th image...
# [2024/09/15 09:00:05] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.30515503883361816
# [2024/09/15 09:00:05] ppocr DEBUG: cls num  : 4, elapsed : 0.02162909507751465
# [2024/09/15 09:00:05] ppocr DEBUG: rec_res num  : 4, elapsed : 0.25407981872558594
# 60 centimeter
# Processing 29th image...
# [2024/09/15 09:00:06] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.3013899326324463
# [2024/09/15 09:00:06] ppocr DEBUG: cls num  : 4, elapsed : 0.012753963470458984
# [2024/09/15 09:00:06] ppocr DEBUG: rec_res num  : 4, elapsed : 0.20803093910217285
# 40 centimeter
# Processing 30th image...
# Batch predictions appended to dataset/test_out.csv
# Processing 31th image...
# [2024/09/15 09:00:06] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.16053390502929688
# [2024/09/15 09:00:06] ppocr DEBUG: cls num  : 4, elapsed : 0.014597654342651367
# [2024/09/15 09:00:07] ppocr DEBUG: rec_res num  : 4, elapsed : 0.1779494285583496
# 191 centimeter
# Processing 32th image...
# [2024/09/15 09:00:07] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.2933177947998047
# [2024/09/15 09:00:07] ppocr DEBUG: cls num  : 1, elapsed : 0.03356671333312988
# [2024/09/15 09:00:07] ppocr DEBUG: rec_res num  : 1, elapsed : 0.11287307739257812
# 25.6 inch
# Processing 33th image...
# [2024/09/15 09:00:07] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.30040836334228516
# [2024/09/15 09:00:07] ppocr DEBUG: cls num  : 2, elapsed : 0.010505914688110352
# [2024/09/15 09:00:08] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10533928871154785
# 20.0 centimeter
# Processing 34th image...
# [2024/09/15 09:00:08] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.30437397956848145
# [2024/09/15 09:00:08] ppocr DEBUG: cls num  : 3, elapsed : 0.018110036849975586
# [2024/09/15 09:00:08] ppocr DEBUG: rec_res num  : 3, elapsed : 0.17230010032653809
# 10 centimeter
# Processing 35th image...
# [2024/09/15 09:00:08] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.1879572868347168
# [2024/09/15 09:00:08] ppocr DEBUG: cls num  : 3, elapsed : 0.013133049011230469
# [2024/09/15 09:00:08] ppocr DEBUG: rec_res num  : 3, elapsed : 0.14252829551696777
# 29.95 centimeter
# Batch predictions appended to dataset/test_out.csv
# Processing 36th image...
# [2024/09/15 09:00:09] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.31041693687438965
# [2024/09/15 09:00:09] ppocr DEBUG: cls num  : 5, elapsed : 0.02115321159362793
# [2024/09/15 09:00:09] ppocr DEBUG: rec_res num  : 5, elapsed : 0.24846529960632324
# 14 centimeter
# Processing 37th image...
# [2024/09/15 09:00:10] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.2990391254425049
# [2024/09/15 09:00:10] ppocr DEBUG: cls num  : 2, elapsed : 0.010102510452270508
# [2024/09/15 09:00:10] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11536240577697754
# 90 centimeter
# Processing 38th image...
# [2024/09/15 09:00:10] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.13949131965637207
# [2024/09/15 09:00:10] ppocr DEBUG: cls num  : 3, elapsed : 0.011490583419799805
# [2024/09/15 09:00:10] ppocr DEBUG: rec_res num  : 3, elapsed : 0.1425025463104248
# 90 centimeter
# Processing 39th image...
# [2024/09/15 09:00:10] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.30309319496154785
# [2024/09/15 09:00:10] ppocr DEBUG: cls num  : 2, elapsed : 0.011680841445922852
# [2024/09/15 09:00:11] ppocr DEBUG: rec_res num  : 2, elapsed : 0.12796497344970703
# 7.86 inch
# Processing 40th image...
# Batch predictions appended to dataset/test_out.csv
# Processing 41th image...
# [2024/09/15 09:00:11] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.1301417350769043
# [2024/09/15 09:00:11] ppocr DEBUG: cls num  : 3, elapsed : 0.013010501861572266
# [2024/09/15 09:00:11] ppocr DEBUG: rec_res num  : 3, elapsed : 0.14024806022644043
# Processing 42th image...
# Processing 43th image...
# [2024/09/15 09:00:11] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.11638021469116211
# [2024/09/15 09:00:11] ppocr DEBUG: cls num  : 3, elapsed : 0.01396036148071289
# [2024/09/15 09:00:11] ppocr DEBUG: rec_res num  : 3, elapsed : 0.20090723037719727
# 82 centimeter
# Processing 44th image...
# [2024/09/15 09:00:12] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.2418208122253418
# [2024/09/15 09:00:12] ppocr DEBUG: cls num  : 2, elapsed : 0.039563894271850586
# [2024/09/15 09:00:12] ppocr DEBUG: rec_res num  : 2, elapsed : 0.15217971801757812
# Processing 45th image...
# [2024/09/15 09:00:12] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.45304059982299805
# [2024/09/15 09:00:13] ppocr DEBUG: cls num  : 2, elapsed : 0.021331787109375
# [2024/09/15 09:00:13] ppocr DEBUG: rec_res num  : 2, elapsed : 0.2107853889465332
# 1.1 inch
# Batch predictions appended to dataset/test_out.csv
# Processing 46th image...
# [2024/09/15 09:00:13] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.4558141231536865
# [2024/09/15 09:00:13] ppocr DEBUG: cls num  : 3, elapsed : 0.022040605545043945
# [2024/09/15 09:00:14] ppocr DEBUG: rec_res num  : 3, elapsed : 0.22302603721618652
# 5 centimeter
# Processing 47th image...
# [2024/09/15 09:00:14] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.44512343406677246
# [2024/09/15 09:00:14] ppocr DEBUG: cls num  : 2, elapsed : 0.02233719825744629
# [2024/09/15 09:00:14] ppocr DEBUG: rec_res num  : 2, elapsed : 0.2822420597076416
# 2.7 inch
# Processing 48th image...
# [2024/09/15 09:00:15] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.4764258861541748
# [2024/09/15 09:00:15] ppocr DEBUG: cls num  : 2, elapsed : 0.017096996307373047
# [2024/09/15 09:00:15] ppocr DEBUG: rec_res num  : 2, elapsed : 0.11734366416931152
# 61 centimeter
# Processing 49th image...
# [2024/09/15 09:00:15] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.30777955055236816
# [2024/09/15 09:00:16] ppocr DEBUG: cls num  : 4, elapsed : 0.019526958465576172
# [2024/09/15 09:00:16] ppocr DEBUG: rec_res num  : 4, elapsed : 0.20612406730651855
# Processing 50th image...
# [2024/09/15 09:00:16] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.1503150463104248
# [2024/09/15 09:00:16] ppocr DEBUG: cls num  : 3, elapsed : 0.013459920883178711
# [2024/09/15 09:00:16] ppocr DEBUG: rec_res num  : 3, elapsed : 0.1406083106994629
# 27.4 centimeter
# Batch predictions appended to dataset/test_out.csv
# Processing 51th image...
# [2024/09/15 09:00:16] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.2967793941497803
# [2024/09/15 09:00:16] ppocr DEBUG: cls num  : 1, elapsed : 0.04218482971191406
# [2024/09/15 09:00:17] ppocr DEBUG: rec_res num  : 1, elapsed : 0.1213371753692627
# 37.5 centimeter
# Processing 52th image...
# [2024/09/15 09:00:17] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.2939012050628662
# [2024/09/15 09:00:17] ppocr DEBUG: cls num  : 3, elapsed : 0.013153791427612305
# [2024/09/15 09:00:17] ppocr DEBUG: rec_res num  : 3, elapsed : 0.14245915412902832
# 13.2 inch
# Processing 53th image...
# [2024/09/15 09:00:18] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.18655157089233398
# [2024/09/15 09:00:18] ppocr DEBUG: cls num  : 6, elapsed : 0.04277539253234863
# [2024/09/15 09:00:18] ppocr DEBUG: rec_res num  : 6, elapsed : 0.31319379806518555
# 27.94 centimeter
# Processing 54th image...
# [2024/09/15 09:00:18] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.10141706466674805
# [2024/09/15 09:00:18] ppocr DEBUG: cls num  : 3, elapsed : 0.01685476303100586
# [2024/09/15 09:00:18] ppocr DEBUG: rec_res num  : 3, elapsed : 0.14478707313537598
# 128 centimeter
# Processing 55th image...
# [2024/09/15 09:00:19] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.30797481536865234
# [2024/09/15 09:00:19] ppocr DEBUG: cls num  : 5, elapsed : 0.04019594192504883
# [2024/09/15 09:00:19] ppocr DEBUG: rec_res num  : 5, elapsed : 0.2722008228302002
# Batch predictions appended to dataset/test_out.csv
# Processing 56th image...
# [2024/09/15 09:00:19] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.10039830207824707
# [2024/09/15 09:00:19] ppocr DEBUG: cls num  : 12, elapsed : 0.03640246391296387
# [2024/09/15 09:00:21] ppocr DEBUG: rec_res num  : 12, elapsed : 1.3597967624664307
# Processing 57th image...
# [2024/09/15 09:00:21] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.14186382293701172
# [2024/09/15 09:00:21] ppocr DEBUG: cls num  : 3, elapsed : 0.0139617919921875
# [2024/09/15 09:00:21] ppocr DEBUG: rec_res num  : 3, elapsed : 0.12408280372619629
# 43.18 centimeter
# Processing 58th image...
# [2024/09/15 09:00:21] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.30112624168395996
# [2024/09/15 09:00:21] ppocr DEBUG: cls num  : 3, elapsed : 0.0146636962890625
# [2024/09/15 09:00:22] ppocr DEBUG: rec_res num  : 3, elapsed : 0.12778639793395996
# 19.5 centimeter
# Processing 59th image...
# [2024/09/15 09:00:22] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.30916309356689453
# [2024/09/15 09:00:22] ppocr DEBUG: cls num  : 3, elapsed : 0.012746095657348633
# [2024/09/15 09:00:22] ppocr DEBUG: rec_res num  : 3, elapsed : 0.12862825393676758
# 60 centimeter
# Processing 60th image...
# [2024/09/15 09:00:22] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.30114269256591797
# [2024/09/15 09:00:22] ppocr DEBUG: cls num  : 6, elapsed : 0.02219700813293457
# [2024/09/15 09:00:23] ppocr DEBUG: rec_res num  : 6, elapsed : 0.26694703102111816
# Batch predictions appended to dataset/test_out.csv
# Processing 61th image...
# [2024/09/15 09:00:23] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.2948274612426758
# [2024/09/15 09:00:23] ppocr DEBUG: cls num  : 3, elapsed : 0.014671802520751953
# [2024/09/15 09:00:23] ppocr DEBUG: rec_res num  : 3, elapsed : 0.18610262870788574
# 180 centimeter
# Processing 62th image...
# [2024/09/15 09:00:24] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.2927718162536621
# [2024/09/15 09:00:24] ppocr DEBUG: cls num  : 2, elapsed : 0.043680429458618164
# [2024/09/15 09:00:24] ppocr DEBUG: rec_res num  : 2, elapsed : 0.13669347763061523
# 7 centimeter
# Processing 63th image...
# [2024/09/15 09:00:24] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.09803080558776855
# [2024/09/15 09:00:24] ppocr DEBUG: cls num  : 7, elapsed : 0.05283665657043457
# [2024/09/15 09:00:24] ppocr DEBUG: rec_res num  : 7, elapsed : 0.34575700759887695
# 27.76 inch
# Processing 64th image...
# [2024/09/15 09:00:25] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.37137532234191895
# [2024/09/15 09:00:25] ppocr DEBUG: cls num  : 2, elapsed : 0.016727685928344727
# [2024/09/15 09:00:25] ppocr DEBUG: rec_res num  : 2, elapsed : 0.1610734462738037
# Processing 65th image...
# [2024/09/15 09:00:26] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.8868396282196045
# [2024/09/15 09:00:26] ppocr DEBUG: cls num  : 3, elapsed : 0.04846692085266113
# [2024/09/15 09:00:26] ppocr DEBUG: rec_res num  : 3, elapsed : 0.47757911682128906
# Batch predictions appended to dataset/test_out.csv
# Processing 66th image...
# [2024/09/15 09:00:27] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.6035301685333252
# [2024/09/15 09:00:27] ppocr DEBUG: cls num  : 2, elapsed : 0.02451920509338379
# [2024/09/15 09:00:27] ppocr DEBUG: rec_res num  : 2, elapsed : 0.23115324974060059
# 2.55 inch
# Processing 67th image...
# [2024/09/15 09:00:28] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.2875349521636963
# [2024/09/15 09:00:28] ppocr DEBUG: cls num  : 6, elapsed : 0.0541534423828125
# [2024/09/15 09:00:28] ppocr DEBUG: rec_res num  : 6, elapsed : 0.38408899307250977
# 9.8 inch
# Processing 68th image...
# [2024/09/15 09:00:29] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.44872093200683594
# [2024/09/15 09:00:29] ppocr DEBUG: cls num  : 2, elapsed : 0.015366077423095703
# [2024/09/15 09:00:29] ppocr DEBUG: rec_res num  : 2, elapsed : 0.16715383529663086
# 5.90 inch
# Processing 69th image...
# [2024/09/15 09:00:29] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.2952711582183838
# [2024/09/15 09:00:29] ppocr DEBUG: cls num  : 2, elapsed : 0.01501607894897461
# [2024/09/15 09:00:29] ppocr DEBUG: rec_res num  : 2, elapsed : 0.13805460929870605
# 1.5 inch
# Processing 70th image...
# [2024/09/15 09:00:30] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.29807424545288086
# [2024/09/15 09:00:30] ppocr DEBUG: cls num  : 2, elapsed : 0.01705646514892578
# [2024/09/15 09:00:30] ppocr DEBUG: rec_res num  : 2, elapsed : 0.13017940521240234
# 8.2 inch
# Batch predictions appended to dataset/test_out.csv
# Processing 71th image...
# [2024/09/15 09:00:30] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.2976672649383545
# [2024/09/15 09:00:30] ppocr DEBUG: cls num  : 3, elapsed : 0.013471841812133789
# [2024/09/15 09:00:30] ppocr DEBUG: rec_res num  : 3, elapsed : 0.12813854217529297
# 16.5 centimeter
# Processing 72th image...
# [2024/09/15 09:00:31] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.31012845039367676
# [2024/09/15 09:00:31] ppocr DEBUG: cls num  : 2, elapsed : 0.015793800354003906
# [2024/09/15 09:00:31] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10577082633972168
# Processing 73th image...
# [2024/09/15 09:00:31] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.2952752113342285
# [2024/09/15 09:00:31] ppocr DEBUG: cls num  : 3, elapsed : 0.014757156372070312
# [2024/09/15 09:00:32] ppocr DEBUG: rec_res num  : 3, elapsed : 0.12719154357910156
# 39 centimeter
# Processing 74th image...
# [2024/09/15 09:00:32] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.2929534912109375
# [2024/09/15 09:00:32] ppocr DEBUG: cls num  : 3, elapsed : 0.012864112854003906
# [2024/09/15 09:00:32] ppocr DEBUG: rec_res num  : 3, elapsed : 0.13663148880004883
# Processing 75th image...
# [2024/09/15 09:00:32] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.10343813896179199
# [2024/09/15 09:00:32] ppocr DEBUG: cls num  : 7, elapsed : 0.05467796325683594
# [2024/09/15 09:00:33] ppocr DEBUG: rec_res num  : 7, elapsed : 0.36887526512145996
# 58.4 centimeter
# Batch predictions appended to dataset/test_out.csv
# Processing 76th image...
# [2024/09/15 09:00:33] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.3074781894683838
# [2024/09/15 09:00:33] ppocr DEBUG: cls num  : 2, elapsed : 0.016341686248779297
# [2024/09/15 09:00:33] ppocr DEBUG: rec_res num  : 2, elapsed : 0.1408555507659912
# 21 centimeter
# Processing 77th image...
# [2024/09/15 09:00:34] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.2993636131286621
# [2024/09/15 09:00:34] ppocr DEBUG: cls num  : 2, elapsed : 0.018544673919677734
# [2024/09/15 09:00:34] ppocr DEBUG: rec_res num  : 2, elapsed : 0.14330792427062988
# 7.5 centimeter
# Processing 78th image...
# [2024/09/15 09:00:34] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.10042023658752441
# [2024/09/15 09:00:34] ppocr DEBUG: cls num  : 6, elapsed : 0.024538040161132812
# [2024/09/15 09:00:34] ppocr DEBUG: rec_res num  : 6, elapsed : 0.27543020248413086
# 27.94 centimeter
# Processing 79th image...
# [2024/09/15 09:00:35] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.2954895496368408
# [2024/09/15 09:00:35] ppocr DEBUG: cls num  : 2, elapsed : 0.016167402267456055
# [2024/09/15 09:00:35] ppocr DEBUG: rec_res num  : 2, elapsed : 0.12764978408813477
# 15.5 centimeter
# Processing 80th image...
# Batch predictions appended to dataset/test_out.csv
# Processing 81th image...
# [2024/09/15 09:00:35] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.310711145401001
# [2024/09/15 09:00:35] ppocr DEBUG: cls num  : 2, elapsed : 0.01610255241394043
# [2024/09/15 09:00:35] ppocr DEBUG: rec_res num  : 2, elapsed : 0.1369614601135254
# 40 centimeter
# Processing 82th image...
# Processing 83th image...
# [2024/09/15 09:00:36] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.34129977226257324
# [2024/09/15 09:00:36] ppocr DEBUG: cls num  : 3, elapsed : 0.018497228622436523
# [2024/09/15 09:00:36] ppocr DEBUG: rec_res num  : 3, elapsed : 0.14800477027893066
# 25 centimeter
# Processing 84th image...
# [2024/09/15 09:00:36] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.31560444831848145
# [2024/09/15 09:00:36] ppocr DEBUG: cls num  : 2, elapsed : 0.018765926361083984
# [2024/09/15 09:00:36] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09519720077514648
# 17 centimeter
# Processing 85th image...
# [2024/09/15 09:00:37] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.30895161628723145
# [2024/09/15 09:00:37] ppocr DEBUG: cls num  : 2, elapsed : 0.01615166664123535
# [2024/09/15 09:00:37] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09770369529724121
# 16 centimeter
# Batch predictions appended to dataset/test_out.csv
# Processing 86th image...
# [2024/09/15 09:00:37] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.3079521656036377
# [2024/09/15 09:00:37] ppocr DEBUG: cls num  : 2, elapsed : 0.016233444213867188
# [2024/09/15 09:00:37] ppocr DEBUG: rec_res num  : 2, elapsed : 0.0962975025177002
# 12 inch
# Processing 87th image...
# [2024/09/15 09:00:38] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.14327621459960938
# [2024/09/15 09:00:38] ppocr DEBUG: cls num  : 4, elapsed : 0.020882129669189453
# [2024/09/15 09:00:38] ppocr DEBUG: rec_res num  : 4, elapsed : 0.18097329139709473
# 74 centimeter
# Processing 88th image...
# [2024/09/15 09:00:38] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.3091311454772949
# [2024/09/15 09:00:38] ppocr DEBUG: cls num  : 6, elapsed : 0.021863937377929688
# [2024/09/15 09:00:39] ppocr DEBUG: rec_res num  : 6, elapsed : 0.2506570816040039
# Processing 89th image...
# [2024/09/15 09:00:39] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.3729696273803711
# [2024/09/15 09:00:39] ppocr DEBUG: cls num  : 3, elapsed : 0.020509719848632812
# [2024/09/15 09:00:39] ppocr DEBUG: rec_res num  : 3, elapsed : 0.19697093963623047
# 190 centimeter
# Processing 90th image...
# Batch predictions appended to dataset/test_out.csv
# Processing 91th image...
# [2024/09/15 09:00:40] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.45022058486938477
# [2024/09/15 09:00:40] ppocr DEBUG: cls num  : 3, elapsed : 0.018193960189819336
# [2024/09/15 09:00:40] ppocr DEBUG: rec_res num  : 3, elapsed : 0.19390416145324707
# 30 centimeter
# Processing 92th image...
# [2024/09/15 09:00:41] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.4494328498840332
# [2024/09/15 09:00:41] ppocr DEBUG: cls num  : 2, elapsed : 0.024311065673828125
# [2024/09/15 09:00:41] ppocr DEBUG: rec_res num  : 2, elapsed : 0.20919585227966309
# 2.4 inch
# Processing 93th image...
# [2024/09/15 09:00:41] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.4503767490386963
# [2024/09/15 09:00:41] ppocr DEBUG: cls num  : 2, elapsed : 0.023763179779052734
# [2024/09/15 09:00:42] ppocr DEBUG: rec_res num  : 2, elapsed : 0.16847777366638184
# 60 centimeter
# Processing 94th image...
# [2024/09/15 09:00:42] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.13980555534362793
# [2024/09/15 09:00:42] ppocr DEBUG: cls num  : 2, elapsed : 0.02453017234802246
# [2024/09/15 09:00:42] ppocr DEBUG: rec_res num  : 2, elapsed : 0.14383554458618164
# Processing 95th image...
# [2024/09/15 09:00:42] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.34443163871765137
# [2024/09/15 09:00:42] ppocr DEBUG: cls num  : 2, elapsed : 0.01753997802734375
# [2024/09/15 09:00:42] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10337281227111816
# 40 centimeter
# Batch predictions appended to dataset/test_out.csv
# Processing 96th image...
# [2024/09/15 09:00:43] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.3117828369140625
# [2024/09/15 09:00:43] ppocr DEBUG: cls num  : 1, elapsed : 0.03599214553833008
# [2024/09/15 09:00:43] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10636281967163086
# 11.5 centimeter
# Processing 97th image...
# Processing 98th image...
# [2024/09/15 09:00:43] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.2972536087036133
# [2024/09/15 09:00:43] ppocr DEBUG: cls num  : 3, elapsed : 0.013850212097167969
# [2024/09/15 09:00:44] ppocr DEBUG: rec_res num  : 3, elapsed : 0.14226007461547852
# 100 centimeter
# Processing 99th image...
# [2024/09/15 09:00:44] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.29523754119873047
# [2024/09/15 09:00:44] ppocr DEBUG: cls num  : 4, elapsed : 0.014474630355834961
# [2024/09/15 09:00:44] ppocr DEBUG: rec_res num  : 4, elapsed : 0.17412114143371582
# 22.2 centimeter
# Processing 100th image...
# [2024/09/15 09:00:45] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.3100712299346924
# [2024/09/15 09:00:45] ppocr DEBUG: cls num  : 4, elapsed : 0.013753652572631836
# [2024/09/15 09:00:45] ppocr DEBUG: rec_res num  : 4, elapsed : 0.25447964668273926
# 5 centimeter
# Batch predictions appended to dataset/test_out.csv
# Processing 101th image...
# [2024/09/15 09:00:45] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.20710992813110352
# [2024/09/15 09:00:45] ppocr DEBUG: cls num  : 3, elapsed : 0.014664411544799805
# [2024/09/15 09:00:45] ppocr DEBUG: rec_res num  : 3, elapsed : 0.14044785499572754
# 146 centimeter
# Processing 102th image...
# [2024/09/15 09:00:46] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.3143479824066162
# [2024/09/15 09:00:46] ppocr DEBUG: cls num  : 2, elapsed : 0.01705169677734375
# [2024/09/15 09:00:46] ppocr DEBUG: rec_res num  : 2, elapsed : 0.14960861206054688
# 8.3 inch
# Processing 103th image...
# Processing 104th image...
# [2024/09/15 09:00:46] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.306581974029541
# [2024/09/15 09:00:46] ppocr DEBUG: cls num  : 2, elapsed : 0.01659107208251953
# [2024/09/15 09:00:46] ppocr DEBUG: rec_res num  : 2, elapsed : 0.1482982635498047
# 3.14 inch
# Processing 105th image...
# [2024/09/15 09:00:47] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.3138144016265869
# [2024/09/15 09:00:47] ppocr DEBUG: cls num  : 3, elapsed : 0.013020753860473633
# [2024/09/15 09:00:47] ppocr DEBUG: rec_res num  : 3, elapsed : 0.20154595375061035
# 3.74 inch
# Batch predictions appended to dataset/test_out.csv
# Processing 106th image...
# [2024/09/15 09:00:47] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.30303406715393066
# [2024/09/15 09:00:47] ppocr DEBUG: cls num  : 2, elapsed : 0.019101381301879883
# [2024/09/15 09:00:48] ppocr DEBUG: rec_res num  : 2, elapsed : 0.12328958511352539
# 6.29 inch
# Processing 107th image...
# [2024/09/15 09:00:48] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.3049046993255615
# [2024/09/15 09:00:48] ppocr DEBUG: cls num  : 3, elapsed : 0.01525425910949707
# [2024/09/15 09:00:48] ppocr DEBUG: rec_res num  : 3, elapsed : 0.18692231178283691
# 175 centimeter
# Processing 108th image...
# Processing 109th image...
# [2024/09/15 09:00:49] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.3056209087371826
# [2024/09/15 09:00:49] ppocr DEBUG: cls num  : 2, elapsed : 0.01846933364868164
# [2024/09/15 09:00:49] ppocr DEBUG: rec_res num  : 2, elapsed : 0.17029857635498047
# 15.35 inch
# Processing 110th image...
# [2024/09/15 09:00:49] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.13512206077575684
# [2024/09/15 09:00:49] ppocr DEBUG: cls num  : 2, elapsed : 0.017925500869750977
# [2024/09/15 09:00:49] ppocr DEBUG: rec_res num  : 2, elapsed : 0.12978863716125488
# 13 inch
# Batch predictions appended to dataset/test_out.csv
# Processing 111th image...
# [2024/09/15 09:00:50] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.29003024101257324
# [2024/09/15 09:00:50] ppocr DEBUG: cls num  : 1, elapsed : 0.03631591796875
# [2024/09/15 09:00:50] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10437893867492676
# 30 centimeter
# Processing 112th image...
# [2024/09/15 09:00:50] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.29421067237854004
# [2024/09/15 09:00:50] ppocr DEBUG: cls num  : 2, elapsed : 0.016364336013793945
# [2024/09/15 09:00:50] ppocr DEBUG: rec_res num  : 2, elapsed : 0.15484380722045898
# 5.9 inch
# Processing 113th image...
# [2024/09/15 09:00:51] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.29027891159057617
# [2024/09/15 09:00:51] ppocr DEBUG: cls num  : 4, elapsed : 0.026093482971191406
# [2024/09/15 09:00:51] ppocr DEBUG: rec_res num  : 4, elapsed : 0.21749472618103027
# 36 centimeter
# Processing 114th image...
# [2024/09/15 09:00:51] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.2526686191558838
# [2024/09/15 09:00:51] ppocr DEBUG: cls num  : 2, elapsed : 0.016063928604125977
# [2024/09/15 09:00:51] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10115861892700195
# 12 millimeter
# Processing 115th image...
# [2024/09/15 09:00:52] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.1838827133178711
# [2024/09/15 09:00:52] ppocr DEBUG: cls num  : 8, elapsed : 0.056055307388305664
# [2024/09/15 09:00:52] ppocr DEBUG: rec_res num  : 8, elapsed : 0.6276800632476807
# 11.7 centimeter
# Batch predictions appended to dataset/test_out.csv
# Processing 116th image...
# Processing 117th image...
# [2024/09/15 09:00:53] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.22703313827514648
# [2024/09/15 09:00:53] ppocr DEBUG: cls num  : 2, elapsed : 0.022312641143798828
# [2024/09/15 09:00:53] ppocr DEBUG: rec_res num  : 2, elapsed : 0.14269304275512695
# 9 centimeter
# Processing 118th image...
# [2024/09/15 09:00:53] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.45142698287963867
# [2024/09/15 09:00:53] ppocr DEBUG: cls num  : 4, elapsed : 0.019108057022094727
# [2024/09/15 09:00:54] ppocr DEBUG: rec_res num  : 4, elapsed : 0.26154160499572754
# Processing 119th image...
# [2024/09/15 09:00:54] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.4434623718261719
# [2024/09/15 09:00:54] ppocr DEBUG: cls num  : 4, elapsed : 0.022192716598510742
# [2024/09/15 09:00:54] ppocr DEBUG: rec_res num  : 4, elapsed : 0.2605628967285156
# Processing 120th image...
# [2024/09/15 09:00:55] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.4523589611053467
# [2024/09/15 09:00:55] ppocr DEBUG: cls num  : 5, elapsed : 0.05799722671508789
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-64c40e1e6106> in <cell line: 25>()
#      51
#      52         # Apply the predictor function to each row of the batch
# ---> 53         batch['prediction'] = batch.apply(lambda row: predictor(row['image_link'], row['group_id'], row['entity_name']), axis=1)
#      54
#      55         # Save the batch predictions to the same file
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10032             kwargs=kwargs,
#   10033         )
# > 10034         return op.apply().__finalize__(self, method="apply")
#   10035
#   10036     def map(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#     835             return self.apply_raw()
#     836
# --> 837         return self.apply_standard()
#     838
#     839     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#     963
#     964     def apply_standard(self):
# --> 965         results, res_index = self.apply_series_generator()
#     966
#     967         # wrap results
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     979             for i, v in enumerate(series_gen):
#     980                 # ignore SettingWithCopy here in case the user mutates
# --> 981                 results[i] = self.func(v, *self.args, **self.kwargs)
#     982                 if isinstance(results[i], ABCSeries):
#     983                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-5-64c40e1e6106> in <lambda>(row)
#      51
#      52         # Apply the predictor function to each row of the batch
# ---> 53         batch['prediction'] = batch.apply(lambda row: predictor(row['image_link'], row['group_id'], row['entity_name']), axis=1)
#      54
#      55         # Save the batch predictions to the same file
#
# <ipython-input-5-64c40e1e6106> in predictor(url, category_id, entity_name)
#      10     i += 1
#      11     print(f"Processing {i}th image...")
# ---> 12     return get_horizontal(url)
#      13
#      14 def save_predictions(df):
#
# <ipython-input-4-59d61b555083> in get_horizontal(image_url)
#     159     image = url_to_image(image_url)
#     160
# --> 161     closest_text, min_distance = find_minimum_distance_text(image)
#     162
#     163     if closest_text:
#
# <ipython-input-4-59d61b555083> in find_minimum_distance_text(image)
#     110
#     111     # Extract text and coordinates
# --> 112     text_coordinates = extract_text_with_coordinates(image)
#     113
#     114     # Initialize variables to store minimum distance and corresponding text
#
# <ipython-input-4-59d61b555083> in extract_text_with_coordinates(image)
#      80 def extract_text_with_coordinates(image):
#      81     # Extract text using PaddleOCR
# ---> 82     result = ocr.ocr(image)
#      83
#      84     text_coordinates = []
#
# /usr/local/lib/python3.10/dist-packages/paddleocr/paddleocr.py in ocr(self, img, det, rec, cls, bin, inv, alpha_color, slice)
#     727             for idx, img in enumerate(imgs):
#     728                 img = preprocess_image(img)
# --> 729                 dt_boxes, rec_res, _ = self.__call__(img, cls, slice)
#     730                 if not dt_boxes and not rec_res:
#     731                     ocr_res.append(None)
#
# /usr/local/lib/python3.10/dist-packages/paddleocr/tools/infer/predict_system.py in __call__(self, img, cls, slice)
#     142             )
#     143
# --> 144         rec_res, elapse = self.text_recognizer(img_crop_list)
#     145         time_dict["rec"] = elapse
#     146         logger.debug("rec_res num  : {}, elapsed : {}".format(len(rec_res), elapse))
#
# /usr/local/lib/python3.10/dist-packages/paddleocr/tools/infer/predict_rec.py in __call__(self, img_list)
#     675                 else:
#     676                     self.input_tensor.copy_from_cpu(norm_img_batch)
# --> 677                     self.predictor.run()
#     678                     outputs = []
#     679                     for output_tensor in self.output_tensors:
#
# KeyboardInterrupt:
